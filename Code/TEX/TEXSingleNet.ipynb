# %%
#unzip NEU datasets
# !unzip '/content/drive/MyDrive/TEX/TEX_validation.zip' -d '/content'
# !unzip '/content/drive/MyDrive/TEX/TEX_test.zip' -d '/content'
# !unzip '/content/drive/MyDrive/TEX/100_samples.zip' -d '/content'
# !unzip '/content/drive/MyDrive/TEX/50_samples.zip' -d '/content'
# !unzip '/content/drive/MyDrive/TEX/20_samples.zip' -d '/content'
# !unzip '/content/drive/MyDrive/TEX/10_samples.zip' -d '/content'
# !unzip '/content/drive/MyDrive/TEX/5_samples.zip' -d '/content'
# !unzip '/content/drive/MyDrive/TEX/3_samples.zip' -d '/content'
# Out:
# "\n!unzip '/content/drive/MyDrive/TEX/TEX_validation.zip' -d '/content'\n!unzip '/content/drive/MyDrive/TEX/TEX_test.zip' -d '/content'\n!unzip '/content/drive/MyDrive/TEX/100_samples.zip' -d '/content'\n!unzip '/content/drive/MyDrive/TEX/50_samples.zip' -d '/content'\n!unzip '/content/drive/MyDrive/TEX/20_samples.zip' -d '/content'\n!unzip '/content/drive/MyDrive/TEX/10_samples.zip' -d '/content'\n!unzip '/content/drive/MyDrive/TEX/5_samples.zip' -d '/content'\n!unzip '/content/drive/MyDrive/TEX/3_samples.zip' -d '/content'\n"

# %%
import random
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import tensorflow.keras.backend as K
from tensorflow import keras
from sklearn import model_selection
import imgaug.augmenters as iaa
import imgaug as ia
import os

# %%
#image augmentation
ia.seed(1)
def Data_Aug(samples):
    randomaug = iaa.Sometimes(
        0.5,
        iaa.OneOf([
            iaa.Sequential([
                iaa.AllChannelsCLAHE(clip_limit=(1, 10)),
                iaa.Affine(rotate=(-5, 5))
            ]),
            iaa.Sequential([
                iaa.Affine(translate_percent={
                    "x": (-0.2, 0.2),
                    "y": (-0.2, 0.2)
                }),
                iaa.Multiply((0.7, 1.3)),
                iaa.AdditiveLaplaceNoise(scale=0.03 * 255, per_channel=True),
                iaa.Fliplr(0.3),
                iaa.Flipud(0.3)
            ]),
            iaa.Sequential([
                iaa.Affine(rotate=(-10, 10)),
                iaa.Multiply((0.7, 1.3)),
                iaa.AdditiveLaplaceNoise(scale=0.03 * 255, per_channel=True),
                iaa.Fliplr(0.3),
                iaa.Flipud(0.3)
            ]),
            iaa.Sequential([
                iaa.PerspectiveTransform(scale=(0, 0.15)),
                iaa.Multiply((0.7, 1.3)),
                iaa.AdditiveLaplaceNoise(scale=0.03 * 255, per_channel=True),
                iaa.Fliplr(0.3),
                iaa.Flipud(0.3)
            ])
        ]))


    return randomaug.augment_images(samples)

def resize_images(imgs, hight, width):
    seq = iaa.Resize({"height": hight, "width": width})
    aug = seq.augment_images(imgs)
    return aug

# %%
#load NEU images
def load_data(dir_path, labels_dict):
  all_names = os.listdir(dir_path)
  data_x = []
  data_y = []
  for name in all_names:
    img = keras.preprocessing.image.load_img(os.path.join(dir_path, name))
    img = keras.preprocessing.image.img_to_array(img,dtype='uint8')
    data_x.append(img)
    lab = labels_dict[name.split(' ')[0]]
    data_y.append(lab)
  data_x = np.array(data_x)
  data_y = np.array(data_y)
  return data_x, data_y
class TEXdata(keras.utils.Sequence):
    def __init__(self, data_x, data_y, batch_size, train):
      self.data_x = data_x
      self.data_y = data_y
      self.train = train
      self.batch_size = batch_size

    def __len__(self):
      return int(np.ceil(len(self.data_y) / self.batch_size))

    def __getitem__(self, idx):
      batch_x = self.data_x[idx * self.batch_size:(idx + 1) * self.batch_size]
                            
      batch_y = self.data_y[idx * self.batch_size:(idx + 1) * self.batch_size]
      if self.train == True:
          batch_x = Data_Aug(batch_x)

      batch_x = np.clip(batch_x / 255.0, 0, 1).astype("float32")
      batch_y = keras.utils.to_categorical(batch_y, 6)
      return batch_x, batch_y

# %%
#save the best model during training
class CustomEarlyStoppingAndSave(keras.callbacks.Callback):
    def __init__(self, save_path, patience=0):
        super(CustomEarlyStoppingAndSave, self).__init__()
        #self.patience = patience
        self.save_path = save_path
        self.best_weights = None

    def on_train_begin(self, logs=None):
        #self.wait = 0
        self.stopped_epoch = 0
        #self.best_val_distance_loss = np.Inf
        self.best_val_acc = 0

    def on_epoch_end(self, epoch, logs=None):
        #val_distance_loss = logs.get('val_MMD_loss')
        val_acc = logs.get('val_accuracy') 

        if  np.greater(val_acc, self.best_val_acc):
            #self.best_val_distance_loss = val_distance_loss
            self.best_val_acc = val_acc
            #self.wait = 0
            # Record the best weights if current results is better (less).
            self.best_weights = self.model.get_weights()
            self.stopped_epoch = epoch
        #else:
            #self.wait += 1
            #if self.wait >= self.patience:
                #self.stopped_epoch = epoch
                #self.model.stop_training = True
                #print("Restoring model weights from the end of the best epoch.")
                #self.model.set_weights(self.best_weights)

    def on_train_end(self, logs=None):
        self.model.set_weights(self.best_weights)
        if self.stopped_epoch >= 0:
            print("Epoch %05d: early stopping and save the model" %
                  (self.stopped_epoch + 1))
        self.model.save(self.save_path)

# %%
#create single AlexNet
def create_AlexNet(input_shape, num_classes=6, random_seed=None):
  inputs = keras.Input(shape=input_shape)
  x = keras.layers.Conv2D(96, (3,3), strides=(2,2), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(inputs)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x)
  x = keras.layers.MaxPooling2D(pool_size=(3,3),strides=(2,2),padding='same')(x)
  
  x = keras.layers.Conv2D(256, (3,3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x) 
  x = keras.layers.MaxPooling2D(pool_size=(3,3),strides=(2,2),padding='same')(x)
 
  x = keras.layers.Conv2D(384, (3,3), padding='same', activation='relu', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x) 
  x = keras.layers.Conv2D(384, (3,3), padding='same', activation='relu', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x) 
  x = keras.layers.Conv2D(256, (3,3), padding='same', activation='relu', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  feature_maps = keras.layers.MaxPooling2D(pool_size=(3,3),strides=(2,2),padding='same')(x)
  
  x = keras.layers.Flatten()(feature_maps)
  #x = keras.layers.Dense(256,activation='relu')(x)
  #x = keras.layers.Dropout(0.5)(x)
  x = keras.layers.Dense(128,activation='relu')(x)
  x = keras.layers.Dropout(0.5)(x)
  outputs = keras.layers.Dense(num_classes, activation='softmax')(x)
  model = keras.Model(inputs=inputs, outputs=outputs)
  return model

# %%
def create_VGGNet(input_shape, num_classes,  random_seed=None):
  inputs = keras.Input(shape=input_shape)
  x = keras.layers.Conv2D(64, (3, 3), padding='same',  kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(inputs)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x)
  x = keras.layers.Conv2D(64, (3, 3), padding='same',  kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x)
  x = keras.layers.MaxPooling2D((2, 2))(x)
  x = keras.layers.Dropout(0.2)(x)

  x = keras.layers.Conv2D(128, (3, 3), padding='same',  kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x)
  x = keras.layers.Conv2D(128, (3, 3), padding='same',  kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x)
  x = keras.layers.MaxPooling2D((2, 2))(x)
  x = keras.layers.Dropout(0.3)(x)
  
  x = keras.layers.Conv2D(256, (3, 3), padding='same',  kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x)
  x = keras.layers.Conv2D(256, (3, 3), padding='same',  kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x)
  x = keras.layers.Conv2D(256, (3, 3), padding='same',  kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x)
  x = keras.layers.MaxPooling2D((2, 2))(x)
  x = keras.layers.Dropout(0.4)(x)


    
  x = keras.layers.Conv2D(512, (3, 3), padding='same',  kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x)
  x = keras.layers.Conv2D(512, (3, 3), padding='same',  kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x)
  x = keras.layers.Conv2D(512, (3, 3), padding='same',  kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x)
  p3 = keras.layers.MaxPooling2D((2, 2))(x)
  x = keras.layers.Dropout(0.5)(p3)


 
   
  '''  
  x = keras.layers.Conv2D(512, (3, 3), padding='same',  kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x)
  x = keras.layers.Conv2D(512, (3, 3), padding='same',  kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x)
  x = keras.layers.Conv2D(512, (3, 3), padding='same',  kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x)
  x = keras.layers.MaxPooling2D((2, 2))(x)
  x = keras.layers.Dropout(0.5)(x) 
  '''
  
 

  #x = keras.layers.GlobalAveragePooling2D()(x)
  x = keras.layers.Flatten()(x)
  x = keras.layers.Dense(128,  kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x)
  x = keras.layers.Dropout(0.5)(x)
  outputs = keras.layers.Dense(num_classes, activation='softmax')(x)
  return keras.Model(inputs=inputs, outputs=outputs)

# %%
def create_ResNet(input_shape, num_classes=6, num_filters = 64, random_seed=None):
  inputs = keras.Input(shape=input_shape)
  y = keras.layers.Conv2D(num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(inputs)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  y = keras.layers.Conv2D(num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(y)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  y = keras.layers.Conv2D(num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(y)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  x = keras.layers.Conv2D(num_filters, (1, 1), kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(inputs)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.add([x, y])
  x = keras.layers.LeakyReLU(alpha=0.1)(x)
  x = keras.layers.MaxPooling2D((2,2))(x)

  
  y = keras.layers.Conv2D(2*num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  y = keras.layers.Conv2D(2*num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(y)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  y = keras.layers.Conv2D(2*num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(y)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  x = keras.layers.Conv2D(2*num_filters, (1, 1), kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.add([x, y])
  x = keras.layers.LeakyReLU(alpha=0.1)(x)
  x = keras.layers.MaxPooling2D((2,2))(x) 

    
  y = keras.layers.Conv2D(4*num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  y = keras.layers.Conv2D(4*num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(y)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  y = keras.layers.Conv2D(4*num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(y)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  x = keras.layers.Conv2D(4*num_filters, (1, 1), kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.add([x, y])
  x = keras.layers.LeakyReLU(alpha=0.1)(x)
  x = keras.layers.MaxPooling2D((2,2))(x) 

 
    
  y = keras.layers.Conv2D(8*num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  y = keras.layers.Conv2D(8*num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(y)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  y = keras.layers.Conv2D(8*num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(y)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  x = keras.layers.Conv2D(8*num_filters, (1, 1), kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.add([x, y])
  x = keras.layers.LeakyReLU(alpha=0.1)(x)
  x = keras.layers.MaxPooling2D((2,2))(x) 
  
  
  
  

  x = keras.layers.GlobalAveragePooling2D()(x)
  outputs = keras.layers.Dense(num_classes, activation='softmax', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  model = keras.Model(inputs=inputs, outputs=outputs)
  return model

# %%
#load training, validation and testing images
training_data_path = '100_samples'
validation_data_path = 'TEX_validation'
test_data_path = 'TEX_test'
labels_dict = {'color': 0, 'cut': 1, 'good': 2, 'hole': 3, 'metal_contamination': 4, 'thread': 5}
x_train, y_train = load_data(training_data_path, labels_dict)
x_val, y_val = load_data(validation_data_path, labels_dict)
x_test, y_test = load_data(test_data_path, labels_dict)
_, x_val, _, y_val = model_selection.train_test_split(
    x_val,
    y_val,
    test_size=2400,
    random_state=0,
    stratify=y_val)
x_test = x_test/255.0

# %%
#construct model
input_size = (64, 64, 3)

model = create_AlexNet(input_shape=input_size, num_classes=6, random_seed=None)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4),
                    loss=['categorical_crossentropy'],
                    metrics=['accuracy'])

train_sequence = TEXdata(x_train, y_train, batch_size=10, train=True)
validation_sequence = TEXdata(x_val, y_val, batch_size=10, train=False)

#training
history = model.fit(
    train_sequence,
    epochs=300,
    validation_data=validation_sequence,
    #validation_steps=12,
    callbacks=CustomEarlyStoppingAndSave(
        save_path='100_samples_seed_fix.h5',
        patience=10))
# Out:
# Epoch 1/300
# 2/2 [==============================] - 4s 1s/step - loss: 5.4360 - accuracy: 0.2222 - val_loss: 1.8376 - val_accuracy: 0.2000
# Epoch 2/300
# 2/2 [==============================] - 1s 969ms/step - loss: 2.7221 - accuracy: 0.2778 - val_loss: 1.9145 - val_accuracy: 0.1683
# Epoch 3/300
# 2/2 [==============================] - 1s 946ms/step - loss: 3.1379 - accuracy: 0.1667 - val_loss: 1.8576 - val_accuracy: 0.1667
# Epoch 4/300
# 2/2 [==============================] - 1s 989ms/step - loss: 2.5800 - accuracy: 0.2222 - val_loss: 1.8307 - val_accuracy: 0.1796
# Epoch 5/300
# 2/2 [==============================] - 1s 976ms/step - loss: 2.8599 - accuracy: 0.3333 - val_loss: 1.8270 - val_accuracy: 0.1708
# Epoch 6/300
# 2/2 [==============================] - 1s 974ms/step - loss: 2.6625 - accuracy: 0.0556 - val_loss: 1.8216 - val_accuracy: 0.1667
# Epoch 7/300
# 2/2 [==============================] - 1s 987ms/step - loss: 2.5154 - accuracy: 0.2222 - val_loss: 1.8194 - val_accuracy: 0.1675
# Epoch 8/300
# 2/2 [==============================] - 1s 975ms/step - loss: 1.8078 - accuracy: 0.4444 - val_loss: 1.8128 - val_accuracy: 0.1721
# Epoch 9/300
# 2/2 [==============================] - 1s 993ms/step - loss: 2.0997 - accuracy: 0.1667 - val_loss: 1.8029 - val_accuracy: 0.1717
# Epoch 10/300
# 2/2 [==============================] - 1s 962ms/step - loss: 1.5677 - accuracy: 0.4444 - val_loss: 1.8122 - val_accuracy: 0.1771
# Epoch 11/300
# 2/2 [==============================] - 1s 953ms/step - loss: 1.7648 - accuracy: 0.1667 - val_loss: 1.8259 - val_accuracy: 0.1737
# Epoch 12/300
# 2/2 [==============================] - 1s 972ms/step - loss: 1.7548 - accuracy: 0.2222 - val_loss: 1.8262 - val_accuracy: 0.1704
# Epoch 13/300
# 2/2 [==============================] - 1s 957ms/step - loss: 1.5476 - accuracy: 0.2778 - val_loss: 1.8079 - val_accuracy: 0.1750
# Epoch 14/300
# 2/2 [==============================] - 1s 964ms/step - loss: 1.1642 - accuracy: 0.6111 - val_loss: 1.7975 - val_accuracy: 0.1708
# Epoch 15/300
# 2/2 [==============================] - 1s 963ms/step - loss: 1.2176 - accuracy: 0.6667 - val_loss: 1.7943 - val_accuracy: 0.1642
# Epoch 16/300
# 2/2 [==============================] - 1s 985ms/step - loss: 1.5735 - accuracy: 0.3333 - val_loss: 1.7929 - val_accuracy: 0.1637
# Epoch 17/300
# 2/2 [==============================] - 1s 937ms/step - loss: 1.3203 - accuracy: 0.4444 - val_loss: 1.7897 - val_accuracy: 0.1700
# Epoch 18/300
# 2/2 [==============================] - 1s 960ms/step - loss: 1.3627 - accuracy: 0.5000 - val_loss: 1.7866 - val_accuracy: 0.1617
# Epoch 19/300
# 2/2 [==============================] - 1s 947ms/step - loss: 1.1890 - accuracy: 0.6111 - val_loss: 1.7974 - val_accuracy: 0.1771
# Epoch 20/300
# 2/2 [==============================] - 1s 945ms/step - loss: 1.2511 - accuracy: 0.4444 - val_loss: 1.8127 - val_accuracy: 0.1958
# Epoch 21/300
# 2/2 [==============================] - 1s 1s/step - loss: 1.3647 - accuracy: 0.5000 - val_loss: 1.8288 - val_accuracy: 0.1750
# Epoch 22/300
# 2/2 [==============================] - 1s 953ms/step - loss: 1.1996 - accuracy: 0.5556 - val_loss: 1.8256 - val_accuracy: 0.1758
# Epoch 23/300
# 2/2 [==============================] - 1s 955ms/step - loss: 1.0429 - accuracy: 0.6111 - val_loss: 1.8119 - val_accuracy: 0.1850
# Epoch 24/300
# 2/2 [==============================] - 1s 956ms/step - loss: 0.9847 - accuracy: 0.6667 - val_loss: 1.7966 - val_accuracy: 0.1925
# Epoch 25/300
# 2/2 [==============================] - 1s 966ms/step - loss: 1.0832 - accuracy: 0.4444 - val_loss: 1.7952 - val_accuracy: 0.1912
# Epoch 26/300
# 2/2 [==============================] - 1s 1s/step - loss: 1.1317 - accuracy: 0.6667 - val_loss: 1.7876 - val_accuracy: 0.1912
# Epoch 27/300
# 2/2 [==============================] - 1s 968ms/step - loss: 0.9819 - accuracy: 0.6111 - val_loss: 1.7890 - val_accuracy: 0.1908
# Epoch 28/300
# 2/2 [==============================] - 1s 996ms/step - loss: 1.0436 - accuracy: 0.6111 - val_loss: 1.7930 - val_accuracy: 0.1975
# Epoch 29/300
# 2/2 [==============================] - 1s 981ms/step - loss: 0.8701 - accuracy: 0.6667 - val_loss: 1.8012 - val_accuracy: 0.2046
# Epoch 30/300
# 2/2 [==============================] - 1s 978ms/step - loss: 0.6805 - accuracy: 0.8333 - val_loss: 1.8047 - val_accuracy: 0.2029
# Epoch 31/300
# 2/2 [==============================] - 1s 969ms/step - loss: 0.8125 - accuracy: 0.7222 - val_loss: 1.8054 - val_accuracy: 0.2037
# Epoch 32/300
# 2/2 [==============================] - 1s 979ms/step - loss: 0.9198 - accuracy: 0.6111 - val_loss: 1.8156 - val_accuracy: 0.2062
# Epoch 33/300
# 2/2 [==============================] - 1s 994ms/step - loss: 1.1041 - accuracy: 0.6111 - val_loss: 1.8120 - val_accuracy: 0.2071
# Epoch 34/300
# 2/2 [==============================] - 1s 956ms/step - loss: 1.0096 - accuracy: 0.6667 - val_loss: 1.7922 - val_accuracy: 0.2129
# Epoch 35/300
# 2/2 [==============================] - 1s 958ms/step - loss: 1.0115 - accuracy: 0.6667 - val_loss: 1.7773 - val_accuracy: 0.2125
# Epoch 36/300
# 2/2 [==============================] - 1s 978ms/step - loss: 0.7499 - accuracy: 0.7222 - val_loss: 1.7694 - val_accuracy: 0.2254
# Epoch 37/300
# 2/2 [==============================] - 1s 972ms/step - loss: 0.9333 - accuracy: 0.6667 - val_loss: 1.7744 - val_accuracy: 0.2321
# Epoch 38/300
# 2/2 [==============================] - 1s 957ms/step - loss: 0.8582 - accuracy: 0.7222 - val_loss: 1.7844 - val_accuracy: 0.2300
# Epoch 39/300
# 2/2 [==============================] - 1s 952ms/step - loss: 0.9679 - accuracy: 0.6111 - val_loss: 1.8153 - val_accuracy: 0.2292
# Epoch 40/300
# 2/2 [==============================] - 1s 987ms/step - loss: 0.5443 - accuracy: 0.8333 - val_loss: 1.8395 - val_accuracy: 0.2271
# Epoch 41/300
# 2/2 [==============================] - 1s 929ms/step - loss: 1.1864 - accuracy: 0.6667 - val_loss: 1.8249 - val_accuracy: 0.2037
# Epoch 42/300
# 2/2 [==============================] - 1s 985ms/step - loss: 1.2579 - accuracy: 0.5000 - val_loss: 1.7890 - val_accuracy: 0.2313
# Epoch 43/300
# 2/2 [==============================] - 1s 941ms/step - loss: 0.5898 - accuracy: 0.7778 - val_loss: 1.7622 - val_accuracy: 0.2562
# Epoch 44/300
# 2/2 [==============================] - 1s 975ms/step - loss: 0.7155 - accuracy: 0.7778 - val_loss: 1.7572 - val_accuracy: 0.2896
# Epoch 45/300
# 2/2 [==============================] - 1s 946ms/step - loss: 0.8585 - accuracy: 0.7778 - val_loss: 1.7567 - val_accuracy: 0.2837
# Epoch 46/300
# 2/2 [==============================] - 1s 979ms/step - loss: 0.9296 - accuracy: 0.6111 - val_loss: 1.7704 - val_accuracy: 0.2533
# Epoch 47/300
# 2/2 [==============================] - 1s 971ms/step - loss: 1.0033 - accuracy: 0.5556 - val_loss: 1.7990 - val_accuracy: 0.2362
# Epoch 48/300
# 2/2 [==============================] - 1s 970ms/step - loss: 1.1517 - accuracy: 0.5556 - val_loss: 1.8218 - val_accuracy: 0.1983
# Epoch 49/300
# 2/2 [==============================] - 1s 955ms/step - loss: 0.9602 - accuracy: 0.5556 - val_loss: 1.8455 - val_accuracy: 0.1825
# Epoch 50/300
# 2/2 [==============================] - 1s 966ms/step - loss: 0.8571 - accuracy: 0.7222 - val_loss: 1.8584 - val_accuracy: 0.1842
# Epoch 51/300
# 2/2 [==============================] - 1s 939ms/step - loss: 0.8118 - accuracy: 0.7222 - val_loss: 1.8411 - val_accuracy: 0.1787
# Epoch 52/300
# 2/2 [==============================] - 1s 958ms/step - loss: 0.9534 - accuracy: 0.6667 - val_loss: 1.8069 - val_accuracy: 0.1946
# Epoch 53/300
# 2/2 [==============================] - 1s 943ms/step - loss: 1.4487 - accuracy: 0.3889 - val_loss: 1.8136 - val_accuracy: 0.2054
# Epoch 54/300
# 2/2 [==============================] - 1s 952ms/step - loss: 0.6788 - accuracy: 0.6667 - val_loss: 1.8280 - val_accuracy: 0.2146
# Epoch 55/300
# 2/2 [==============================] - 1s 938ms/step - loss: 0.9001 - accuracy: 0.7778 - val_loss: 1.8510 - val_accuracy: 0.2096
# Epoch 56/300
# 2/2 [==============================] - 1s 985ms/step - loss: 0.8736 - accuracy: 0.7222 - val_loss: 1.8586 - val_accuracy: 0.2175
# Epoch 57/300
# 2/2 [==============================] - 1s 940ms/step - loss: 0.8081 - accuracy: 0.7778 - val_loss: 1.8563 - val_accuracy: 0.2196
# Epoch 58/300
# 2/2 [==============================] - 1s 929ms/step - loss: 0.4838 - accuracy: 0.8333 - val_loss: 1.8350 - val_accuracy: 0.2133
# Epoch 59/300
# 2/2 [==============================] - 1s 951ms/step - loss: 0.9929 - accuracy: 0.7222 - val_loss: 1.8371 - val_accuracy: 0.2096
# Epoch 60/300
# 2/2 [==============================] - 1s 941ms/step - loss: 0.6929 - accuracy: 0.7778 - val_loss: 1.8388 - val_accuracy: 0.2037
# Epoch 61/300
# 2/2 [==============================] - 1s 916ms/step - loss: 0.6844 - accuracy: 0.7778 - val_loss: 1.8348 - val_accuracy: 0.1988
# Epoch 62/300
# 2/2 [==============================] - 1s 912ms/step - loss: 0.3799 - accuracy: 0.9444 - val_loss: 1.8230 - val_accuracy: 0.2017
# Epoch 63/300
# 2/2 [==============================] - 1s 948ms/step - loss: 0.8457 - accuracy: 0.6667 - val_loss: 1.8091 - val_accuracy: 0.2008
# Epoch 64/300
# 2/2 [==============================] - 1s 959ms/step - loss: 0.7675 - accuracy: 0.7222 - val_loss: 1.8026 - val_accuracy: 0.1958
# Epoch 65/300
# 2/2 [==============================] - 1s 947ms/step - loss: 0.5387 - accuracy: 0.8333 - val_loss: 1.8236 - val_accuracy: 0.1967
# Epoch 66/300
# 2/2 [==============================] - 1s 942ms/step - loss: 0.7545 - accuracy: 0.6667 - val_loss: 1.8577 - val_accuracy: 0.1963
# Epoch 67/300
# 2/2 [==============================] - 1s 979ms/step - loss: 0.5624 - accuracy: 0.8333 - val_loss: 1.8952 - val_accuracy: 0.1892
# Epoch 68/300
# 2/2 [==============================] - 1s 945ms/step - loss: 0.5123 - accuracy: 0.8889 - val_loss: 1.9087 - val_accuracy: 0.1825
# Epoch 69/300
# 2/2 [==============================] - 1s 965ms/step - loss: 1.4020 - accuracy: 0.5000 - val_loss: 1.8581 - val_accuracy: 0.1929
# Epoch 70/300
# 2/2 [==============================] - 1s 1s/step - loss: 0.6492 - accuracy: 0.7778 - val_loss: 1.7853 - val_accuracy: 0.2279
# Epoch 71/300
# 2/2 [==============================] - 1s 960ms/step - loss: 0.8637 - accuracy: 0.7222 - val_loss: 1.8061 - val_accuracy: 0.2192
# Epoch 72/300
# 2/2 [==============================] - 1s 935ms/step - loss: 0.2893 - accuracy: 1.0000 - val_loss: 1.8444 - val_accuracy: 0.2037
# Epoch 73/300
# 2/2 [==============================] - 1s 940ms/step - loss: 0.6294 - accuracy: 0.6667 - val_loss: 1.8663 - val_accuracy: 0.2025
# Epoch 74/300
# 2/2 [==============================] - 1s 952ms/step - loss: 0.5691 - accuracy: 0.7778 - val_loss: 1.8754 - val_accuracy: 0.2071
# Epoch 75/300
# 2/2 [==============================] - 1s 986ms/step - loss: 0.3807 - accuracy: 0.9444 - val_loss: 1.9161 - val_accuracy: 0.2246
# Epoch 76/300
# 2/2 [==============================] - 1s 946ms/step - loss: 0.2864 - accuracy: 0.9444 - val_loss: 1.9791 - val_accuracy: 0.2275
# Epoch 77/300
# 2/2 [==============================] - 1s 969ms/step - loss: 0.8068 - accuracy: 0.7778 - val_loss: 2.0732 - val_accuracy: 0.2254
# Epoch 78/300
# 2/2 [==============================] - 1s 955ms/step - loss: 0.4062 - accuracy: 0.8889 - val_loss: 2.1127 - val_accuracy: 0.2267
# Epoch 79/300
# 2/2 [==============================] - 1s 951ms/step - loss: 0.1880 - accuracy: 0.9444 - val_loss: 2.1066 - val_accuracy: 0.2283
# Epoch 80/300
# 2/2 [==============================] - 1s 969ms/step - loss: 0.4038 - accuracy: 0.8333 - val_loss: 2.0642 - val_accuracy: 0.2350
# Epoch 81/300
# 2/2 [==============================] - 1s 950ms/step - loss: 0.9259 - accuracy: 0.6667 - val_loss: 1.9419 - val_accuracy: 0.2275
# Epoch 82/300
# 2/2 [==============================] - 1s 920ms/step - loss: 0.4674 - accuracy: 0.8889 - val_loss: 1.8532 - val_accuracy: 0.2404
# Epoch 83/300
# 2/2 [==============================] - 1s 947ms/step - loss: 1.1412 - accuracy: 0.6667 - val_loss: 1.8503 - val_accuracy: 0.2583
# Epoch 84/300
# 2/2 [==============================] - 1s 960ms/step - loss: 0.3168 - accuracy: 0.8889 - val_loss: 1.8661 - val_accuracy: 0.2254
# Epoch 85/300
# 2/2 [==============================] - 1s 1s/step - loss: 1.1532 - accuracy: 0.7222 - val_loss: 1.8509 - val_accuracy: 0.2417
# Epoch 86/300
# 2/2 [==============================] - 1s 962ms/step - loss: 0.6940 - accuracy: 0.7222 - val_loss: 1.8605 - val_accuracy: 0.2154
# Epoch 87/300
# 2/2 [==============================] - 1s 951ms/step - loss: 0.4504 - accuracy: 0.8333 - val_loss: 1.9906 - val_accuracy: 0.1958
# Epoch 88/300
# 2/2 [==============================] - 1s 932ms/step - loss: 0.7899 - accuracy: 0.7778 - val_loss: 2.1599 - val_accuracy: 0.1829
# Epoch 89/300
# 2/2 [==============================] - 1s 956ms/step - loss: 0.6191 - accuracy: 0.7778 - val_loss: 2.2412 - val_accuracy: 0.1762
# Epoch 90/300
# 2/2 [==============================] - 1s 980ms/step - loss: 0.6530 - accuracy: 0.7778 - val_loss: 2.2063 - val_accuracy: 0.1713
# Epoch 91/300
# 2/2 [==============================] - 1s 932ms/step - loss: 0.7251 - accuracy: 0.7778 - val_loss: 2.0778 - val_accuracy: 0.1758
# Epoch 92/300
# 2/2 [==============================] - 1s 929ms/step - loss: 0.3911 - accuracy: 0.8333 - val_loss: 1.9963 - val_accuracy: 0.1963
# Epoch 93/300
# 2/2 [==============================] - 1s 953ms/step - loss: 0.6186 - accuracy: 0.8333 - val_loss: 1.9729 - val_accuracy: 0.2208
# Epoch 94/300
# 2/2 [==============================] - 1s 960ms/step - loss: 0.8177 - accuracy: 0.6111 - val_loss: 1.9694 - val_accuracy: 0.2317
# Epoch 95/300
# 2/2 [==============================] - 1s 976ms/step - loss: 0.7947 - accuracy: 0.6667 - val_loss: 2.0525 - val_accuracy: 0.2246
# Epoch 96/300
# 2/2 [==============================] - 1s 942ms/step - loss: 1.0647 - accuracy: 0.6667 - val_loss: 2.0767 - val_accuracy: 0.2229
# Epoch 97/300
# 2/2 [==============================] - 1s 955ms/step - loss: 0.3606 - accuracy: 0.9444 - val_loss: 2.1306 - val_accuracy: 0.2129
# Epoch 98/300
# 2/2 [==============================] - 1s 960ms/step - loss: 0.7660 - accuracy: 0.7778 - val_loss: 2.1393 - val_accuracy: 0.2075
# Epoch 99/300
# 2/2 [==============================] - 1s 927ms/step - loss: 0.4059 - accuracy: 0.8889 - val_loss: 2.0392 - val_accuracy: 0.2154
# Epoch 100/300
# 2/2 [==============================] - 1s 959ms/step - loss: 1.0709 - accuracy: 0.5556 - val_loss: 2.0504 - val_accuracy: 0.2075
# Epoch 101/300
# 2/2 [==============================] - 1s 952ms/step - loss: 1.0486 - accuracy: 0.6111 - val_loss: 1.9530 - val_accuracy: 0.2267
# Epoch 102/300
# 2/2 [==============================] - 1s 964ms/step - loss: 0.5445 - accuracy: 0.8889 - val_loss: 1.8841 - val_accuracy: 0.2342
# Epoch 103/300
# 2/2 [==============================] - 1s 972ms/step - loss: 0.6539 - accuracy: 0.8333 - val_loss: 1.8734 - val_accuracy: 0.2167
# Epoch 104/300
# 2/2 [==============================] - 1s 968ms/step - loss: 0.4377 - accuracy: 0.9444 - val_loss: 1.8941 - val_accuracy: 0.2196
# Epoch 105/300
# 2/2 [==============================] - 1s 1s/step - loss: 0.7271 - accuracy: 0.7222 - val_loss: 1.9196 - val_accuracy: 0.2412
# Epoch 106/300
# 2/2 [==============================] - 1s 946ms/step - loss: 0.4065 - accuracy: 0.8889 - val_loss: 1.9193 - val_accuracy: 0.2342
# Epoch 107/300
# 2/2 [==============================] - 1s 965ms/step - loss: 0.7132 - accuracy: 0.7778 - val_loss: 1.8902 - val_accuracy: 0.2179
# Epoch 108/300
# 2/2 [==============================] - 1s 941ms/step - loss: 0.9846 - accuracy: 0.6111 - val_loss: 1.9081 - val_accuracy: 0.2108
# Epoch 109/300
# 2/2 [==============================] - 1s 943ms/step - loss: 0.5306 - accuracy: 0.8889 - val_loss: 1.9399 - val_accuracy: 0.2208
# Epoch 110/300
# 2/2 [==============================] - 1s 985ms/step - loss: 0.8687 - accuracy: 0.7222 - val_loss: 1.9867 - val_accuracy: 0.2071
# Epoch 111/300
# 2/2 [==============================] - 1s 983ms/step - loss: 0.5575 - accuracy: 0.7778 - val_loss: 2.0245 - val_accuracy: 0.1992
# Epoch 112/300
# 2/2 [==============================] - 1s 943ms/step - loss: 0.7892 - accuracy: 0.7778 - val_loss: 2.0660 - val_accuracy: 0.1908
# Epoch 113/300
# 2/2 [==============================] - 1s 958ms/step - loss: 0.4750 - accuracy: 0.8889 - val_loss: 2.0739 - val_accuracy: 0.1883
# Epoch 114/300
# 2/2 [==============================] - 1s 943ms/step - loss: 0.4824 - accuracy: 0.8889 - val_loss: 2.0780 - val_accuracy: 0.1867
# Epoch 115/300
# 2/2 [==============================] - 1s 987ms/step - loss: 0.7780 - accuracy: 0.7778 - val_loss: 2.1008 - val_accuracy: 0.1871
# Epoch 116/300
# 2/2 [==============================] - 1s 937ms/step - loss: 0.6278 - accuracy: 0.7778 - val_loss: 2.1136 - val_accuracy: 0.1950
# Epoch 117/300
# 2/2 [==============================] - 1s 979ms/step - loss: 0.6018 - accuracy: 0.7222 - val_loss: 2.1692 - val_accuracy: 0.1929
# Epoch 118/300
# 2/2 [==============================] - 1s 1s/step - loss: 0.7437 - accuracy: 0.7222 - val_loss: 2.2090 - val_accuracy: 0.1904
# Epoch 119/300
# 2/2 [==============================] - 1s 1s/step - loss: 0.6138 - accuracy: 0.7778 - val_loss: 2.1306 - val_accuracy: 0.1996
# Epoch 120/300
# 2/2 [==============================] - 1s 1s/step - loss: 0.5700 - accuracy: 0.7222 - val_loss: 2.0781 - val_accuracy: 0.2121
# Epoch 121/300
# 2/2 [==============================] - 1s 1s/step - loss: 0.5259 - accuracy: 0.8333 - val_loss: 2.0188 - val_accuracy: 0.2350
# Epoch 122/300
# 2/2 [==============================] - 1s 1s/step - loss: 1.0786 - accuracy: 0.5556 - val_loss: 1.9342 - val_accuracy: 0.2438
# Epoch 123/300
# 2/2 [==============================] - 1s 1s/step - loss: 0.6579 - accuracy: 0.8333 - val_loss: 1.9200 - val_accuracy: 0.2479
# Epoch 124/300
# 2/2 [==============================] - 1s 1s/step - loss: 0.5549 - accuracy: 0.7778 - val_loss: 1.9735 - val_accuracy: 0.2408
# Epoch 125/300
# 2/2 [==============================] - 1s 943ms/step - loss: 0.6715 - accuracy: 0.6667 - val_loss: 2.0983 - val_accuracy: 0.2342
# Epoch 126/300
# 2/2 [==============================] - 1s 985ms/step - loss: 0.5682 - accuracy: 0.8333 - val_loss: 2.2111 - val_accuracy: 0.2308
# Epoch 127/300
# 2/2 [==============================] - 1s 958ms/step - loss: 0.7020 - accuracy: 0.7778 - val_loss: 2.2251 - val_accuracy: 0.2250
# Epoch 128/300
# 2/2 [==============================] - 1s 945ms/step - loss: 0.3763 - accuracy: 0.8889 - val_loss: 2.2671 - val_accuracy: 0.2117
# Epoch 129/300
# 2/2 [==============================] - 1s 966ms/step - loss: 0.9344 - accuracy: 0.7778 - val_loss: 2.1547 - val_accuracy: 0.2121
# Epoch 130/300
# 2/2 [==============================] - 1s 964ms/step - loss: 0.3558 - accuracy: 0.9444 - val_loss: 2.0375 - val_accuracy: 0.2188
# Epoch 131/300
# 2/2 [==============================] - 1s 963ms/step - loss: 0.4768 - accuracy: 0.8889 - val_loss: 1.9673 - val_accuracy: 0.2479
# Epoch 132/300
# 2/2 [==============================] - 1s 960ms/step - loss: 0.5524 - accuracy: 0.8889 - val_loss: 2.0818 - val_accuracy: 0.2421
# Epoch 133/300
# 2/2 [==============================] - 1s 958ms/step - loss: 0.9578 - accuracy: 0.7222 - val_loss: 2.2269 - val_accuracy: 0.2346
# Epoch 134/300
# 2/2 [==============================] - 1s 944ms/step - loss: 0.1899 - accuracy: 1.0000 - val_loss: 2.2869 - val_accuracy: 0.2412
# Epoch 135/300
# 2/2 [==============================] - 1s 929ms/step - loss: 0.2784 - accuracy: 0.8889 - val_loss: 2.2420 - val_accuracy: 0.2554
# Epoch 136/300
# 2/2 [==============================] - 1s 924ms/step - loss: 0.1601 - accuracy: 1.0000 - val_loss: 2.2085 - val_accuracy: 0.2587
# Epoch 137/300
# 2/2 [==============================] - 1s 945ms/step - loss: 0.3744 - accuracy: 0.8889 - val_loss: 2.1232 - val_accuracy: 0.2725
# Epoch 138/300
# 2/2 [==============================] - 1s 930ms/step - loss: 0.2232 - accuracy: 0.9444 - val_loss: 2.0569 - val_accuracy: 0.2708
# Epoch 139/300
# 2/2 [==============================] - 1s 976ms/step - loss: 0.3256 - accuracy: 0.9444 - val_loss: 2.0345 - val_accuracy: 0.2663
# Epoch 140/300
# 2/2 [==============================] - 1s 971ms/step - loss: 0.3685 - accuracy: 0.8333 - val_loss: 2.0811 - val_accuracy: 0.2412
# Epoch 141/300
# 2/2 [==============================] - 1s 952ms/step - loss: 0.4684 - accuracy: 0.8333 - val_loss: 2.1288 - val_accuracy: 0.2329
# Epoch 142/300
# 2/2 [==============================] - 1s 943ms/step - loss: 0.7937 - accuracy: 0.7778 - val_loss: 2.1764 - val_accuracy: 0.2288
# Epoch 143/300
# 2/2 [==============================] - 1s 956ms/step - loss: 0.6484 - accuracy: 0.8333 - val_loss: 2.3748 - val_accuracy: 0.2333
# Epoch 144/300
# 2/2 [==============================] - 1s 959ms/step - loss: 0.8147 - accuracy: 0.6667 - val_loss: 2.3062 - val_accuracy: 0.2392
# Epoch 145/300
# 2/2 [==============================] - 1s 972ms/step - loss: 0.4564 - accuracy: 0.8889 - val_loss: 2.1929 - val_accuracy: 0.2400
# Epoch 146/300
# 2/2 [==============================] - 1s 967ms/step - loss: 0.6754 - accuracy: 0.7778 - val_loss: 2.0881 - val_accuracy: 0.2554
# Epoch 147/300
# 2/2 [==============================] - 1s 968ms/step - loss: 0.4810 - accuracy: 0.7222 - val_loss: 2.0723 - val_accuracy: 0.2612
# Epoch 148/300
# 2/2 [==============================] - 1s 973ms/step - loss: 0.9648 - accuracy: 0.7222 - val_loss: 2.0591 - val_accuracy: 0.2667
# Epoch 149/300
# 2/2 [==============================] - 1s 963ms/step - loss: 0.4235 - accuracy: 0.8889 - val_loss: 2.0078 - val_accuracy: 0.2596
# Epoch 150/300
# 2/2 [==============================] - 1s 956ms/step - loss: 0.3290 - accuracy: 0.8889 - val_loss: 2.0269 - val_accuracy: 0.2417
# Epoch 151/300
# 2/2 [==============================] - 1s 993ms/step - loss: 0.6889 - accuracy: 0.8333 - val_loss: 2.0542 - val_accuracy: 0.2421
# Epoch 152/300
# 2/2 [==============================] - 1s 980ms/step - loss: 0.4347 - accuracy: 0.8333 - val_loss: 2.0795 - val_accuracy: 0.2404
# Epoch 153/300
# 2/2 [==============================] - 1s 957ms/step - loss: 1.0594 - accuracy: 0.6111 - val_loss: 2.0477 - val_accuracy: 0.2417
# Epoch 154/300
# 2/2 [==============================] - 1s 945ms/step - loss: 0.3225 - accuracy: 0.8889 - val_loss: 1.9827 - val_accuracy: 0.2654
# Epoch 155/300
# 2/2 [==============================] - 1s 946ms/step - loss: 0.5015 - accuracy: 0.7778 - val_loss: 2.0107 - val_accuracy: 0.2896
# Epoch 156/300
# 2/2 [==============================] - 1s 948ms/step - loss: 0.4749 - accuracy: 0.7778 - val_loss: 2.2471 - val_accuracy: 0.2475
# Epoch 157/300
# 2/2 [==============================] - 1s 970ms/step - loss: 1.1780 - accuracy: 0.6111 - val_loss: 2.2572 - val_accuracy: 0.2479
# Epoch 158/300
# 2/2 [==============================] - 1s 985ms/step - loss: 0.7960 - accuracy: 0.7778 - val_loss: 2.1323 - val_accuracy: 0.2767
# Epoch 159/300
# 2/2 [==============================] - 1s 962ms/step - loss: 0.0723 - accuracy: 1.0000 - val_loss: 2.1006 - val_accuracy: 0.2733
# Epoch 160/300
# 2/2 [==============================] - 1s 958ms/step - loss: 0.4421 - accuracy: 0.7778 - val_loss: 2.1775 - val_accuracy: 0.2546
# Epoch 161/300
# 2/2 [==============================] - 1s 963ms/step - loss: 0.4236 - accuracy: 0.8333 - val_loss: 2.4326 - val_accuracy: 0.2267
# Epoch 162/300
# 2/2 [==============================] - 1s 970ms/step - loss: 0.5828 - accuracy: 0.8333 - val_loss: 2.6337 - val_accuracy: 0.2154
# Epoch 163/300
# 2/2 [==============================] - 1s 987ms/step - loss: 0.8785 - accuracy: 0.6667 - val_loss: 2.3527 - val_accuracy: 0.2279
# Epoch 164/300
# 2/2 [==============================] - 1s 943ms/step - loss: 0.6460 - accuracy: 0.8333 - val_loss: 1.9999 - val_accuracy: 0.2729
# Epoch 165/300
# 2/2 [==============================] - 1s 941ms/step - loss: 0.2604 - accuracy: 0.8889 - val_loss: 2.0968 - val_accuracy: 0.2667
# Epoch 166/300
# 2/2 [==============================] - 1s 958ms/step - loss: 0.8871 - accuracy: 0.7222 - val_loss: 2.1547 - val_accuracy: 0.2533
# Epoch 167/300
# 2/2 [==============================] - 1s 956ms/step - loss: 0.7360 - accuracy: 0.7778 - val_loss: 2.2756 - val_accuracy: 0.2212
# Epoch 168/300
# 2/2 [==============================] - 1s 979ms/step - loss: 0.4358 - accuracy: 0.8889 - val_loss: 2.4202 - val_accuracy: 0.1975
# Epoch 169/300
# 2/2 [==============================] - 1s 974ms/step - loss: 1.5325 - accuracy: 0.5556 - val_loss: 2.2637 - val_accuracy: 0.2163
# Epoch 170/300
# 2/2 [==============================] - 1s 975ms/step - loss: 0.7374 - accuracy: 0.7222 - val_loss: 2.0077 - val_accuracy: 0.2767
# Epoch 171/300
# 2/2 [==============================] - 1s 958ms/step - loss: 0.5851 - accuracy: 0.8333 - val_loss: 1.9736 - val_accuracy: 0.2821
# Epoch 172/300
# 2/2 [==============================] - 1s 969ms/step - loss: 0.7270 - accuracy: 0.7778 - val_loss: 1.9845 - val_accuracy: 0.2625
# Epoch 173/300
# 2/2 [==============================] - 1s 967ms/step - loss: 0.5426 - accuracy: 0.8889 - val_loss: 2.0562 - val_accuracy: 0.2217
# Epoch 174/300
# 2/2 [==============================] - 1s 961ms/step - loss: 0.7614 - accuracy: 0.7222 - val_loss: 2.0604 - val_accuracy: 0.2046
# Epoch 175/300
# 2/2 [==============================] - 1s 968ms/step - loss: 0.6865 - accuracy: 0.7778 - val_loss: 1.9929 - val_accuracy: 0.2108
# Epoch 176/300
# 2/2 [==============================] - 1s 965ms/step - loss: 0.5418 - accuracy: 0.8889 - val_loss: 1.9498 - val_accuracy: 0.2258
# Epoch 177/300
# 2/2 [==============================] - 1s 978ms/step - loss: 0.4971 - accuracy: 0.8889 - val_loss: 1.8960 - val_accuracy: 0.2379
# Epoch 178/300
# 2/2 [==============================] - 1s 957ms/step - loss: 0.6843 - accuracy: 0.7778 - val_loss: 1.8650 - val_accuracy: 0.2467
# Epoch 179/300
# 2/2 [==============================] - 1s 954ms/step - loss: 0.5245 - accuracy: 0.8889 - val_loss: 1.8485 - val_accuracy: 0.2629
# Epoch 180/300
# 2/2 [==============================] - 1s 1s/step - loss: 0.4445 - accuracy: 0.8889 - val_loss: 1.8293 - val_accuracy: 0.2946
# Epoch 181/300
# 2/2 [==============================] - 1s 956ms/step - loss: 0.5324 - accuracy: 0.8889 - val_loss: 1.8472 - val_accuracy: 0.3150
# Epoch 182/300
# 2/2 [==============================] - 1s 973ms/step - loss: 0.5335 - accuracy: 0.7222 - val_loss: 1.9313 - val_accuracy: 0.3117
# Epoch 183/300
# 2/2 [==============================] - 1s 977ms/step - loss: 0.4069 - accuracy: 0.8333 - val_loss: 2.1365 - val_accuracy: 0.2800
# Epoch 184/300
# 2/2 [==============================] - 1s 984ms/step - loss: 0.4302 - accuracy: 0.8889 - val_loss: 2.4099 - val_accuracy: 0.2562
# Epoch 185/300
# 2/2 [==============================] - 1s 959ms/step - loss: 0.7455 - accuracy: 0.7778 - val_loss: 2.5306 - val_accuracy: 0.2329
# Epoch 186/300
# 2/2 [==============================] - 1s 967ms/step - loss: 0.3663 - accuracy: 0.8889 - val_loss: 2.3808 - val_accuracy: 0.2212
# Epoch 187/300
# 2/2 [==============================] - 1s 942ms/step - loss: 0.4363 - accuracy: 0.8333 - val_loss: 2.1363 - val_accuracy: 0.2596
# Epoch 188/300
# 2/2 [==============================] - 1s 940ms/step - loss: 0.6170 - accuracy: 0.8889 - val_loss: 1.9405 - val_accuracy: 0.3021
# Epoch 189/300
# 2/2 [==============================] - 1s 953ms/step - loss: 0.5128 - accuracy: 0.7778 - val_loss: 2.0144 - val_accuracy: 0.2983
# Epoch 190/300
# 2/2 [==============================] - 1s 961ms/step - loss: 0.5941 - accuracy: 0.7778 - val_loss: 2.0731 - val_accuracy: 0.2971
# Epoch 191/300
# 2/2 [==============================] - 1s 964ms/step - loss: 0.4479 - accuracy: 0.8333 - val_loss: 2.0365 - val_accuracy: 0.3171
# Epoch 192/300
# 2/2 [==============================] - 1s 980ms/step - loss: 0.4143 - accuracy: 0.8889 - val_loss: 2.0458 - val_accuracy: 0.3063
# Epoch 193/300
# 2/2 [==============================] - 1s 946ms/step - loss: 0.1748 - accuracy: 1.0000 - val_loss: 2.2173 - val_accuracy: 0.2788
# Epoch 194/300
# 2/2 [==============================] - 1s 947ms/step - loss: 0.3692 - accuracy: 0.8333 - val_loss: 2.3959 - val_accuracy: 0.2596
# Epoch 195/300
# 2/2 [==============================] - 1s 971ms/step - loss: 0.8492 - accuracy: 0.6111 - val_loss: 2.3016 - val_accuracy: 0.2704
# Epoch 196/300
# 2/2 [==============================] - 1s 962ms/step - loss: 0.3859 - accuracy: 0.9444 - val_loss: 2.2257 - val_accuracy: 0.2796
# Epoch 197/300
# 2/2 [==============================] - 1s 947ms/step - loss: 0.7263 - accuracy: 0.7222 - val_loss: 2.1193 - val_accuracy: 0.2788
# Epoch 198/300
# 2/2 [==============================] - 1s 982ms/step - loss: 0.2388 - accuracy: 0.8889 - val_loss: 2.0922 - val_accuracy: 0.2829
# Epoch 199/300
# 2/2 [==============================] - 1s 936ms/step - loss: 0.4233 - accuracy: 0.8889 - val_loss: 2.2285 - val_accuracy: 0.2788
# Epoch 200/300
# 2/2 [==============================] - 1s 949ms/step - loss: 0.5061 - accuracy: 0.7778 - val_loss: 2.2930 - val_accuracy: 0.2642
# Epoch 201/300
# 2/2 [==============================] - 1s 978ms/step - loss: 0.5190 - accuracy: 0.8333 - val_loss: 2.2605 - val_accuracy: 0.2592
# Epoch 202/300
# 2/2 [==============================] - 1s 963ms/step - loss: 0.4239 - accuracy: 0.8333 - val_loss: 2.2059 - val_accuracy: 0.2621
# Epoch 203/300
# 2/2 [==============================] - 1s 980ms/step - loss: 0.3181 - accuracy: 0.8889 - val_loss: 2.1744 - val_accuracy: 0.2525
# Epoch 204/300
# 2/2 [==============================] - 1s 972ms/step - loss: 0.5261 - accuracy: 0.8333 - val_loss: 2.1659 - val_accuracy: 0.2546
# Epoch 205/300
# 2/2 [==============================] - 1s 940ms/step - loss: 0.5539 - accuracy: 0.8333 - val_loss: 2.1084 - val_accuracy: 0.2704
# Epoch 206/300
# 2/2 [==============================] - 1s 964ms/step - loss: 0.4014 - accuracy: 0.9444 - val_loss: 2.0312 - val_accuracy: 0.3050
# Epoch 207/300
# 2/2 [==============================] - 1s 964ms/step - loss: 0.2880 - accuracy: 0.8889 - val_loss: 2.0053 - val_accuracy: 0.3146
# Epoch 208/300
# 2/2 [==============================] - 1s 963ms/step - loss: 0.1493 - accuracy: 0.9444 - val_loss: 1.9967 - val_accuracy: 0.3167
# Epoch 209/300
# 2/2 [==============================] - 1s 957ms/step - loss: 0.4690 - accuracy: 0.7778 - val_loss: 2.0679 - val_accuracy: 0.3038
# Epoch 210/300
# 2/2 [==============================] - 1s 924ms/step - loss: 0.6071 - accuracy: 0.7222 - val_loss: 2.4024 - val_accuracy: 0.2342
# Epoch 211/300
# 2/2 [==============================] - 1s 955ms/step - loss: 0.2899 - accuracy: 0.8333 - val_loss: 2.8055 - val_accuracy: 0.2075
# Epoch 212/300
# 2/2 [==============================] - 1s 928ms/step - loss: 0.3897 - accuracy: 0.7778 - val_loss: 2.9406 - val_accuracy: 0.2037
# Epoch 213/300
# 2/2 [==============================] - 1s 944ms/step - loss: 0.6798 - accuracy: 0.8333 - val_loss: 2.4957 - val_accuracy: 0.2267
# Epoch 214/300
# 2/2 [==============================] - 1s 951ms/step - loss: 0.6514 - accuracy: 0.6667 - val_loss: 2.1802 - val_accuracy: 0.2796
# Epoch 215/300
# 2/2 [==============================] - 1s 951ms/step - loss: 0.2152 - accuracy: 1.0000 - val_loss: 2.1462 - val_accuracy: 0.3046
# Epoch 216/300
# 2/2 [==============================] - 1s 961ms/step - loss: 0.4223 - accuracy: 0.8889 - val_loss: 2.1557 - val_accuracy: 0.2988
# Epoch 217/300
# 2/2 [==============================] - 1s 926ms/step - loss: 0.0237 - accuracy: 1.0000 - val_loss: 2.1605 - val_accuracy: 0.3000
# Epoch 218/300
# 2/2 [==============================] - 1s 936ms/step - loss: 0.0512 - accuracy: 1.0000 - val_loss: 2.1682 - val_accuracy: 0.3042
# Epoch 219/300
# 2/2 [==============================] - 1s 940ms/step - loss: 0.5766 - accuracy: 0.7778 - val_loss: 2.1131 - val_accuracy: 0.2988
# Epoch 220/300
# 2/2 [==============================] - 1s 951ms/step - loss: 0.5241 - accuracy: 0.8333 - val_loss: 2.1108 - val_accuracy: 0.2954
# Epoch 221/300
# 2/2 [==============================] - 1s 975ms/step - loss: 0.3428 - accuracy: 0.8889 - val_loss: 2.1390 - val_accuracy: 0.2871
# Epoch 222/300
# 2/2 [==============================] - 1s 941ms/step - loss: 0.5614 - accuracy: 0.7778 - val_loss: 2.1047 - val_accuracy: 0.2875
# Epoch 223/300
# 2/2 [==============================] - 1s 957ms/step - loss: 0.8517 - accuracy: 0.6667 - val_loss: 2.1152 - val_accuracy: 0.2492
# Epoch 224/300
# 2/2 [==============================] - 1s 969ms/step - loss: 0.3105 - accuracy: 0.8889 - val_loss: 2.2899 - val_accuracy: 0.2325
# Epoch 225/300
# 2/2 [==============================] - 1s 958ms/step - loss: 0.2794 - accuracy: 0.8889 - val_loss: 2.5396 - val_accuracy: 0.2125
# Epoch 226/300
# 2/2 [==============================] - 1s 972ms/step - loss: 0.1384 - accuracy: 1.0000 - val_loss: 2.6201 - val_accuracy: 0.2025
# Epoch 227/300
# 2/2 [==============================] - 1s 971ms/step - loss: 0.6959 - accuracy: 0.8333 - val_loss: 2.3277 - val_accuracy: 0.2133
# Epoch 228/300
# 2/2 [==============================] - 1s 961ms/step - loss: 0.2561 - accuracy: 0.8889 - val_loss: 2.0981 - val_accuracy: 0.2412
# Epoch 229/300
# 2/2 [==============================] - 1s 952ms/step - loss: 0.3567 - accuracy: 0.9444 - val_loss: 2.0062 - val_accuracy: 0.2558
# Epoch 230/300
# 2/2 [==============================] - 1s 951ms/step - loss: 0.2808 - accuracy: 0.9444 - val_loss: 2.0059 - val_accuracy: 0.2612
# Epoch 231/300
# 2/2 [==============================] - 1s 959ms/step - loss: 0.2077 - accuracy: 0.9444 - val_loss: 2.0520 - val_accuracy: 0.2625
# Epoch 232/300
# 2/2 [==============================] - 1s 948ms/step - loss: 0.2361 - accuracy: 0.9444 - val_loss: 2.1878 - val_accuracy: 0.2408
# Epoch 233/300
# 2/2 [==============================] - 1s 969ms/step - loss: 0.5803 - accuracy: 0.8889 - val_loss: 2.4763 - val_accuracy: 0.2254
# Epoch 234/300
# 2/2 [==============================] - 1s 950ms/step - loss: 0.0313 - accuracy: 1.0000 - val_loss: 2.7379 - val_accuracy: 0.2271
# Epoch 235/300
# 2/2 [==============================] - 1s 938ms/step - loss: 0.4096 - accuracy: 0.8889 - val_loss: 2.8161 - val_accuracy: 0.2233
# Epoch 236/300
# 2/2 [==============================] - 1s 958ms/step - loss: 0.4795 - accuracy: 0.8889 - val_loss: 2.5124 - val_accuracy: 0.2283
# Epoch 237/300
# 2/2 [==============================] - 1s 948ms/step - loss: 0.1910 - accuracy: 0.8889 - val_loss: 2.3841 - val_accuracy: 0.2371
# Epoch 238/300
# 2/2 [==============================] - 1s 958ms/step - loss: 0.2044 - accuracy: 0.9444 - val_loss: 2.3267 - val_accuracy: 0.2308
# Epoch 239/300
# 2/2 [==============================] - 1s 974ms/step - loss: 0.2867 - accuracy: 0.8889 - val_loss: 2.1919 - val_accuracy: 0.2442
# Epoch 240/300
# 2/2 [==============================] - 1s 975ms/step - loss: 0.3990 - accuracy: 0.7778 - val_loss: 2.1681 - val_accuracy: 0.2608
# Epoch 241/300
# 2/2 [==============================] - 1s 971ms/step - loss: 0.6132 - accuracy: 0.7222 - val_loss: 2.2513 - val_accuracy: 0.2988
# Epoch 242/300
# 2/2 [==============================] - 1s 958ms/step - loss: 0.2290 - accuracy: 0.8889 - val_loss: 2.4519 - val_accuracy: 0.3004
# Epoch 243/300
# 2/2 [==============================] - 1s 962ms/step - loss: 0.4075 - accuracy: 0.7778 - val_loss: 2.6312 - val_accuracy: 0.2783
# Epoch 244/300
# 2/2 [==============================] - 1s 949ms/step - loss: 0.6217 - accuracy: 0.8889 - val_loss: 2.6759 - val_accuracy: 0.2642
# Epoch 245/300
# 2/2 [==============================] - 1s 936ms/step - loss: 0.4058 - accuracy: 0.8333 - val_loss: 2.6138 - val_accuracy: 0.2633
# Epoch 246/300
# 2/2 [==============================] - 1s 932ms/step - loss: 0.2436 - accuracy: 0.9444 - val_loss: 2.4894 - val_accuracy: 0.2571
# Epoch 247/300
# 2/2 [==============================] - 1s 945ms/step - loss: 0.9887 - accuracy: 0.6111 - val_loss: 2.2180 - val_accuracy: 0.2950
# Epoch 248/300
# 2/2 [==============================] - 1s 960ms/step - loss: 0.4798 - accuracy: 0.7778 - val_loss: 2.1227 - val_accuracy: 0.2983
# Epoch 249/300
# 2/2 [==============================] - 1s 934ms/step - loss: 0.1354 - accuracy: 1.0000 - val_loss: 2.0892 - val_accuracy: 0.3071
# Epoch 250/300
# 2/2 [==============================] - 1s 928ms/step - loss: 0.2017 - accuracy: 0.8889 - val_loss: 2.0658 - val_accuracy: 0.3021
# Epoch 251/300
# 2/2 [==============================] - 1s 948ms/step - loss: 0.4095 - accuracy: 0.8889 - val_loss: 2.0750 - val_accuracy: 0.2908
# Epoch 252/300
# 2/2 [==============================] - 1s 921ms/step - loss: 0.2021 - accuracy: 0.9444 - val_loss: 2.1564 - val_accuracy: 0.2821
# Epoch 253/300
# 2/2 [==============================] - 1s 938ms/step - loss: 0.2387 - accuracy: 0.8889 - val_loss: 2.2714 - val_accuracy: 0.2775
# Epoch 254/300
# 2/2 [==============================] - 1s 989ms/step - loss: 0.3285 - accuracy: 0.8333 - val_loss: 2.3345 - val_accuracy: 0.2750
# Epoch 255/300
# 2/2 [==============================] - 1s 979ms/step - loss: 0.4510 - accuracy: 0.8333 - val_loss: 2.2701 - val_accuracy: 0.2792
# Epoch 256/300
# 2/2 [==============================] - 1s 927ms/step - loss: 0.1076 - accuracy: 1.0000 - val_loss: 2.2103 - val_accuracy: 0.2821
# Epoch 257/300
# 2/2 [==============================] - 1s 934ms/step - loss: 0.5338 - accuracy: 0.8889 - val_loss: 2.0847 - val_accuracy: 0.2871
# Epoch 258/300
# 2/2 [==============================] - 1s 962ms/step - loss: 0.2010 - accuracy: 0.8889 - val_loss: 2.2205 - val_accuracy: 0.2696
# Epoch 259/300
# 2/2 [==============================] - 1s 947ms/step - loss: 0.5700 - accuracy: 0.8333 - val_loss: 2.3838 - val_accuracy: 0.2471
# Epoch 260/300
# 2/2 [==============================] - 1s 927ms/step - loss: 0.2236 - accuracy: 0.9444 - val_loss: 2.5470 - val_accuracy: 0.2258
# Epoch 261/300
# 2/2 [==============================] - 1s 977ms/step - loss: 0.1522 - accuracy: 0.9444 - val_loss: 2.5104 - val_accuracy: 0.2288
# Epoch 262/300
# 2/2 [==============================] - 1s 965ms/step - loss: 0.5528 - accuracy: 0.8333 - val_loss: 2.3961 - val_accuracy: 0.2504
# Epoch 263/300
# 2/2 [==============================] - 1s 967ms/step - loss: 0.0515 - accuracy: 0.9444 - val_loss: 2.5304 - val_accuracy: 0.2408
# Epoch 264/300
# 2/2 [==============================] - 1s 970ms/step - loss: 0.4225 - accuracy: 0.7778 - val_loss: 2.8944 - val_accuracy: 0.2271
# Epoch 265/300
# 2/2 [==============================] - 1s 974ms/step - loss: 0.1935 - accuracy: 0.9444 - val_loss: 3.1104 - val_accuracy: 0.2175
# Epoch 266/300
# 2/2 [==============================] - 1s 970ms/step - loss: 0.2893 - accuracy: 0.8889 - val_loss: 2.9149 - val_accuracy: 0.2092
# Epoch 267/300
# 2/2 [==============================] - 1s 989ms/step - loss: 0.0909 - accuracy: 0.9444 - val_loss: 2.6681 - val_accuracy: 0.2233
# Epoch 268/300
# 2/2 [==============================] - 1s 985ms/step - loss: 0.3269 - accuracy: 0.8333 - val_loss: 2.3307 - val_accuracy: 0.2550
# Epoch 269/300
# 2/2 [==============================] - 1s 996ms/step - loss: 0.2394 - accuracy: 0.9444 - val_loss: 2.2079 - val_accuracy: 0.2771
# Epoch 270/300
# 2/2 [==============================] - 1s 973ms/step - loss: 0.4035 - accuracy: 0.8333 - val_loss: 2.2488 - val_accuracy: 0.2775
# Epoch 271/300
# 2/2 [==============================] - 1s 972ms/step - loss: 0.3664 - accuracy: 0.8333 - val_loss: 2.2897 - val_accuracy: 0.2883
# Epoch 272/300
# 2/2 [==============================] - 1s 975ms/step - loss: 0.1622 - accuracy: 0.8889 - val_loss: 2.2739 - val_accuracy: 0.3000
# Epoch 273/300
# 2/2 [==============================] - 1s 981ms/step - loss: 0.3684 - accuracy: 0.8333 - val_loss: 2.2653 - val_accuracy: 0.2867
# Epoch 274/300
# 2/2 [==============================] - 1s 974ms/step - loss: 0.4571 - accuracy: 0.8889 - val_loss: 2.3368 - val_accuracy: 0.2854
# Epoch 275/300
# 2/2 [==============================] - 1s 972ms/step - loss: 0.6578 - accuracy: 0.7778 - val_loss: 2.3776 - val_accuracy: 0.2800
# Epoch 276/300
# 2/2 [==============================] - 1s 970ms/step - loss: 0.5672 - accuracy: 0.7778 - val_loss: 2.3330 - val_accuracy: 0.2808
# Epoch 277/300
# 2/2 [==============================] - 1s 986ms/step - loss: 0.1601 - accuracy: 1.0000 - val_loss: 2.2439 - val_accuracy: 0.2788
# Epoch 278/300
# 2/2 [==============================] - 1s 973ms/step - loss: 0.1633 - accuracy: 0.9444 - val_loss: 2.1804 - val_accuracy: 0.2887
# Epoch 279/300
# 2/2 [==============================] - 1s 959ms/step - loss: 0.3103 - accuracy: 0.8889 - val_loss: 2.1615 - val_accuracy: 0.3038
# Epoch 280/300
# 2/2 [==============================] - 1s 972ms/step - loss: 0.8449 - accuracy: 0.7222 - val_loss: 2.1567 - val_accuracy: 0.3033
# Epoch 281/300
# 2/2 [==============================] - 1s 966ms/step - loss: 0.1567 - accuracy: 0.9444 - val_loss: 2.1499 - val_accuracy: 0.2808
# Epoch 282/300
# 2/2 [==============================] - 1s 966ms/step - loss: 0.2322 - accuracy: 0.9444 - val_loss: 2.1737 - val_accuracy: 0.2704
# Epoch 283/300
# 2/2 [==============================] - 1s 969ms/step - loss: 0.4641 - accuracy: 0.9444 - val_loss: 2.2002 - val_accuracy: 0.2525
# Epoch 284/300
# 2/2 [==============================] - 1s 991ms/step - loss: 0.3640 - accuracy: 0.8333 - val_loss: 2.2166 - val_accuracy: 0.2475
# Epoch 285/300
# 2/2 [==============================] - 1s 967ms/step - loss: 0.0628 - accuracy: 1.0000 - val_loss: 2.2121 - val_accuracy: 0.2367
# Epoch 286/300
# 2/2 [==============================] - 1s 970ms/step - loss: 0.4133 - accuracy: 0.8333 - val_loss: 2.2402 - val_accuracy: 0.2308
# Epoch 287/300
# 2/2 [==============================] - 1s 964ms/step - loss: 0.2685 - accuracy: 0.8889 - val_loss: 2.2491 - val_accuracy: 0.2208
# Epoch 288/300
# 2/2 [==============================] - 1s 956ms/step - loss: 0.4870 - accuracy: 0.8333 - val_loss: 2.1672 - val_accuracy: 0.2404
# Epoch 289/300
# 2/2 [==============================] - 1s 978ms/step - loss: 0.5296 - accuracy: 0.8889 - val_loss: 2.2112 - val_accuracy: 0.2383
# Epoch 290/300
# 2/2 [==============================] - 1s 1s/step - loss: 0.7372 - accuracy: 0.7222 - val_loss: 2.1989 - val_accuracy: 0.2650
# Epoch 291/300
# 2/2 [==============================] - 1s 1s/step - loss: 0.1025 - accuracy: 0.9444 - val_loss: 2.2241 - val_accuracy: 0.2733
# Epoch 292/300
# 2/2 [==============================] - 1s 962ms/step - loss: 0.5274 - accuracy: 0.8333 - val_loss: 2.2173 - val_accuracy: 0.2763
# Epoch 293/300
# 2/2 [==============================] - 1s 973ms/step - loss: 0.1648 - accuracy: 0.9444 - val_loss: 2.2781 - val_accuracy: 0.2675
# Epoch 294/300
# 2/2 [==============================] - 1s 961ms/step - loss: 0.1541 - accuracy: 0.9444 - val_loss: 2.3718 - val_accuracy: 0.2429
# Epoch 295/300
# 2/2 [==============================] - 1s 938ms/step - loss: 0.6046 - accuracy: 0.7778 - val_loss: 2.4712 - val_accuracy: 0.2313
# Epoch 296/300
# 2/2 [==============================] - 1s 1s/step - loss: 0.5187 - accuracy: 0.7778 - val_loss: 2.4935 - val_accuracy: 0.2421
# Epoch 297/300
# 2/2 [==============================] - 1s 971ms/step - loss: 0.1107 - accuracy: 1.0000 - val_loss: 2.5092 - val_accuracy: 0.2508
# Epoch 298/300
# 2/2 [==============================] - 1s 979ms/step - loss: 0.3434 - accuracy: 0.9444 - val_loss: 2.4236 - val_accuracy: 0.2692
# Epoch 299/300
# 2/2 [==============================] - 1s 976ms/step - loss: 0.3771 - accuracy: 0.8333 - val_loss: 2.3195 - val_accuracy: 0.2954
# Epoch 300/300
# 2/2 [==============================] - 1s 980ms/step - loss: 0.5814 - accuracy: 0.8333 - val_loss: 2.2795 - val_accuracy: 0.3067
# Epoch 00191: early stopping and save the model

# %%
evaluate1 = model.evaluate(x_test, keras.utils.to_categorical(y_test,6))
evaluate1
# Out:
# 675/675 [==============================] - 3s 4ms/step - loss: 2.0385 - accuracy: 0.3147
# [2.0385258197784424, 0.3147222101688385]

# %%
model_train = keras.models.load_model('100_samples_seed_fix.h5')
evaluate2 = model_train.evaluate(x_test, keras.utils.to_categorical(y_test,6))
evaluate2
# Out:
# 675/675 [==============================] - 3s 4ms/step - loss: 2.0385 - accuracy: 0.3147
# [2.0385258197784424, 0.3147222101688385]
