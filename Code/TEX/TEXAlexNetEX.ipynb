# %%
#unzip NEU dataset
# !unzip '/content/drive/MyDrive/TEX/TEX_validation.zip' -d '/content'
# !unzip '/content/drive/MyDrive/TEX/TEX_test.zip' -d '/content'
# !unzip '/content/drive/MyDrive/TEX/100_samples.zip' -d '/content'
# !unzip '/content/drive/MyDrive/TEX/50_samples.zip' -d '/content'
# !unzip '/content/drive/MyDrive/TEX/20_samples.zip' -d '/content'
# !unzip '/content/drive/MyDrive/TEX/10_samples.zip' -d '/content'
# !unzip '/content/drive/MyDrive/TEX/5_samples.zip' -d '/content'
# !unzip '/content/drive/MyDrive/TEX/3_samples.zip' -d '/content'
# Out:
# "\n!unzip '/content/drive/MyDrive/TEX/TEX_validation.zip' -d '/content'\n!unzip '/content/drive/MyDrive/TEX/TEX_test.zip' -d '/content'\n!unzip '/content/drive/MyDrive/TEX/100_samples.zip' -d '/content'\n!unzip '/content/drive/MyDrive/TEX/50_samples.zip' -d '/content'\n!unzip '/content/drive/MyDrive/TEX/20_samples.zip' -d '/content'\n!unzip '/content/drive/MyDrive/TEX/10_samples.zip' -d '/content'\n!unzip '/content/drive/MyDrive/TEX/5_samples.zip' -d '/content'\n!unzip '/content/drive/MyDrive/TEX/3_samples.zip' -d '/content'\n"

# %%
import random
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import tensorflow.keras.backend as K
from tensorflow import keras
from sklearn import model_selection
from sklearn.metrics import classification_report
import imgaug.augmenters as iaa
import imgaug as ia
import os

# %%
ia.seed(1)
def Data_Aug(samples):
    randomaug = iaa.Sometimes(
        0.5,
        iaa.OneOf([
            iaa.Sequential([
                iaa.AllChannelsCLAHE(clip_limit=(1, 10)),
                iaa.Affine(rotate=(-5, 5))
            ]),
            iaa.Sequential([
                iaa.Affine(translate_percent={
                    "x": (-0.2, 0.2),
                    "y": (-0.2, 0.2)
                }),
                iaa.Multiply((0.7, 1.3)),
                iaa.AdditiveLaplaceNoise(scale=0.03 * 255, per_channel=True),
                iaa.Fliplr(0.3),
                iaa.Flipud(0.3)
            ]),
            iaa.Sequential([
                iaa.Affine(rotate=(-10, 10)),
                iaa.Multiply((0.7, 1.3)),
                iaa.AdditiveLaplaceNoise(scale=0.03 * 255, per_channel=True),
                iaa.Fliplr(0.3),
                iaa.Flipud(0.3)
            ]),
            iaa.Sequential([
                iaa.PerspectiveTransform(scale=(0, 0.15)),
                iaa.Multiply((0.7, 1.3)),
                iaa.AdditiveLaplaceNoise(scale=0.03 * 255, per_channel=True),
                iaa.Fliplr(0.3),
                iaa.Flipud(0.3)
            ])
        ]))


    return randomaug.augment_images(samples)

def resize_images(imgs, hight, width):
    seq = iaa.Resize({"height": hight, "width": width})
    aug = seq.augment_images(imgs)
    return aug

# %%
#load NEU dataset
def load_data(dir_path, labels_dict):
  all_names = os.listdir(dir_path)
  data_x = []
  data_y = []
  for name in all_names:
    img = keras.preprocessing.image.load_img(os.path.join(dir_path, name))
    img = keras.preprocessing.image.img_to_array(img,dtype='uint8')
    data_x.append(img)
    lab = labels_dict[name.split(' ')[0]]
    data_y.append(lab)
  data_x = np.array(data_x)
  data_y = np.array(data_y)
  return data_x, data_y
class TEXdata(keras.utils.Sequence):
    def __init__(self, data_x, data_y, batch_size, train):
      self.data_x = data_x
      self.data_y = data_y
      self.train = train
      self.batch_size = batch_size

    def __len__(self):
      return int(np.ceil(len(self.data_y) / self.batch_size))

    def __getitem__(self, idx):
      batch_x = self.data_x[idx * self.batch_size:(idx + 1) * self.batch_size]
                            
      batch_y = self.data_y[idx * self.batch_size:(idx + 1) * self.batch_size]
      if self.train == True:
          batch_x = Data_Aug(batch_x)

      batch_x = np.clip(batch_x / 255.0, 0, 1).astype("float32")
      batch_y = keras.utils.to_categorical(batch_y, 6)
      return batch_x, [batch_y, batch_y, batch_y, batch_y, batch_y]

# %%
#save the best model during training 
class CustomEarlyStoppingAndSave(keras.callbacks.Callback):
    def __init__(self, save_path, patience=0):
        super(CustomEarlyStoppingAndSave, self).__init__()
        #self.patience = patience
        self.save_path = save_path
        self.best_weights = None

    def on_train_begin(self, logs=None):
        #self.wait = 0
        self.stopped_epoch = 0
        #self.best_val_distance_loss = np.Inf
        self.best_val_acc = 0

    def on_epoch_end(self, epoch, logs=None):
        #val_distance_loss = logs.get('val_MMD_loss')
        val_acc = logs.get('val_model_accuracy') + logs.get(
            'val_model_1_accuracy') + logs.get(
                'val_model_2_accuracy') 
                #+ logs.get(
                 #   'val_model_3_accuracy') + logs.get('val_model_4_accuracy')

        if  np.greater(val_acc, self.best_val_acc):
            #self.best_val_distance_loss = val_distance_loss
            self.best_val_acc = val_acc
            #self.wait = 0
            # Record the best weights if current results is better (less).
            self.best_weights = self.model.get_weights()
            self.stopped_epoch = epoch
        #else:
            #self.wait += 1
            #if self.wait >= self.patience:
                #self.stopped_epoch = epoch
                #self.model.stop_training = True
                #print("Restoring model weights from the end of the best epoch.")
                #self.model.set_weights(self.best_weights)

    def on_train_end(self, logs=None):
        self.model.set_weights(self.best_weights)
        if self.stopped_epoch >= 0:
            print("Epoch %05d: early stopping and save the model" %
                  (self.stopped_epoch + 1))
        self.model.save(self.save_path)

# %%
#Cosine&Euclidean distance loss
def descriptor(X, mask = False, max_norm = False):
  X = tf.reduce_mean(X, axis=3)
  if mask:
    mean_X = tf.reduce_mean(X, axis = [1,2], keepdims= True)
    X = tf.where(X > mean_X, X , tf.zeros_like(X, dtype=tf.float32))
  if max_norm:
    max_X=tf.reduce_max(X, axis = [1,2], keepdims= True)
    X = tf.math.divide_no_nan(X, max_X)
  return X 
  
def compute_euclidean_sum(X, Y):
  L2_distance = tf.reduce_mean(tf.exp(-(X - Y)**2), axis= [1,2])
  return tf.reduce_mean(L2_distance)

def compute_cosine_sum(X, Y):
  X = tf.reshape(X, [tf.shape(X)[0], -1])
  Y = tf.reshape(Y, [tf.shape(Y)[0], -1])
  loss = -keras.losses.cosine_similarity(X,Y,axis=-1)
  return tf.reduce_mean(loss)

def cosine_euclidean_sum_loss(x, cosine_weight, euclidean_weight, mask, max_norm):
  descriptor0 = descriptor(x[0], mask=mask, max_norm=max_norm)
  descriptor1 = descriptor(x[1], mask=mask, max_norm=max_norm)
  descriptor2 = descriptor(x[2], mask=mask, max_norm=max_norm)
  descriptor3 = descriptor(x[3], mask=mask, max_norm=max_norm)
  descriptor4 = descriptor(x[4], mask=mask, max_norm=max_norm)
  cosine_sum = compute_cosine_sum(descriptor0, descriptor1)+compute_cosine_sum(descriptor0, descriptor2)+compute_cosine_sum(descriptor0, descriptor3)+compute_cosine_sum(descriptor0, descriptor4)+compute_cosine_sum(descriptor1, descriptor2)+compute_cosine_sum(descriptor1, descriptor3)+compute_cosine_sum(descriptor1, descriptor4)+compute_cosine_sum(descriptor2, descriptor3)+compute_cosine_sum(descriptor2, descriptor4)+compute_cosine_sum(descriptor3, descriptor4)
  euclidean_sum = compute_euclidean_sum(descriptor0, descriptor1)+compute_euclidean_sum(descriptor0, descriptor2)+compute_euclidean_sum(descriptor0, descriptor3)+compute_euclidean_sum(descriptor0, descriptor4)+compute_euclidean_sum(descriptor1, descriptor2)+compute_euclidean_sum(descriptor1, descriptor3)+compute_euclidean_sum(descriptor1, descriptor4)+compute_euclidean_sum(descriptor2, descriptor3)+compute_euclidean_sum(descriptor2, descriptor4)+compute_euclidean_sum(descriptor3, descriptor4)
  return cosine_sum, euclidean_sum, cosine_weight*cosine_sum+euclidean_weight*euclidean_sum

# %%
#create single AlexNet model
def create_AlexNet(input_shape, num_classes=6, random_seed=None):
  inputs = keras.Input(shape=input_shape)
  x = keras.layers.Conv2D(96, (3,3), strides=(2,2), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(inputs)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x)
  x = keras.layers.MaxPooling2D(pool_size=(3,3),strides=(2,2),padding='same')(x)
  
  x = keras.layers.Conv2D(256, (3,3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x) 
  x = keras.layers.MaxPooling2D(pool_size=(3,3),strides=(2,2),padding='same')(x)
 
  x = keras.layers.Conv2D(384, (3,3), padding='same', activation='relu', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x) 
  x = keras.layers.Conv2D(384, (3,3), padding='same', activation='relu', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x) 
  x = keras.layers.Conv2D(256, (3,3), padding='same', activation='relu', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  feature_maps = keras.layers.MaxPooling2D(pool_size=(3,3),strides=(2,2),padding='same')(x)
  
  x = keras.layers.Flatten()(feature_maps)
  #x = keras.layers.Dense(256,activation='relu')(x)
  #x = keras.layers.Dropout(0.5)(x)
  x = keras.layers.Dense(128,activation='relu')(x)
  x = keras.layers.Dropout(0.5)(x)
  outputs = keras.layers.Dense(num_classes, activation='softmax')(x)
  model = keras.Model(inputs=inputs, outputs=[outputs,feature_maps])
  return model

# %%
#load training, validation and testing images
training_data_path = '100_samples'
validation_data_path = 'TEX_validation'
test_data_path = 'TEX_test'
labels_dict = {'color': 0, 'cut': 1, 'good': 2, 'hole': 3, 'metal_contamination': 4, 'thread': 5}
x_train, y_train = load_data(training_data_path, labels_dict)
x_val, y_val = load_data(validation_data_path, labels_dict)
x_test, y_test = load_data(test_data_path, labels_dict)
_, x_val, _, y_val = model_selection.train_test_split(
    x_val,
    y_val,
    test_size=2400,
    random_state=0,
    stratify=y_val)
x_test = x_test/255.0

# %%
#construct joint training for the five base models
input_size = (64, 64, 3)
model0 = create_AlexNet(input_shape=input_size, num_classes=6,  random_seed=1)
model1 = create_AlexNet(input_shape=input_size, num_classes=6,  random_seed=2)
model2 = create_AlexNet(input_shape=input_size, num_classes=6,  random_seed=3)
model3 = create_AlexNet(input_shape=input_size, num_classes=6,  random_seed=4)
model4 = create_AlexNet(input_shape=input_size, num_classes=6,  random_seed=5)
allinputs = keras.Input(shape=input_size)
output0, feature_maps0 = model0(allinputs)
output1, feature_maps1 = model1(allinputs)
output2, feature_maps2 = model2(allinputs)
output3, feature_maps3 = model3(allinputs)
output4, feature_maps4 = model4(allinputs)
model_train = keras.Model(
    inputs=allinputs, outputs=[output0, output1, output2, output3, output4])

#implement distance loss
loss1, loss2, loss = cosine_euclidean_sum_loss(x=[feature_maps0, feature_maps1, feature_maps2, feature_maps3, feature_maps4], 
                                      cosine_weight=1, euclidean_weight=0.03, mask=True, max_norm=False)

model_train.add_loss(loss)
model_train.add_metric(loss1, name="loss1", aggregation='mean')
model_train.add_metric(loss2, name="loss2", aggregation='mean')

model_train.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4),
                    loss=['categorical_crossentropy','categorical_crossentropy','categorical_crossentropy','categorical_crossentropy','categorical_crossentropy'],
                    metrics=['accuracy'])

#construct training and validation samples
train_sequence = TEXdata(x_train, y_train, batch_size=10, train=True)
validation_sequence = TEXdata(x_val, y_val, batch_size=10, train=False)

#training 
history = model_train.fit(
    train_sequence,
    epochs=300,
    validation_data=validation_sequence,
    #validation_steps=36,
    callbacks=CustomEarlyStoppingAndSave(
        save_path='50_samples_seed_fix.h5',
        patience=10))
frame = pd.DataFrame({
    'loss':
    history.history['loss'],
    'loss1':
    history.history['loss1'],
    'loss2':
    history.history['loss2'],
    'model_0_loss':
    history.history['model_loss'],
    'model_1_loss':
    history.history['model_1_loss'],
    'model_2_loss':
    history.history['model_2_loss'],
    'model_3_loss':
    history.history['model_3_loss'],
    'model_4_loss':
    history.history['model_4_loss'],
    'model_0_accuracy':
    history.history['model_accuracy'],
    'model_1_accuracy':
    history.history['model_1_accuracy'],
    'model_2_accuracy':
    history.history['model_2_accuracy'],
    'model_3_accuracy':
    history.history['model_3_accuracy'],
    'model_4_accuracy':
    history.history['model_4_accuracy'],
    'val_loss':
    history.history['val_loss'],
    'val_loss1':
    history.history['val_loss1'],
    'val_loss2':
    history.history['val_loss2'],
    'val_model_0_loss':
    history.history['val_model_loss'],
    'val_model_1_loss':
    history.history['val_model_1_loss'],
    'val_model_2_loss':
    history.history['val_model_2_loss'],
    'val_model_3_loss':
    history.history['val_model_3_loss'],
    'val_model_4_loss':
    history.history['val_model_4_loss'],
    'val_model_0_accuracy':
    history.history['val_model_accuracy'],
    'val_model_1_accuracy':
    history.history['val_model_1_accuracy'],
    'val_model_2_accuracy':
    history.history['val_model_2_accuracy'],
    'val_model_3_accuracy':
    history.history['val_model_3_accuracy'],
    'val_model_4_accuracy':
    history.history['val_model_4_accuracy'],
})
#frame.to_excel('table_{numsample}_samples_seed_{numseed}.xlsx'.format(numsample=100, numseed='fix'))
# Out:
# Epoch 1/300
# 2/2 [==============================] - 16s 4s/step - loss: 34.1709 - model_loss: 5.4890 - model_1_loss: 4.2695 - model_2_loss: 5.4372 - model_3_loss: 4.1299 - model_4_loss: 6.0874 - model_accuracy: 0.0556 - model_1_accuracy: 0.1667 - model_2_accuracy: 0.1667 - model_3_accuracy: 0.1667 - model_4_accuracy: 0.1667 - loss1: 8.4847 - loss2: 8.5020 - val_loss: 20.0940 - val_model_loss: 2.1306 - val_model_1_loss: 2.0272 - val_model_2_loss: 2.3424 - val_model_3_loss: 2.1320 - val_model_4_loss: 2.3663 - val_model_accuracy: 0.1617 - val_model_1_accuracy: 0.1575 - val_model_2_accuracy: 0.1667 - val_model_3_accuracy: 0.1617 - val_model_4_accuracy: 0.1642 - val_loss1: 8.8091 - val_loss2: 9.5513
# Epoch 2/300
# 2/2 [==============================] - 3s 3s/step - loss: 28.0146 - model_loss: 3.1655 - model_1_loss: 2.9822 - model_2_loss: 4.7608 - model_3_loss: 4.2149 - model_4_loss: 4.0279 - model_accuracy: 0.2222 - model_1_accuracy: 0.1667 - model_2_accuracy: 0.1667 - model_3_accuracy: 0.2222 - model_4_accuracy: 0.1667 - loss1: 8.5856 - loss2: 8.6408 - val_loss: 19.5320 - val_model_loss: 2.1142 - val_model_1_loss: 1.9970 - val_model_2_loss: 1.9965 - val_model_3_loss: 1.8974 - val_model_4_loss: 2.4921 - val_model_accuracy: 0.1821 - val_model_1_accuracy: 0.1646 - val_model_2_accuracy: 0.1737 - val_model_3_accuracy: 0.1546 - val_model_4_accuracy: 0.1667 - val_loss1: 8.7474 - val_loss2: 9.5793
# Epoch 3/300
# 2/2 [==============================] - 3s 2s/step - loss: 23.5592 - model_loss: 3.4262 - model_1_loss: 2.4603 - model_2_loss: 2.6760 - model_3_loss: 3.3694 - model_4_loss: 2.8285 - model_accuracy: 0.1667 - model_1_accuracy: 0.3889 - model_2_accuracy: 0.3333 - model_3_accuracy: 0.3333 - model_4_accuracy: 0.2778 - loss1: 8.5165 - loss2: 8.7043 - val_loss: 18.7262 - val_model_loss: 1.9998 - val_model_1_loss: 1.8699 - val_model_2_loss: 1.8845 - val_model_3_loss: 1.7927 - val_model_4_loss: 2.2218 - val_model_accuracy: 0.1754 - val_model_1_accuracy: 0.1675 - val_model_2_accuracy: 0.1821 - val_model_3_accuracy: 0.1717 - val_model_4_accuracy: 0.1667 - val_loss1: 8.6696 - val_loss2: 9.5982
# Epoch 4/300
# 2/2 [==============================] - 2s 2s/step - loss: 22.0735 - model_loss: 3.4594 - model_1_loss: 1.9889 - model_2_loss: 2.0998 - model_3_loss: 2.1228 - model_4_loss: 3.6684 - model_accuracy: 0.1667 - model_1_accuracy: 0.2778 - model_2_accuracy: 0.3333 - model_3_accuracy: 0.2222 - model_4_accuracy: 0.1667 - loss1: 8.4525 - loss2: 8.7110 - val_loss: 18.3264 - val_model_loss: 1.8786 - val_model_1_loss: 1.8342 - val_model_2_loss: 1.7978 - val_model_3_loss: 1.8070 - val_model_4_loss: 2.0701 - val_model_accuracy: 0.1779 - val_model_1_accuracy: 0.1629 - val_model_2_accuracy: 0.1708 - val_model_3_accuracy: 0.1667 - val_model_4_accuracy: 0.1883 - val_loss1: 8.6499 - val_loss2: 9.6267
# Epoch 5/300
# 2/2 [==============================] - 2s 2s/step - loss: 19.3239 - model_loss: 1.7904 - model_1_loss: 2.0079 - model_2_loss: 2.3701 - model_3_loss: 2.1058 - model_4_loss: 2.4811 - model_accuracy: 0.2778 - model_1_accuracy: 0.3333 - model_2_accuracy: 0.1667 - model_3_accuracy: 0.2222 - model_4_accuracy: 0.2778 - loss1: 8.2855 - loss2: 8.6729 - val_loss: 18.2490 - val_model_loss: 1.8469 - val_model_1_loss: 1.8314 - val_model_2_loss: 1.8183 - val_model_3_loss: 1.8164 - val_model_4_loss: 2.0084 - val_model_accuracy: 0.1633 - val_model_1_accuracy: 0.1571 - val_model_2_accuracy: 0.1671 - val_model_3_accuracy: 0.1671 - val_model_4_accuracy: 0.1604 - val_loss1: 8.6381 - val_loss2: 9.6505
# Epoch 6/300
# 2/2 [==============================] - 2s 2s/step - loss: 17.9103 - model_loss: 2.0731 - model_1_loss: 1.7853 - model_2_loss: 1.4675 - model_3_loss: 1.9903 - model_4_loss: 1.9829 - model_accuracy: 0.1667 - model_1_accuracy: 0.3889 - model_2_accuracy: 0.3889 - model_3_accuracy: 0.2222 - model_4_accuracy: 0.2778 - loss1: 8.3487 - loss2: 8.7123 - val_loss: 18.2022 - val_model_loss: 1.8477 - val_model_1_loss: 1.8393 - val_model_2_loss: 1.8265 - val_model_3_loss: 1.8105 - val_model_4_loss: 1.9717 - val_model_accuracy: 0.1633 - val_model_1_accuracy: 0.1696 - val_model_2_accuracy: 0.1733 - val_model_3_accuracy: 0.1675 - val_model_4_accuracy: 0.1667 - val_loss1: 8.6165 - val_loss2: 9.6659
# Epoch 7/300
# 2/2 [==============================] - 2s 2s/step - loss: 17.3360 - model_loss: 1.9260 - model_1_loss: 1.7165 - model_2_loss: 1.6224 - model_3_loss: 1.8545 - model_4_loss: 1.8166 - model_accuracy: 0.2222 - model_1_accuracy: 0.2778 - model_2_accuracy: 0.4444 - model_3_accuracy: 0.2222 - model_4_accuracy: 0.3889 - loss1: 8.1195 - loss2: 8.6678 - val_loss: 18.0491 - val_model_loss: 1.8336 - val_model_1_loss: 1.8241 - val_model_2_loss: 1.8240 - val_model_3_loss: 1.8063 - val_model_4_loss: 1.8957 - val_model_accuracy: 0.1629 - val_model_1_accuracy: 0.1658 - val_model_2_accuracy: 0.1717 - val_model_3_accuracy: 0.1717 - val_model_4_accuracy: 0.1650 - val_loss1: 8.5752 - val_loss2: 9.6732
# Epoch 8/300
# 2/2 [==============================] - 2s 2s/step - loss: 15.8096 - model_loss: 1.3330 - model_1_loss: 1.7120 - model_2_loss: 1.4541 - model_3_loss: 1.3503 - model_4_loss: 1.4512 - model_accuracy: 0.5000 - model_1_accuracy: 0.3333 - model_2_accuracy: 0.3889 - model_3_accuracy: 0.3889 - model_4_accuracy: 0.4444 - loss1: 8.2393 - loss2: 8.6925 - val_loss: 17.9476 - val_model_loss: 1.8197 - val_model_1_loss: 1.8243 - val_model_2_loss: 1.8196 - val_model_3_loss: 1.8029 - val_model_4_loss: 1.8488 - val_model_accuracy: 0.1629 - val_model_1_accuracy: 0.1558 - val_model_2_accuracy: 0.1671 - val_model_3_accuracy: 0.1721 - val_model_4_accuracy: 0.1462 - val_loss1: 8.5419 - val_loss2: 9.6805
# Epoch 9/300
# 2/2 [==============================] - 2s 2s/step - loss: 16.1713 - model_loss: 1.8161 - model_1_loss: 1.2957 - model_2_loss: 1.6323 - model_3_loss: 1.5260 - model_4_loss: 1.5881 - model_accuracy: 0.2778 - model_1_accuracy: 0.5000 - model_2_accuracy: 0.2778 - model_3_accuracy: 0.3333 - model_4_accuracy: 0.3889 - loss1: 8.0076 - loss2: 8.6076 - val_loss: 17.9059 - val_model_loss: 1.8131 - val_model_1_loss: 1.8262 - val_model_2_loss: 1.8119 - val_model_3_loss: 1.7999 - val_model_4_loss: 1.8418 - val_model_accuracy: 0.1596 - val_model_1_accuracy: 0.1646 - val_model_2_accuracy: 0.1713 - val_model_3_accuracy: 0.1762 - val_model_4_accuracy: 0.1813 - val_loss1: 8.5224 - val_loss2: 9.6895
# Epoch 10/300
# 2/2 [==============================] - 2s 2s/step - loss: 15.3965 - model_loss: 1.6445 - model_1_loss: 1.3264 - model_2_loss: 1.3672 - model_3_loss: 1.3436 - model_4_loss: 1.5061 - model_accuracy: 0.2222 - model_1_accuracy: 0.4444 - model_2_accuracy: 0.4444 - model_3_accuracy: 0.5556 - model_4_accuracy: 0.4444 - loss1: 7.9299 - loss2: 8.6028 - val_loss: 17.8795 - val_model_loss: 1.8051 - val_model_1_loss: 1.8411 - val_model_2_loss: 1.8029 - val_model_3_loss: 1.7957 - val_model_4_loss: 1.8529 - val_model_accuracy: 0.1575 - val_model_1_accuracy: 0.1692 - val_model_2_accuracy: 0.1671 - val_model_3_accuracy: 0.1850 - val_model_4_accuracy: 0.1917 - val_loss1: 8.4910 - val_loss2: 9.6927
# Epoch 11/300
# 2/2 [==============================] - 2s 2s/step - loss: 15.4329 - model_loss: 1.5180 - model_1_loss: 1.4512 - model_2_loss: 1.3768 - model_3_loss: 1.4307 - model_4_loss: 1.3811 - model_accuracy: 0.3889 - model_1_accuracy: 0.4444 - model_2_accuracy: 0.5556 - model_3_accuracy: 0.3889 - model_4_accuracy: 0.4444 - loss1: 7.9644 - loss2: 8.6069 - val_loss: 17.8471 - val_model_loss: 1.7983 - val_model_1_loss: 1.8458 - val_model_2_loss: 1.8028 - val_model_3_loss: 1.7919 - val_model_4_loss: 1.8569 - val_model_accuracy: 0.1846 - val_model_1_accuracy: 0.1667 - val_model_2_accuracy: 0.1546 - val_model_3_accuracy: 0.1762 - val_model_4_accuracy: 0.1967 - val_loss1: 8.4607 - val_loss2: 9.6950
# Epoch 12/300
# 2/2 [==============================] - 2s 2s/step - loss: 14.6978 - model_loss: 1.4518 - model_1_loss: 1.2624 - model_2_loss: 1.3758 - model_3_loss: 1.2172 - model_4_loss: 1.3654 - model_accuracy: 0.4444 - model_1_accuracy: 0.4444 - model_2_accuracy: 0.3889 - model_3_accuracy: 0.6111 - model_4_accuracy: 0.6667 - loss1: 7.7475 - loss2: 8.4940 - val_loss: 17.7504 - val_model_loss: 1.7914 - val_model_1_loss: 1.8281 - val_model_2_loss: 1.8012 - val_model_3_loss: 1.7926 - val_model_4_loss: 1.8349 - val_model_accuracy: 0.1912 - val_model_1_accuracy: 0.1671 - val_model_2_accuracy: 0.1538 - val_model_3_accuracy: 0.1642 - val_model_4_accuracy: 0.1992 - val_loss1: 8.4114 - val_loss2: 9.6929
# Epoch 13/300
# 2/2 [==============================] - 2s 2s/step - loss: 16.1218 - model_loss: 1.4313 - model_1_loss: 1.5307 - model_2_loss: 1.9447 - model_3_loss: 1.4556 - model_4_loss: 1.9051 - model_accuracy: 0.5556 - model_1_accuracy: 0.5000 - model_2_accuracy: 0.3333 - model_3_accuracy: 0.4444 - model_4_accuracy: 0.2778 - loss1: 7.5440 - loss2: 8.4996 - val_loss: 17.6346 - val_model_loss: 1.7860 - val_model_1_loss: 1.8108 - val_model_2_loss: 1.7939 - val_model_3_loss: 1.7932 - val_model_4_loss: 1.8149 - val_model_accuracy: 0.1863 - val_model_1_accuracy: 0.1704 - val_model_2_accuracy: 0.1592 - val_model_3_accuracy: 0.1633 - val_model_4_accuracy: 0.1488 - val_loss1: 8.3452 - val_loss2: 9.6866
# Epoch 14/300
# 2/2 [==============================] - 3s 3s/step - loss: 13.8241 - model_loss: 1.1663 - model_1_loss: 1.1778 - model_2_loss: 1.1717 - model_3_loss: 1.2543 - model_4_loss: 1.2186 - model_accuracy: 0.6111 - model_1_accuracy: 0.3333 - model_2_accuracy: 0.5000 - model_3_accuracy: 0.5000 - model_4_accuracy: 0.5556 - loss1: 7.5309 - loss2: 8.4183 - val_loss: 17.5456 - val_model_loss: 1.7834 - val_model_1_loss: 1.7925 - val_model_2_loss: 1.7805 - val_model_3_loss: 1.7954 - val_model_4_loss: 1.8230 - val_model_accuracy: 0.1912 - val_model_1_accuracy: 0.1817 - val_model_2_accuracy: 0.1983 - val_model_3_accuracy: 0.1583 - val_model_4_accuracy: 0.1358 - val_loss1: 8.2805 - val_loss2: 9.6787
# Epoch 15/300
# 2/2 [==============================] - 2s 2s/step - loss: 13.4672 - model_loss: 0.9766 - model_1_loss: 1.0436 - model_2_loss: 1.2592 - model_3_loss: 1.0994 - model_4_loss: 1.3206 - model_accuracy: 0.7222 - model_1_accuracy: 0.6111 - model_2_accuracy: 0.6667 - model_3_accuracy: 0.7778 - model_4_accuracy: 0.5000 - loss1: 7.4813 - loss2: 8.3117 - val_loss: 17.4764 - val_model_loss: 1.7859 - val_model_1_loss: 1.7839 - val_model_2_loss: 1.7797 - val_model_3_loss: 1.7974 - val_model_4_loss: 1.8302 - val_model_accuracy: 0.1979 - val_model_1_accuracy: 0.1967 - val_model_2_accuracy: 0.2000 - val_model_3_accuracy: 0.1654 - val_model_4_accuracy: 0.1317 - val_loss1: 8.2093 - val_loss2: 9.6663
# Epoch 16/300
# 2/2 [==============================] - 2s 2s/step - loss: 14.1003 - model_loss: 1.4779 - model_1_loss: 1.0242 - model_2_loss: 1.3952 - model_3_loss: 1.2797 - model_4_loss: 1.4324 - model_accuracy: 0.6111 - model_1_accuracy: 0.6111 - model_2_accuracy: 0.3889 - model_3_accuracy: 0.5556 - model_4_accuracy: 0.4444 - loss1: 7.1887 - loss2: 8.2134 - val_loss: 17.4073 - val_model_loss: 1.7933 - val_model_1_loss: 1.7855 - val_model_2_loss: 1.7822 - val_model_3_loss: 1.7940 - val_model_4_loss: 1.8291 - val_model_accuracy: 0.1942 - val_model_1_accuracy: 0.1683 - val_model_2_accuracy: 0.1825 - val_model_3_accuracy: 0.1688 - val_model_4_accuracy: 0.1225 - val_loss1: 8.1336 - val_loss2: 9.6518
# Epoch 17/300
# 2/2 [==============================] - 2s 2s/step - loss: 13.3941 - model_loss: 1.2083 - model_1_loss: 0.9599 - model_2_loss: 1.4366 - model_3_loss: 1.0369 - model_4_loss: 1.0208 - model_accuracy: 0.6111 - model_1_accuracy: 0.5556 - model_2_accuracy: 0.5000 - model_3_accuracy: 0.6667 - model_4_accuracy: 0.8333 - loss1: 7.4532 - loss2: 8.2749 - val_loss: 17.3286 - val_model_loss: 1.7958 - val_model_1_loss: 1.7881 - val_model_2_loss: 1.7815 - val_model_3_loss: 1.7992 - val_model_4_loss: 1.8214 - val_model_accuracy: 0.1883 - val_model_1_accuracy: 0.1675 - val_model_2_accuracy: 0.1696 - val_model_3_accuracy: 0.1671 - val_model_4_accuracy: 0.1367 - val_loss1: 8.0537 - val_loss2: 9.6352
# Epoch 18/300
# 2/2 [==============================] - 2s 2s/step - loss: 13.3340 - model_loss: 1.0884 - model_1_loss: 1.1591 - model_2_loss: 1.2742 - model_3_loss: 1.2935 - model_4_loss: 1.1660 - model_accuracy: 0.6667 - model_1_accuracy: 0.5000 - model_2_accuracy: 0.3889 - model_3_accuracy: 0.5556 - model_4_accuracy: 0.6667 - loss1: 7.0618 - loss2: 8.0747 - val_loss: 17.2387 - val_model_loss: 1.7948 - val_model_1_loss: 1.8142 - val_model_2_loss: 1.7804 - val_model_3_loss: 1.7951 - val_model_4_loss: 1.8149 - val_model_accuracy: 0.1800 - val_model_1_accuracy: 0.1696 - val_model_2_accuracy: 0.1733 - val_model_3_accuracy: 0.1679 - val_model_4_accuracy: 0.1446 - val_loss1: 7.9508 - val_loss2: 9.6136
# Epoch 19/300
# 2/2 [==============================] - 2s 2s/step - loss: 12.0018 - model_loss: 0.9487 - model_1_loss: 0.8426 - model_2_loss: 1.0794 - model_3_loss: 1.0202 - model_4_loss: 0.7644 - model_accuracy: 0.6667 - model_1_accuracy: 0.7222 - model_2_accuracy: 0.6111 - model_3_accuracy: 0.6667 - model_4_accuracy: 0.7778 - loss1: 7.0601 - loss2: 8.0286 - val_loss: 17.1586 - val_model_loss: 1.7965 - val_model_1_loss: 1.8352 - val_model_2_loss: 1.7795 - val_model_3_loss: 1.7923 - val_model_4_loss: 1.8119 - val_model_accuracy: 0.2262 - val_model_1_accuracy: 0.1671 - val_model_2_accuracy: 0.1746 - val_model_3_accuracy: 0.1692 - val_model_4_accuracy: 0.1446 - val_loss1: 7.8554 - val_loss2: 9.5920
# Epoch 20/300
# 2/2 [==============================] - 2s 2s/step - loss: 12.8577 - model_loss: 1.0593 - model_1_loss: 1.1502 - model_2_loss: 1.4753 - model_3_loss: 1.2513 - model_4_loss: 1.0742 - model_accuracy: 0.6111 - model_1_accuracy: 0.5556 - model_2_accuracy: 0.3333 - model_3_accuracy: 0.6111 - model_4_accuracy: 0.7222 - loss1: 6.5625 - loss2: 7.7982 - val_loss: 17.0339 - val_model_loss: 1.8018 - val_model_1_loss: 1.8163 - val_model_2_loss: 1.7768 - val_model_3_loss: 1.7891 - val_model_4_loss: 1.8139 - val_model_accuracy: 0.2371 - val_model_1_accuracy: 0.1725 - val_model_2_accuracy: 0.1796 - val_model_3_accuracy: 0.1879 - val_model_4_accuracy: 0.1429 - val_loss1: 7.7490 - val_loss2: 9.5691
# Epoch 21/300
# 2/2 [==============================] - 2s 2s/step - loss: 11.8672 - model_loss: 0.8090 - model_1_loss: 0.7174 - model_2_loss: 1.1527 - model_3_loss: 0.8708 - model_4_loss: 0.9322 - model_accuracy: 0.7778 - model_1_accuracy: 0.8333 - model_2_accuracy: 0.5556 - model_3_accuracy: 0.6667 - model_4_accuracy: 0.6667 - loss1: 7.1004 - loss2: 8.0337 - val_loss: 16.9160 - val_model_loss: 1.7992 - val_model_1_loss: 1.8036 - val_model_2_loss: 1.7774 - val_model_3_loss: 1.7883 - val_model_4_loss: 1.8217 - val_model_accuracy: 0.2438 - val_model_1_accuracy: 0.1796 - val_model_2_accuracy: 0.2175 - val_model_3_accuracy: 0.1892 - val_model_4_accuracy: 0.1375 - val_loss1: 7.6394 - val_loss2: 9.5446
# Epoch 22/300
# 2/2 [==============================] - 2s 2s/step - loss: 13.8999 - model_loss: 1.1953 - model_1_loss: 1.4637 - model_2_loss: 1.4808 - model_3_loss: 1.4022 - model_4_loss: 1.3077 - model_accuracy: 0.5000 - model_1_accuracy: 0.4444 - model_2_accuracy: 0.5556 - model_3_accuracy: 0.5000 - model_4_accuracy: 0.4444 - loss1: 6.7869 - loss2: 7.9128 - val_loss: 16.8190 - val_model_loss: 1.7957 - val_model_1_loss: 1.8034 - val_model_2_loss: 1.7770 - val_model_3_loss: 1.7923 - val_model_4_loss: 1.8326 - val_model_accuracy: 0.2300 - val_model_1_accuracy: 0.2092 - val_model_2_accuracy: 0.2196 - val_model_3_accuracy: 0.2025 - val_model_4_accuracy: 0.1292 - val_loss1: 7.5322 - val_loss2: 9.5270
# Epoch 23/300
# 2/2 [==============================] - 2s 2s/step - loss: 12.3637 - model_loss: 1.0056 - model_1_loss: 1.0301 - model_2_loss: 1.6074 - model_3_loss: 0.9143 - model_4_loss: 1.2205 - model_accuracy: 0.6111 - model_1_accuracy: 0.5556 - model_2_accuracy: 0.4444 - model_3_accuracy: 0.7778 - model_4_accuracy: 0.5556 - loss1: 6.3156 - loss2: 7.7063 - val_loss: 16.7130 - val_model_loss: 1.7981 - val_model_1_loss: 1.8080 - val_model_2_loss: 1.7719 - val_model_3_loss: 1.7875 - val_model_4_loss: 1.8393 - val_model_accuracy: 0.2446 - val_model_1_accuracy: 0.1704 - val_model_2_accuracy: 0.2075 - val_model_3_accuracy: 0.2117 - val_model_4_accuracy: 0.1287 - val_loss1: 7.4229 - val_loss2: 9.5112
# Epoch 24/300
# 2/2 [==============================] - 3s 3s/step - loss: 12.0650 - model_loss: 1.1690 - model_1_loss: 0.9893 - model_2_loss: 1.3683 - model_3_loss: 1.1659 - model_4_loss: 1.0157 - model_accuracy: 0.5556 - model_1_accuracy: 0.5556 - model_2_accuracy: 0.4444 - model_3_accuracy: 0.6667 - model_4_accuracy: 0.7222 - loss1: 6.0689 - loss2: 7.4771 - val_loss: 16.5791 - val_model_loss: 1.7954 - val_model_1_loss: 1.7980 - val_model_2_loss: 1.7671 - val_model_3_loss: 1.7852 - val_model_4_loss: 1.8444 - val_model_accuracy: 0.2467 - val_model_1_accuracy: 0.1725 - val_model_2_accuracy: 0.2296 - val_model_3_accuracy: 0.2087 - val_model_4_accuracy: 0.1250 - val_loss1: 7.3041 - val_loss2: 9.4969
# Epoch 25/300
# 2/2 [==============================] - 2s 2s/step - loss: 11.7938 - model_loss: 1.0922 - model_1_loss: 1.1630 - model_2_loss: 1.2854 - model_3_loss: 1.1634 - model_4_loss: 0.9146 - model_accuracy: 0.6667 - model_1_accuracy: 0.6111 - model_2_accuracy: 0.5556 - model_3_accuracy: 0.5556 - model_4_accuracy: 0.7222 - loss1: 5.9421 - loss2: 7.3360 - val_loss: 16.4498 - val_model_loss: 1.7978 - val_model_1_loss: 1.7910 - val_model_2_loss: 1.7658 - val_model_3_loss: 1.7845 - val_model_4_loss: 1.8455 - val_model_accuracy: 0.2200 - val_model_1_accuracy: 0.2475 - val_model_2_accuracy: 0.2229 - val_model_3_accuracy: 0.2179 - val_model_4_accuracy: 0.1296 - val_loss1: 7.1808 - val_loss2: 9.4831
# Epoch 26/300
# 2/2 [==============================] - 3s 2s/step - loss: 12.0130 - model_loss: 1.0870 - model_1_loss: 1.2116 - model_2_loss: 1.3909 - model_3_loss: 1.1522 - model_4_loss: 0.9569 - model_accuracy: 0.7222 - model_1_accuracy: 0.5556 - model_2_accuracy: 0.5556 - model_3_accuracy: 0.6667 - model_4_accuracy: 0.6667 - loss1: 5.9717 - loss2: 7.4560 - val_loss: 16.3914 - val_model_loss: 1.8224 - val_model_1_loss: 1.8173 - val_model_2_loss: 1.7697 - val_model_3_loss: 1.7874 - val_model_4_loss: 1.8433 - val_model_accuracy: 0.1787 - val_model_1_accuracy: 0.2508 - val_model_2_accuracy: 0.2321 - val_model_3_accuracy: 0.2267 - val_model_4_accuracy: 0.1346 - val_loss1: 7.0672 - val_loss2: 9.4688
# Epoch 27/300
# 2/2 [==============================] - 3s 2s/step - loss: 10.6813 - model_loss: 1.0531 - model_1_loss: 0.8012 - model_2_loss: 1.0820 - model_3_loss: 0.8606 - model_4_loss: 0.8692 - model_accuracy: 0.6111 - model_1_accuracy: 0.7778 - model_2_accuracy: 0.6667 - model_3_accuracy: 0.6667 - model_4_accuracy: 0.8333 - loss1: 5.7511 - loss2: 7.3358 - val_loss: 16.3454 - val_model_loss: 1.8323 - val_model_1_loss: 1.8571 - val_model_2_loss: 1.7818 - val_model_3_loss: 1.7898 - val_model_4_loss: 1.8366 - val_model_accuracy: 0.1708 - val_model_1_accuracy: 0.2442 - val_model_2_accuracy: 0.2358 - val_model_3_accuracy: 0.2058 - val_model_4_accuracy: 0.1412 - val_loss1: 6.9642 - val_loss2: 9.4535
# Epoch 28/300
# 2/2 [==============================] - 2s 2s/step - loss: 10.0601 - model_loss: 0.8983 - model_1_loss: 0.7902 - model_2_loss: 1.2291 - model_3_loss: 0.7820 - model_4_loss: 0.6309 - model_accuracy: 0.7778 - model_1_accuracy: 0.7778 - model_2_accuracy: 0.4444 - model_3_accuracy: 0.7778 - model_4_accuracy: 0.8889 - loss1: 5.4770 - loss2: 7.1826 - val_loss: 16.2420 - val_model_loss: 1.8203 - val_model_1_loss: 1.8822 - val_model_2_loss: 1.7864 - val_model_3_loss: 1.7885 - val_model_4_loss: 1.8233 - val_model_accuracy: 0.1683 - val_model_1_accuracy: 0.2375 - val_model_2_accuracy: 0.1929 - val_model_3_accuracy: 0.2125 - val_model_4_accuracy: 0.1562 - val_loss1: 6.8582 - val_loss2: 9.4362
# Epoch 29/300
# 2/2 [==============================] - 2s 2s/step - loss: 10.4940 - model_loss: 0.9982 - model_1_loss: 0.9116 - model_2_loss: 0.9691 - model_3_loss: 0.8374 - model_4_loss: 0.9954 - model_accuracy: 0.6667 - model_1_accuracy: 0.5556 - model_2_accuracy: 0.7222 - model_3_accuracy: 0.7222 - model_4_accuracy: 0.7222 - loss1: 5.5280 - loss2: 7.2530 - val_loss: 16.1079 - val_model_loss: 1.8073 - val_model_1_loss: 1.8672 - val_model_2_loss: 1.7951 - val_model_3_loss: 1.7836 - val_model_4_loss: 1.8111 - val_model_accuracy: 0.1937 - val_model_1_accuracy: 0.2408 - val_model_2_accuracy: 0.1713 - val_model_3_accuracy: 0.2188 - val_model_4_accuracy: 0.1754 - val_loss1: 6.7612 - val_loss2: 9.4147
# Epoch 30/300
# 2/2 [==============================] - 2s 2s/step - loss: 10.2434 - model_loss: 0.7690 - model_1_loss: 1.1877 - model_2_loss: 0.9007 - model_3_loss: 0.9406 - model_4_loss: 0.7530 - model_accuracy: 0.8333 - model_1_accuracy: 0.5556 - model_2_accuracy: 0.6667 - model_3_accuracy: 0.7222 - model_4_accuracy: 0.7778 - loss1: 5.4514 - loss2: 7.2803 - val_loss: 16.0144 - val_model_loss: 1.7876 - val_model_1_loss: 1.8151 - val_model_2_loss: 1.8190 - val_model_3_loss: 1.7919 - val_model_4_loss: 1.8178 - val_model_accuracy: 0.2450 - val_model_1_accuracy: 0.2608 - val_model_2_accuracy: 0.1592 - val_model_3_accuracy: 0.2154 - val_model_4_accuracy: 0.1825 - val_loss1: 6.7010 - val_loss2: 9.4013
# Epoch 31/300
# 2/2 [==============================] - 2s 2s/step - loss: 10.7727 - model_loss: 1.0772 - model_1_loss: 0.8764 - model_2_loss: 1.3057 - model_3_loss: 1.1587 - model_4_loss: 0.9888 - model_accuracy: 0.6111 - model_1_accuracy: 0.6111 - model_2_accuracy: 0.5556 - model_3_accuracy: 0.5000 - model_4_accuracy: 0.7222 - loss1: 5.1296 - loss2: 7.0619 - val_loss: 15.9640 - val_model_loss: 1.7802 - val_model_1_loss: 1.8080 - val_model_2_loss: 1.8381 - val_model_3_loss: 1.7915 - val_model_4_loss: 1.8368 - val_model_accuracy: 0.2488 - val_model_1_accuracy: 0.2358 - val_model_2_accuracy: 0.1700 - val_model_3_accuracy: 0.2096 - val_model_4_accuracy: 0.1850 - val_loss1: 6.6279 - val_loss2: 9.3890
# Epoch 32/300
# 2/2 [==============================] - 2s 2s/step - loss: 11.2069 - model_loss: 1.1718 - model_1_loss: 0.8642 - model_2_loss: 1.4505 - model_3_loss: 1.2817 - model_4_loss: 1.0702 - model_accuracy: 0.6111 - model_1_accuracy: 0.7222 - model_2_accuracy: 0.5000 - model_3_accuracy: 0.4444 - model_4_accuracy: 0.6111 - loss1: 5.1304 - loss2: 7.1242 - val_loss: 15.9432 - val_model_loss: 1.7914 - val_model_1_loss: 1.8194 - val_model_2_loss: 1.8290 - val_model_3_loss: 1.8041 - val_model_4_loss: 1.8698 - val_model_accuracy: 0.2087 - val_model_1_accuracy: 0.2062 - val_model_2_accuracy: 0.1725 - val_model_3_accuracy: 0.1737 - val_model_4_accuracy: 0.1671 - val_loss1: 6.5483 - val_loss2: 9.3734
# Epoch 33/300
# 2/2 [==============================] - 2s 2s/step - loss: 10.5308 - model_loss: 0.9430 - model_1_loss: 0.9734 - model_2_loss: 1.3776 - model_3_loss: 0.9008 - model_4_loss: 0.9223 - model_accuracy: 0.5556 - model_1_accuracy: 0.7778 - model_2_accuracy: 0.5000 - model_3_accuracy: 0.7222 - model_4_accuracy: 0.7778 - loss1: 5.1525 - loss2: 7.1636 - val_loss: 15.9138 - val_model_loss: 1.8165 - val_model_1_loss: 1.8288 - val_model_2_loss: 1.8221 - val_model_3_loss: 1.8190 - val_model_4_loss: 1.8901 - val_model_accuracy: 0.2000 - val_model_1_accuracy: 0.2142 - val_model_2_accuracy: 0.1721 - val_model_3_accuracy: 0.1783 - val_model_4_accuracy: 0.1592 - val_loss1: 6.4567 - val_loss2: 9.3531
# Epoch 34/300
# 2/2 [==============================] - 2s 2s/step - loss: 10.6485 - model_loss: 1.0483 - model_1_loss: 1.1063 - model_2_loss: 1.1549 - model_3_loss: 1.2022 - model_4_loss: 1.0975 - model_accuracy: 0.6667 - model_1_accuracy: 0.7222 - model_2_accuracy: 0.4444 - model_3_accuracy: 0.7222 - model_4_accuracy: 0.6111 - loss1: 4.8021 - loss2: 6.9023 - val_loss: 15.8626 - val_model_loss: 1.8552 - val_model_1_loss: 1.8529 - val_model_2_loss: 1.8270 - val_model_3_loss: 1.8161 - val_model_4_loss: 1.8683 - val_model_accuracy: 0.1954 - val_model_1_accuracy: 0.2317 - val_model_2_accuracy: 0.2054 - val_model_3_accuracy: 0.1904 - val_model_4_accuracy: 0.1713 - val_loss1: 6.3633 - val_loss2: 9.3277
# Epoch 35/300
# 2/2 [==============================] - 2s 2s/step - loss: 10.4801 - model_loss: 0.8007 - model_1_loss: 1.0799 - model_2_loss: 1.5007 - model_3_loss: 0.8371 - model_4_loss: 0.9939 - model_accuracy: 0.7222 - model_1_accuracy: 0.7222 - model_2_accuracy: 0.4444 - model_3_accuracy: 0.7222 - model_4_accuracy: 0.6667 - loss1: 5.0209 - loss2: 7.0029 - val_loss: 15.7189 - val_model_loss: 1.8765 - val_model_1_loss: 1.8582 - val_model_2_loss: 1.8117 - val_model_3_loss: 1.8027 - val_model_4_loss: 1.8361 - val_model_accuracy: 0.1833 - val_model_1_accuracy: 0.2596 - val_model_2_accuracy: 0.2246 - val_model_3_accuracy: 0.2229 - val_model_4_accuracy: 0.1937 - val_loss1: 6.2545 - val_loss2: 9.3057
# Epoch 36/300
# 2/2 [==============================] - 2s 2s/step - loss: 9.4952 - model_loss: 0.9712 - model_1_loss: 0.7634 - model_2_loss: 1.0358 - model_3_loss: 0.8317 - model_4_loss: 0.8494 - model_accuracy: 0.6667 - model_1_accuracy: 0.7222 - model_2_accuracy: 0.5556 - model_3_accuracy: 0.7222 - model_4_accuracy: 0.6667 - loss1: 4.7964 - loss2: 6.9774 - val_loss: 15.5465 - val_model_loss: 1.8745 - val_model_1_loss: 1.8595 - val_model_2_loss: 1.7947 - val_model_3_loss: 1.7878 - val_model_4_loss: 1.8096 - val_model_accuracy: 0.1854 - val_model_1_accuracy: 0.2617 - val_model_2_accuracy: 0.2392 - val_model_3_accuracy: 0.2492 - val_model_4_accuracy: 0.1917 - val_loss1: 6.1418 - val_loss2: 9.2847
# Epoch 37/300
# 2/2 [==============================] - 3s 3s/step - loss: 8.0613 - model_loss: 0.3410 - model_1_loss: 0.8247 - model_2_loss: 0.9091 - model_3_loss: 0.6297 - model_4_loss: 0.5832 - model_accuracy: 0.8889 - model_1_accuracy: 0.7222 - model_2_accuracy: 0.6667 - model_3_accuracy: 0.7222 - model_4_accuracy: 0.7778 - loss1: 4.5592 - loss2: 6.7472 - val_loss: 15.4559 - val_model_loss: 1.8916 - val_model_1_loss: 1.8895 - val_model_2_loss: 1.7890 - val_model_3_loss: 1.7878 - val_model_4_loss: 1.7844 - val_model_accuracy: 0.2062 - val_model_1_accuracy: 0.2671 - val_model_2_accuracy: 0.2442 - val_model_3_accuracy: 0.2463 - val_model_4_accuracy: 0.2067 - val_loss1: 6.0359 - val_loss2: 9.2578
# Epoch 38/300
# 2/2 [==============================] - 3s 2s/step - loss: 9.2434 - model_loss: 0.7540 - model_1_loss: 0.8637 - model_2_loss: 0.9719 - model_3_loss: 1.0603 - model_4_loss: 0.8308 - model_accuracy: 0.6667 - model_1_accuracy: 0.6667 - model_2_accuracy: 0.7778 - model_3_accuracy: 0.6111 - model_4_accuracy: 0.7222 - loss1: 4.5330 - loss2: 6.7466 - val_loss: 15.3696 - val_model_loss: 1.9094 - val_model_1_loss: 1.8882 - val_model_2_loss: 1.7812 - val_model_3_loss: 1.7953 - val_model_4_loss: 1.7807 - val_model_accuracy: 0.2167 - val_model_1_accuracy: 0.2754 - val_model_2_accuracy: 0.2483 - val_model_3_accuracy: 0.2329 - val_model_4_accuracy: 0.2212 - val_loss1: 5.9380 - val_loss2: 9.2315
# Epoch 39/300
# 2/2 [==============================] - 2s 2s/step - loss: 11.2993 - model_loss: 1.1669 - model_1_loss: 1.0801 - model_2_loss: 1.2680 - model_3_loss: 1.3911 - model_4_loss: 1.6326 - model_accuracy: 0.6667 - model_1_accuracy: 0.5556 - model_2_accuracy: 0.6111 - model_3_accuracy: 0.4444 - model_4_accuracy: 0.5000 - loss1: 4.5229 - loss2: 6.8106 - val_loss: 15.3223 - val_model_loss: 1.9229 - val_model_1_loss: 1.8660 - val_model_2_loss: 1.7699 - val_model_3_loss: 1.8199 - val_model_4_loss: 1.8042 - val_model_accuracy: 0.1817 - val_model_1_accuracy: 0.2746 - val_model_2_accuracy: 0.2562 - val_model_3_accuracy: 0.2425 - val_model_4_accuracy: 0.2113 - val_loss1: 5.8631 - val_loss2: 9.2069
# Epoch 40/300
# 2/2 [==============================] - 2s 2s/step - loss: 10.3090 - model_loss: 1.1209 - model_1_loss: 1.3084 - model_2_loss: 1.1223 - model_3_loss: 0.9065 - model_4_loss: 1.1749 - model_accuracy: 0.5000 - model_1_accuracy: 0.5000 - model_2_accuracy: 0.6667 - model_3_accuracy: 0.6111 - model_4_accuracy: 0.6111 - loss1: 4.4409 - loss2: 6.8278 - val_loss: 15.2369 - val_model_loss: 1.8727 - val_model_1_loss: 1.8477 - val_model_2_loss: 1.7665 - val_model_3_loss: 1.8673 - val_model_4_loss: 1.8261 - val_model_accuracy: 0.1754 - val_model_1_accuracy: 0.2483 - val_model_2_accuracy: 0.2721 - val_model_3_accuracy: 0.2292 - val_model_4_accuracy: 0.2058 - val_loss1: 5.7812 - val_loss2: 9.1784
# Epoch 41/300
# 2/2 [==============================] - 2s 2s/step - loss: 9.2573 - model_loss: 0.9025 - model_1_loss: 0.8264 - model_2_loss: 0.7943 - model_3_loss: 1.0520 - model_4_loss: 0.9471 - model_accuracy: 0.7222 - model_1_accuracy: 0.7222 - model_2_accuracy: 0.7778 - model_3_accuracy: 0.6667 - model_4_accuracy: 0.7778 - loss1: 4.4881 - loss2: 6.7336 - val_loss: 15.0774 - val_model_loss: 1.8396 - val_model_1_loss: 1.8324 - val_model_2_loss: 1.7644 - val_model_3_loss: 1.8456 - val_model_4_loss: 1.8198 - val_model_accuracy: 0.1796 - val_model_1_accuracy: 0.2246 - val_model_2_accuracy: 0.2679 - val_model_3_accuracy: 0.2025 - val_model_4_accuracy: 0.2025 - val_loss1: 5.7011 - val_loss2: 9.1489
# Epoch 42/300
# 2/2 [==============================] - 2s 2s/step - loss: 10.2320 - model_loss: 1.0332 - model_1_loss: 1.0982 - model_2_loss: 1.1459 - model_3_loss: 1.2123 - model_4_loss: 1.1727 - model_accuracy: 0.6667 - model_1_accuracy: 0.6111 - model_2_accuracy: 0.6111 - model_3_accuracy: 0.4444 - model_4_accuracy: 0.6111 - loss1: 4.3847 - loss2: 6.6724 - val_loss: 14.9759 - val_model_loss: 1.8426 - val_model_1_loss: 1.8562 - val_model_2_loss: 1.7743 - val_model_3_loss: 1.8056 - val_model_4_loss: 1.8097 - val_model_accuracy: 0.1946 - val_model_1_accuracy: 0.1988 - val_model_2_accuracy: 0.2392 - val_model_3_accuracy: 0.2129 - val_model_4_accuracy: 0.2000 - val_loss1: 5.6139 - val_loss2: 9.1167
# Epoch 43/300
# 2/2 [==============================] - 2s 2s/step - loss: 8.9848 - model_loss: 0.7208 - model_1_loss: 0.6607 - model_2_loss: 1.1341 - model_3_loss: 1.1634 - model_4_loss: 0.8530 - model_accuracy: 0.7778 - model_1_accuracy: 0.7222 - model_2_accuracy: 0.6667 - model_3_accuracy: 0.5556 - model_4_accuracy: 0.7778 - loss1: 4.2364 - loss2: 6.5484 - val_loss: 14.9146 - val_model_loss: 1.8634 - val_model_1_loss: 1.8600 - val_model_2_loss: 1.7841 - val_model_3_loss: 1.7957 - val_model_4_loss: 1.7935 - val_model_accuracy: 0.2050 - val_model_1_accuracy: 0.1833 - val_model_2_accuracy: 0.2338 - val_model_3_accuracy: 0.2171 - val_model_4_accuracy: 0.2075 - val_loss1: 5.5452 - val_loss2: 9.0897
# Epoch 44/300
# 2/2 [==============================] - 2s 2s/step - loss: 8.1088 - model_loss: 0.8491 - model_1_loss: 0.4801 - model_2_loss: 0.9419 - model_3_loss: 0.8490 - model_4_loss: 0.5486 - model_accuracy: 0.6667 - model_1_accuracy: 0.8889 - model_2_accuracy: 0.8333 - model_3_accuracy: 0.7222 - model_4_accuracy: 0.8889 - loss1: 4.1937 - loss2: 6.6313 - val_loss: 14.8956 - val_model_loss: 1.8938 - val_model_1_loss: 1.8722 - val_model_2_loss: 1.8003 - val_model_3_loss: 1.8034 - val_model_4_loss: 1.7839 - val_model_accuracy: 0.1954 - val_model_1_accuracy: 0.1800 - val_model_2_accuracy: 0.2321 - val_model_3_accuracy: 0.2138 - val_model_4_accuracy: 0.2233 - val_loss1: 5.4703 - val_loss2: 9.0579
# Epoch 45/300
# 2/2 [==============================] - 3s 2s/step - loss: 8.4448 - model_loss: 0.6299 - model_1_loss: 0.5770 - model_2_loss: 0.9311 - model_3_loss: 0.9079 - model_4_loss: 0.8575 - model_accuracy: 0.8333 - model_1_accuracy: 0.9444 - model_2_accuracy: 0.7222 - model_3_accuracy: 0.7778 - model_4_accuracy: 0.7222 - loss1: 4.3238 - loss2: 6.5276 - val_loss: 14.8761 - val_model_loss: 1.9331 - val_model_1_loss: 1.8549 - val_model_2_loss: 1.8059 - val_model_3_loss: 1.8136 - val_model_4_loss: 1.7970 - val_model_accuracy: 0.1796 - val_model_1_accuracy: 0.1804 - val_model_2_accuracy: 0.2367 - val_model_3_accuracy: 0.2117 - val_model_4_accuracy: 0.2375 - val_loss1: 5.4009 - val_loss2: 9.0218
# Epoch 46/300
# 2/2 [==============================] - 2s 2s/step - loss: 8.5070 - model_loss: 0.5194 - model_1_loss: 0.8793 - model_2_loss: 0.8643 - model_3_loss: 0.6695 - model_4_loss: 0.8513 - model_accuracy: 0.8889 - model_1_accuracy: 0.7778 - model_2_accuracy: 0.7222 - model_3_accuracy: 0.7778 - model_4_accuracy: 0.7778 - loss1: 4.4940 - loss2: 6.6483 - val_loss: 14.8479 - val_model_loss: 1.9683 - val_model_1_loss: 1.8221 - val_model_2_loss: 1.8096 - val_model_3_loss: 1.8220 - val_model_4_loss: 1.8249 - val_model_accuracy: 0.1762 - val_model_1_accuracy: 0.1917 - val_model_2_accuracy: 0.2283 - val_model_3_accuracy: 0.2021 - val_model_4_accuracy: 0.2142 - val_loss1: 5.3315 - val_loss2: 8.9838
# Epoch 47/300
# 2/2 [==============================] - 2s 2s/step - loss: 9.5737 - model_loss: 1.3620 - model_1_loss: 1.0605 - model_2_loss: 0.9895 - model_3_loss: 0.8773 - model_4_loss: 0.9606 - model_accuracy: 0.4444 - model_1_accuracy: 0.6667 - model_2_accuracy: 0.7778 - model_3_accuracy: 0.6111 - model_4_accuracy: 0.5556 - loss1: 4.0942 - loss2: 6.5541 - val_loss: 14.8035 - val_model_loss: 1.9556 - val_model_1_loss: 1.8471 - val_model_2_loss: 1.7976 - val_model_3_loss: 1.8249 - val_model_4_loss: 1.8361 - val_model_accuracy: 0.1879 - val_model_1_accuracy: 0.2392 - val_model_2_accuracy: 0.2121 - val_model_3_accuracy: 0.1963 - val_model_4_accuracy: 0.2079 - val_loss1: 5.2734 - val_loss2: 8.9621
# Epoch 48/300
# 2/2 [==============================] - 2s 2s/step - loss: 9.9531 - model_loss: 0.8721 - model_1_loss: 1.0676 - model_2_loss: 1.2233 - model_3_loss: 1.2598 - model_4_loss: 1.2100 - model_accuracy: 0.5000 - model_1_accuracy: 0.6111 - model_2_accuracy: 0.5000 - model_3_accuracy: 0.5556 - model_4_accuracy: 0.4444 - loss1: 4.1232 - loss2: 6.5354 - val_loss: 14.7261 - val_model_loss: 1.9931 - val_model_1_loss: 1.8241 - val_model_2_loss: 1.7970 - val_model_3_loss: 1.8048 - val_model_4_loss: 1.8459 - val_model_accuracy: 0.1996 - val_model_1_accuracy: 0.2579 - val_model_2_accuracy: 0.2125 - val_model_3_accuracy: 0.2229 - val_model_4_accuracy: 0.2004 - val_loss1: 5.1930 - val_loss2: 8.9412
# Epoch 49/300
# 2/2 [==============================] - 2s 2s/step - loss: 9.5400 - model_loss: 0.8487 - model_1_loss: 1.3709 - model_2_loss: 1.1353 - model_3_loss: 1.1693 - model_4_loss: 0.7384 - model_accuracy: 0.7222 - model_1_accuracy: 0.5556 - model_2_accuracy: 0.6667 - model_3_accuracy: 0.6111 - model_4_accuracy: 0.7222 - loss1: 4.0786 - loss2: 6.3738 - val_loss: 14.6596 - val_model_loss: 2.0379 - val_model_1_loss: 1.7890 - val_model_2_loss: 1.8130 - val_model_3_loss: 1.7978 - val_model_4_loss: 1.8459 - val_model_accuracy: 0.2054 - val_model_1_accuracy: 0.2887 - val_model_2_accuracy: 0.2058 - val_model_3_accuracy: 0.2379 - val_model_4_accuracy: 0.2054 - val_loss1: 5.1084 - val_loss2: 8.9199
# Epoch 50/300
# 2/2 [==============================] - 2s 2s/step - loss: 9.3269 - model_loss: 1.2099 - model_1_loss: 0.8268 - model_2_loss: 0.9641 - model_3_loss: 1.0548 - model_4_loss: 1.1865 - model_accuracy: 0.7222 - model_1_accuracy: 0.7222 - model_2_accuracy: 0.8333 - model_3_accuracy: 0.7222 - model_4_accuracy: 0.5000 - loss1: 3.8702 - loss2: 6.5526 - val_loss: 14.6424 - val_model_loss: 2.0293 - val_model_1_loss: 1.8082 - val_model_2_loss: 1.8396 - val_model_3_loss: 1.8067 - val_model_4_loss: 1.8528 - val_model_accuracy: 0.1996 - val_model_1_accuracy: 0.2596 - val_model_2_accuracy: 0.2271 - val_model_3_accuracy: 0.2408 - val_model_4_accuracy: 0.2029 - val_loss1: 5.0385 - val_loss2: 8.9063
# Epoch 51/300
# 2/2 [==============================] - 2s 2s/step - loss: 9.2384 - model_loss: 1.0632 - model_1_loss: 0.9555 - model_2_loss: 1.0131 - model_3_loss: 1.0639 - model_4_loss: 0.7735 - model_accuracy: 0.6667 - model_1_accuracy: 0.7222 - model_2_accuracy: 0.5556 - model_3_accuracy: 0.6111 - model_4_accuracy: 0.7222 - loss1: 4.1644 - loss2: 6.5541 - val_loss: 14.7545 - val_model_loss: 2.0259 - val_model_1_loss: 1.8437 - val_model_2_loss: 1.8957 - val_model_3_loss: 1.8394 - val_model_4_loss: 1.9217 - val_model_accuracy: 0.1792 - val_model_1_accuracy: 0.2721 - val_model_2_accuracy: 0.1929 - val_model_3_accuracy: 0.2342 - val_model_4_accuracy: 0.1946 - val_loss1: 4.9616 - val_loss2: 8.8801
# Epoch 52/300
# 2/2 [==============================] - 2s 2s/step - loss: 8.5081 - model_loss: 0.9168 - model_1_loss: 0.8447 - model_2_loss: 0.9144 - model_3_loss: 0.7607 - model_4_loss: 0.8770 - model_accuracy: 0.6111 - model_1_accuracy: 0.7222 - model_2_accuracy: 0.8333 - model_3_accuracy: 0.7778 - model_4_accuracy: 0.7222 - loss1: 3.9747 - loss2: 6.4507 - val_loss: 14.7553 - val_model_loss: 2.0024 - val_model_1_loss: 1.8611 - val_model_2_loss: 1.9293 - val_model_3_loss: 1.8449 - val_model_4_loss: 1.9597 - val_model_accuracy: 0.1700 - val_model_1_accuracy: 0.2867 - val_model_2_accuracy: 0.1775 - val_model_3_accuracy: 0.2533 - val_model_4_accuracy: 0.1921 - val_loss1: 4.8922 - val_loss2: 8.8568
# Epoch 53/300
# 2/2 [==============================] - 2s 2s/step - loss: 7.8547 - model_loss: 0.7050 - model_1_loss: 0.5260 - model_2_loss: 0.9797 - model_3_loss: 0.6773 - model_4_loss: 0.7032 - model_accuracy: 0.7778 - model_1_accuracy: 0.8889 - model_2_accuracy: 0.6667 - model_3_accuracy: 0.7778 - model_4_accuracy: 0.7778 - loss1: 4.0620 - loss2: 6.5096 - val_loss: 14.6257 - val_model_loss: 1.9819 - val_model_1_loss: 1.8740 - val_model_2_loss: 1.8841 - val_model_3_loss: 1.8331 - val_model_4_loss: 1.9648 - val_model_accuracy: 0.1713 - val_model_1_accuracy: 0.2629 - val_model_2_accuracy: 0.2463 - val_model_3_accuracy: 0.2558 - val_model_4_accuracy: 0.1767 - val_loss1: 4.8226 - val_loss2: 8.8392
# Epoch 54/300
# 2/2 [==============================] - 2s 2s/step - loss: 9.2320 - model_loss: 0.8361 - model_1_loss: 0.9774 - model_2_loss: 1.3740 - model_3_loss: 0.9216 - model_4_loss: 1.0972 - model_accuracy: 0.7222 - model_1_accuracy: 0.6111 - model_2_accuracy: 0.4444 - model_3_accuracy: 0.7222 - model_4_accuracy: 0.6667 - loss1: 3.8291 - loss2: 6.4068 - val_loss: 14.4921 - val_model_loss: 1.9906 - val_model_1_loss: 1.8943 - val_model_2_loss: 1.8383 - val_model_3_loss: 1.8250 - val_model_4_loss: 1.9363 - val_model_accuracy: 0.1721 - val_model_1_accuracy: 0.2096 - val_model_2_accuracy: 0.2554 - val_model_3_accuracy: 0.2421 - val_model_4_accuracy: 0.1775 - val_loss1: 4.7432 - val_loss2: 8.8154
# Epoch 55/300
# 2/2 [==============================] - 2s 2s/step - loss: 8.4226 - model_loss: 0.8062 - model_1_loss: 0.6945 - model_2_loss: 1.1623 - model_3_loss: 0.8254 - model_4_loss: 0.9778 - model_accuracy: 0.7778 - model_1_accuracy: 0.8333 - model_2_accuracy: 0.5556 - model_3_accuracy: 0.6111 - model_4_accuracy: 0.5556 - loss1: 3.7514 - loss2: 6.4273 - val_loss: 14.4036 - val_model_loss: 2.0701 - val_model_1_loss: 1.8893 - val_model_2_loss: 1.8129 - val_model_3_loss: 1.8253 - val_model_4_loss: 1.8702 - val_model_accuracy: 0.1721 - val_model_1_accuracy: 0.2025 - val_model_2_accuracy: 0.2237 - val_model_3_accuracy: 0.2333 - val_model_4_accuracy: 0.1875 - val_loss1: 4.6723 - val_loss2: 8.7859
# Epoch 56/300
# 2/2 [==============================] - 2s 2s/step - loss: 7.5707 - model_loss: 0.6799 - model_1_loss: 0.6926 - model_2_loss: 0.7301 - model_3_loss: 0.8337 - model_4_loss: 0.6286 - model_accuracy: 0.8333 - model_1_accuracy: 0.6667 - model_2_accuracy: 0.7222 - model_3_accuracy: 0.7222 - model_4_accuracy: 0.7778 - loss1: 3.7887 - loss2: 6.4274 - val_loss: 14.3296 - val_model_loss: 2.1204 - val_model_1_loss: 1.8799 - val_model_2_loss: 1.8104 - val_model_3_loss: 1.8425 - val_model_4_loss: 1.8081 - val_model_accuracy: 0.1842 - val_model_1_accuracy: 0.2033 - val_model_2_accuracy: 0.2133 - val_model_3_accuracy: 0.2133 - val_model_4_accuracy: 0.2013 - val_loss1: 4.6057 - val_loss2: 8.7540
# Epoch 57/300
# 2/2 [==============================] - 2s 2s/step - loss: 8.5242 - model_loss: 0.8051 - model_1_loss: 0.9449 - model_2_loss: 0.8743 - model_3_loss: 0.9823 - model_4_loss: 0.7707 - model_accuracy: 0.8889 - model_1_accuracy: 0.6667 - model_2_accuracy: 0.7778 - model_3_accuracy: 0.6111 - model_4_accuracy: 0.6667 - loss1: 3.9295 - loss2: 6.5416 - val_loss: 14.3749 - val_model_loss: 2.1905 - val_model_1_loss: 1.8959 - val_model_2_loss: 1.8326 - val_model_3_loss: 1.8558 - val_model_4_loss: 1.8038 - val_model_accuracy: 0.1904 - val_model_1_accuracy: 0.1858 - val_model_2_accuracy: 0.2283 - val_model_3_accuracy: 0.2054 - val_model_4_accuracy: 0.1904 - val_loss1: 4.5349 - val_loss2: 8.7188
# Epoch 58/300
# 2/2 [==============================] - 2s 2s/step - loss: 7.7370 - model_loss: 0.6298 - model_1_loss: 0.7824 - model_2_loss: 0.7621 - model_3_loss: 0.7837 - model_4_loss: 0.7693 - model_accuracy: 0.8333 - model_1_accuracy: 0.6667 - model_2_accuracy: 0.6667 - model_3_accuracy: 0.7778 - model_4_accuracy: 0.6667 - loss1: 3.8059 - loss2: 6.4098 - val_loss: 14.4994 - val_model_loss: 2.2192 - val_model_1_loss: 1.9556 - val_model_2_loss: 1.8537 - val_model_3_loss: 1.8604 - val_model_4_loss: 1.8597 - val_model_accuracy: 0.1821 - val_model_1_accuracy: 0.1737 - val_model_2_accuracy: 0.2404 - val_model_3_accuracy: 0.1988 - val_model_4_accuracy: 0.1854 - val_loss1: 4.4904 - val_loss2: 8.6796
# Epoch 59/300
# 2/2 [==============================] - 2s 2s/step - loss: 7.3182 - model_loss: 0.6985 - model_1_loss: 0.5712 - model_2_loss: 0.7363 - model_3_loss: 0.7736 - model_4_loss: 0.6575 - model_accuracy: 0.8333 - model_1_accuracy: 0.7778 - model_2_accuracy: 0.7778 - model_3_accuracy: 0.7222 - model_4_accuracy: 0.8333 - loss1: 3.6754 - loss2: 6.4297 - val_loss: 14.5712 - val_model_loss: 2.2411 - val_model_1_loss: 1.9710 - val_model_2_loss: 1.8659 - val_model_3_loss: 1.8786 - val_model_4_loss: 1.9062 - val_model_accuracy: 0.1758 - val_model_1_accuracy: 0.1733 - val_model_2_accuracy: 0.2267 - val_model_3_accuracy: 0.1921 - val_model_4_accuracy: 0.1817 - val_loss1: 4.4493 - val_loss2: 8.6374
# Epoch 60/300
# 2/2 [==============================] - 2s 2s/step - loss: 6.4200 - model_loss: 0.4079 - model_1_loss: 0.5647 - model_2_loss: 0.4962 - model_3_loss: 0.5667 - model_4_loss: 0.4395 - model_accuracy: 0.8889 - model_1_accuracy: 0.7778 - model_2_accuracy: 0.8333 - model_3_accuracy: 0.8889 - model_4_accuracy: 0.8889 - loss1: 3.7478 - loss2: 6.3061 - val_loss: 14.6399 - val_model_loss: 2.2603 - val_model_1_loss: 1.9909 - val_model_2_loss: 1.8744 - val_model_3_loss: 1.8993 - val_model_4_loss: 1.9337 - val_model_accuracy: 0.1713 - val_model_1_accuracy: 0.1721 - val_model_2_accuracy: 0.2179 - val_model_3_accuracy: 0.2017 - val_model_4_accuracy: 0.1846 - val_loss1: 4.4236 - val_loss2: 8.5918
# Epoch 61/300
# 2/2 [==============================] - 2s 2s/step - loss: 6.3353 - model_loss: 0.4259 - model_1_loss: 0.5173 - model_2_loss: 0.5784 - model_3_loss: 0.4234 - model_4_loss: 0.4060 - model_accuracy: 0.8333 - model_1_accuracy: 0.8333 - model_2_accuracy: 0.8889 - model_3_accuracy: 0.8333 - model_4_accuracy: 0.9444 - loss1: 3.7916 - loss2: 6.3041 - val_loss: 14.6925 - val_model_loss: 2.2708 - val_model_1_loss: 2.0118 - val_model_2_loss: 1.8851 - val_model_3_loss: 1.9421 - val_model_4_loss: 1.9312 - val_model_accuracy: 0.1717 - val_model_1_accuracy: 0.1838 - val_model_2_accuracy: 0.2442 - val_model_3_accuracy: 0.2017 - val_model_4_accuracy: 0.1867 - val_loss1: 4.3953 - val_loss2: 8.5406
# Epoch 62/300
# 2/2 [==============================] - 3s 2s/step - loss: 7.8084 - model_loss: 0.8992 - model_1_loss: 0.6978 - model_2_loss: 0.6081 - model_3_loss: 0.9509 - model_4_loss: 0.7960 - model_accuracy: 0.7222 - model_1_accuracy: 0.7222 - model_2_accuracy: 0.8333 - model_3_accuracy: 0.6667 - model_4_accuracy: 0.6667 - loss1: 3.6566 - loss2: 6.2655 - val_loss: 14.7721 - val_model_loss: 2.2984 - val_model_1_loss: 2.0325 - val_model_2_loss: 1.9215 - val_model_3_loss: 2.0211 - val_model_4_loss: 1.9003 - val_model_accuracy: 0.1737 - val_model_1_accuracy: 0.1996 - val_model_2_accuracy: 0.2600 - val_model_3_accuracy: 0.2033 - val_model_4_accuracy: 0.1867 - val_loss1: 4.3435 - val_loss2: 8.4892
# Epoch 63/300
# 2/2 [==============================] - 2s 2s/step - loss: 6.1633 - model_loss: 0.4579 - model_1_loss: 0.3436 - model_2_loss: 0.7843 - model_3_loss: 0.3345 - model_4_loss: 0.5865 - model_accuracy: 0.8333 - model_1_accuracy: 0.8889 - model_2_accuracy: 0.6667 - model_3_accuracy: 0.9444 - model_4_accuracy: 0.8333 - loss1: 3.4799 - loss2: 6.1156 - val_loss: 14.9002 - val_model_loss: 2.3450 - val_model_1_loss: 2.0846 - val_model_2_loss: 1.9337 - val_model_3_loss: 2.0697 - val_model_4_loss: 1.9118 - val_model_accuracy: 0.1808 - val_model_1_accuracy: 0.1971 - val_model_2_accuracy: 0.2121 - val_model_3_accuracy: 0.1950 - val_model_4_accuracy: 0.1979 - val_loss1: 4.3022 - val_loss2: 8.4396
# Epoch 64/300
# 2/2 [==============================] - 2s 2s/step - loss: 6.1415 - model_loss: 0.4061 - model_1_loss: 0.5099 - model_2_loss: 0.6092 - model_3_loss: 0.4853 - model_4_loss: 0.3111 - model_accuracy: 0.8889 - model_1_accuracy: 0.8333 - model_2_accuracy: 0.8333 - model_3_accuracy: 0.8889 - model_4_accuracy: 1.0000 - loss1: 3.6162 - loss2: 6.1327 - val_loss: 14.7844 - val_model_loss: 2.2732 - val_model_1_loss: 2.0681 - val_model_2_loss: 1.9371 - val_model_3_loss: 2.0632 - val_model_4_loss: 1.9258 - val_model_accuracy: 0.1933 - val_model_1_accuracy: 0.1871 - val_model_2_accuracy: 0.1871 - val_model_3_accuracy: 0.1958 - val_model_4_accuracy: 0.1971 - val_loss1: 4.2651 - val_loss2: 8.4003
# Epoch 65/300
# 2/2 [==============================] - 2s 2s/step - loss: 8.2283 - model_loss: 0.6534 - model_1_loss: 0.9315 - model_2_loss: 0.8558 - model_3_loss: 1.0509 - model_4_loss: 0.9436 - model_accuracy: 0.7222 - model_1_accuracy: 0.6667 - model_2_accuracy: 0.7778 - model_3_accuracy: 0.6111 - model_4_accuracy: 0.6667 - loss1: 3.5979 - loss2: 6.1280 - val_loss: 14.6977 - val_model_loss: 2.2425 - val_model_1_loss: 2.0437 - val_model_2_loss: 1.9207 - val_model_3_loss: 2.0722 - val_model_4_loss: 1.9413 - val_model_accuracy: 0.2021 - val_model_1_accuracy: 0.1858 - val_model_2_accuracy: 0.2050 - val_model_3_accuracy: 0.2008 - val_model_4_accuracy: 0.1933 - val_loss1: 4.2263 - val_loss2: 8.3658
# Epoch 66/300
# 2/2 [==============================] - 3s 3s/step - loss: 7.2170 - model_loss: 0.8205 - model_1_loss: 0.6913 - model_2_loss: 0.5600 - model_3_loss: 0.6763 - model_4_loss: 0.6312 - model_accuracy: 0.7222 - model_1_accuracy: 0.8333 - model_2_accuracy: 0.8889 - model_3_accuracy: 0.7222 - model_4_accuracy: 0.8333 - loss1: 3.6556 - loss2: 6.1876 - val_loss: 14.6277 - val_model_loss: 2.2352 - val_model_1_loss: 2.0296 - val_model_2_loss: 1.9186 - val_model_3_loss: 2.0898 - val_model_4_loss: 1.9167 - val_model_accuracy: 0.1979 - val_model_1_accuracy: 0.1946 - val_model_2_accuracy: 0.2296 - val_model_3_accuracy: 0.2092 - val_model_4_accuracy: 0.1929 - val_loss1: 4.1876 - val_loss2: 8.3379
# Epoch 67/300
# 2/2 [==============================] - 3s 2s/step - loss: 6.7029 - model_loss: 0.4853 - model_1_loss: 0.6509 - model_2_loss: 0.6565 - model_3_loss: 0.6930 - model_4_loss: 0.5163 - model_accuracy: 0.8333 - model_1_accuracy: 0.8333 - model_2_accuracy: 0.7778 - model_3_accuracy: 0.8333 - model_4_accuracy: 0.8333 - loss1: 3.5059 - loss2: 6.1023 - val_loss: 14.5451 - val_model_loss: 2.1832 - val_model_1_loss: 2.1058 - val_model_2_loss: 1.9064 - val_model_3_loss: 2.0840 - val_model_4_loss: 1.8587 - val_model_accuracy: 0.2050 - val_model_1_accuracy: 0.2013 - val_model_2_accuracy: 0.1954 - val_model_3_accuracy: 0.1975 - val_model_4_accuracy: 0.2229 - val_loss1: 4.1577 - val_loss2: 8.3106
# Epoch 68/300
# 2/2 [==============================] - 2s 2s/step - loss: 9.3923 - model_loss: 1.3740 - model_1_loss: 1.1830 - model_2_loss: 1.2530 - model_3_loss: 1.1002 - model_4_loss: 0.7637 - model_accuracy: 0.5556 - model_1_accuracy: 0.6111 - model_2_accuracy: 0.6667 - model_3_accuracy: 0.5556 - model_4_accuracy: 0.6667 - loss1: 3.5212 - loss2: 6.1541 - val_loss: 14.4797 - val_model_loss: 2.1273 - val_model_1_loss: 2.1826 - val_model_2_loss: 1.9063 - val_model_3_loss: 1.9977 - val_model_4_loss: 1.8876 - val_model_accuracy: 0.2121 - val_model_1_accuracy: 0.1858 - val_model_2_accuracy: 0.1842 - val_model_3_accuracy: 0.2046 - val_model_4_accuracy: 0.2313 - val_loss1: 4.1294 - val_loss2: 8.2915
# Epoch 69/300
# ...
# Epoch 279/300
# 2/2 [==============================] - 2s 2s/step - loss: 3.6053 - model_loss: 0.3049 - model_1_loss: 0.3514 - model_2_loss: 0.2609 - model_3_loss: 0.3605 - model_4_loss: 0.3903 - model_accuracy: 0.9444 - model_1_accuracy: 0.9444 - model_2_accuracy: 0.9444 - model_3_accuracy: 0.9444 - model_4_accuracy: 0.8889 - loss1: 1.7617 - loss2: 6.0372 - val_loss: 13.3329 - val_model_loss: 2.0909 - val_model_1_loss: 2.4258 - val_model_2_loss: 2.1492 - val_model_3_loss: 2.3616 - val_model_4_loss: 2.1868 - val_model_accuracy: 0.3063 - val_model_1_accuracy: 0.3013 - val_model_2_accuracy: 0.2925 - val_model_3_accuracy: 0.2550 - val_model_4_accuracy: 0.2887 - val_loss1: 1.9333 - val_loss2: 6.1805
# Epoch 280/300
# 2/2 [==============================] - 2s 2s/step - loss: 3.5438 - model_loss: 0.3282 - model_1_loss: 0.2748 - model_2_loss: 0.2906 - model_3_loss: 0.2998 - model_4_loss: 0.4956 - model_accuracy: 0.8889 - model_1_accuracy: 0.8889 - model_2_accuracy: 0.9444 - model_3_accuracy: 0.8889 - model_4_accuracy: 0.8333 - loss1: 1.6593 - loss2: 6.0458 - val_loss: 13.1949 - val_model_loss: 2.0165 - val_model_1_loss: 2.4695 - val_model_2_loss: 2.1648 - val_model_3_loss: 2.4218 - val_model_4_loss: 2.0198 - val_model_accuracy: 0.3083 - val_model_1_accuracy: 0.2937 - val_model_2_accuracy: 0.2912 - val_model_3_accuracy: 0.2442 - val_model_4_accuracy: 0.2971 - val_loss1: 1.9161 - val_loss2: 6.2112
# Epoch 281/300
# 2/2 [==============================] - 2s 2s/step - loss: 3.5685 - model_loss: 0.2848 - model_1_loss: 0.3244 - model_2_loss: 0.5130 - model_3_loss: 0.2537 - model_4_loss: 0.2417 - model_accuracy: 0.8889 - model_1_accuracy: 0.8889 - model_2_accuracy: 0.9444 - model_3_accuracy: 0.8889 - model_4_accuracy: 0.9444 - loss1: 1.7534 - loss2: 6.0187 - val_loss: 13.2141 - val_model_loss: 2.0742 - val_model_1_loss: 2.4264 - val_model_2_loss: 2.2921 - val_model_3_loss: 2.3640 - val_model_4_loss: 1.9762 - val_model_accuracy: 0.2950 - val_model_1_accuracy: 0.2788 - val_model_2_accuracy: 0.2821 - val_model_3_accuracy: 0.2496 - val_model_4_accuracy: 0.2788 - val_loss1: 1.8940 - val_loss2: 6.2377
# Epoch 282/300
# 2/2 [==============================] - 2s 2s/step - loss: 3.9500 - model_loss: 0.4248 - model_1_loss: 0.3942 - model_2_loss: 0.3790 - model_3_loss: 0.4396 - model_4_loss: 0.5235 - model_accuracy: 0.7778 - model_1_accuracy: 0.7778 - model_2_accuracy: 0.8889 - model_3_accuracy: 0.8333 - model_4_accuracy: 0.8333 - loss1: 1.5982 - loss2: 6.1628 - val_loss: 13.1840 - val_model_loss: 2.1715 - val_model_1_loss: 2.4009 - val_model_2_loss: 2.3623 - val_model_3_loss: 2.2324 - val_model_4_loss: 1.9573 - val_model_accuracy: 0.2842 - val_model_1_accuracy: 0.2875 - val_model_2_accuracy: 0.2667 - val_model_3_accuracy: 0.2646 - val_model_4_accuracy: 0.2637 - val_loss1: 1.8722 - val_loss2: 6.2464
# Epoch 283/300
# 2/2 [==============================] - 2s 2s/step - loss: 2.8553 - model_loss: 0.1915 - model_1_loss: 0.1258 - model_2_loss: 0.2042 - model_3_loss: 0.3066 - model_4_loss: 0.2350 - model_accuracy: 0.9444 - model_1_accuracy: 0.9444 - model_2_accuracy: 0.9444 - model_3_accuracy: 0.8333 - model_4_accuracy: 0.9444 - loss1: 1.6042 - loss2: 6.1392 - val_loss: 13.7720 - val_model_loss: 2.2253 - val_model_1_loss: 2.7840 - val_model_2_loss: 2.4691 - val_model_3_loss: 2.2515 - val_model_4_loss: 1.9980 - val_model_accuracy: 0.2887 - val_model_1_accuracy: 0.2463 - val_model_2_accuracy: 0.2321 - val_model_3_accuracy: 0.2421 - val_model_4_accuracy: 0.2696 - val_loss1: 1.8567 - val_loss2: 6.2459
# Epoch 284/300
# 2/2 [==============================] - 2s 2s/step - loss: 5.0855 - model_loss: 0.7986 - model_1_loss: 0.8513 - model_2_loss: 0.4328 - model_3_loss: 0.6236 - model_4_loss: 0.5639 - model_accuracy: 0.7778 - model_1_accuracy: 0.7222 - model_2_accuracy: 0.7778 - model_3_accuracy: 0.8333 - model_4_accuracy: 0.7778 - loss1: 1.6189 - loss2: 6.1435 - val_loss: 13.5857 - val_model_loss: 2.1886 - val_model_1_loss: 2.6379 - val_model_2_loss: 2.2802 - val_model_3_loss: 2.3424 - val_model_4_loss: 2.1060 - val_model_accuracy: 0.2933 - val_model_1_accuracy: 0.2575 - val_model_2_accuracy: 0.2300 - val_model_3_accuracy: 0.2167 - val_model_4_accuracy: 0.2808 - val_loss1: 1.8431 - val_loss2: 6.2498
# Epoch 285/300
# 2/2 [==============================] - 3s 2s/step - loss: 6.2831 - model_loss: 0.7447 - model_1_loss: 1.1357 - model_2_loss: 0.7353 - model_3_loss: 0.8463 - model_4_loss: 0.9173 - model_accuracy: 0.7222 - model_1_accuracy: 0.6667 - model_2_accuracy: 0.7222 - model_3_accuracy: 0.8333 - model_4_accuracy: 0.6111 - loss1: 1.7034 - loss2: 6.3636 - val_loss: 12.8626 - val_model_loss: 2.1933 - val_model_1_loss: 2.2254 - val_model_2_loss: 2.0394 - val_model_3_loss: 2.2464 - val_model_4_loss: 2.1413 - val_model_accuracy: 0.3079 - val_model_1_accuracy: 0.3113 - val_model_2_accuracy: 0.2438 - val_model_3_accuracy: 0.2192 - val_model_4_accuracy: 0.2983 - val_loss1: 1.8285 - val_loss2: 6.2738
# Epoch 286/300
# 2/2 [==============================] - 3s 2s/step - loss: 3.8556 - model_loss: 0.5383 - model_1_loss: 0.3882 - model_2_loss: 0.4649 - model_3_loss: 0.3509 - model_4_loss: 0.2869 - model_accuracy: 0.8333 - model_1_accuracy: 0.8889 - model_2_accuracy: 0.8333 - model_3_accuracy: 0.8333 - model_4_accuracy: 0.8889 - loss1: 1.6293 - loss2: 6.2286 - val_loss: 12.9611 - val_model_loss: 2.2122 - val_model_1_loss: 2.2206 - val_model_2_loss: 1.9945 - val_model_3_loss: 2.2275 - val_model_4_loss: 2.3015 - val_model_accuracy: 0.2937 - val_model_1_accuracy: 0.3008 - val_model_2_accuracy: 0.2463 - val_model_3_accuracy: 0.2183 - val_model_4_accuracy: 0.2833 - val_loss1: 1.8164 - val_loss2: 6.2804
# Epoch 287/300
# 2/2 [==============================] - 3s 2s/step - loss: 3.6904 - model_loss: 0.3774 - model_1_loss: 0.2252 - model_2_loss: 0.5936 - model_3_loss: 0.3333 - model_4_loss: 0.3167 - model_accuracy: 0.8889 - model_1_accuracy: 0.9444 - model_2_accuracy: 0.7222 - model_3_accuracy: 0.8889 - model_4_accuracy: 0.8333 - loss1: 1.6512 - loss2: 6.2123 - val_loss: 13.2491 - val_model_loss: 2.2920 - val_model_1_loss: 2.2540 - val_model_2_loss: 1.9912 - val_model_3_loss: 2.3131 - val_model_4_loss: 2.4012 - val_model_accuracy: 0.2854 - val_model_1_accuracy: 0.2871 - val_model_2_accuracy: 0.2604 - val_model_3_accuracy: 0.2237 - val_model_4_accuracy: 0.2850 - val_loss1: 1.8093 - val_loss2: 6.2789
# Epoch 288/300
# 2/2 [==============================] - 2s 2s/step - loss: 5.0844 - model_loss: 0.5876 - model_1_loss: 0.9013 - model_2_loss: 0.6996 - model_3_loss: 0.7342 - model_4_loss: 0.4540 - model_accuracy: 0.7778 - model_1_accuracy: 0.6667 - model_2_accuracy: 0.7778 - model_3_accuracy: 0.7222 - model_4_accuracy: 0.7778 - loss1: 1.4981 - loss2: 6.2506 - val_loss: 13.5952 - val_model_loss: 2.4001 - val_model_1_loss: 2.2617 - val_model_2_loss: 2.1126 - val_model_3_loss: 2.3454 - val_model_4_loss: 2.4855 - val_model_accuracy: 0.2846 - val_model_1_accuracy: 0.2825 - val_model_2_accuracy: 0.2688 - val_model_3_accuracy: 0.2429 - val_model_4_accuracy: 0.2871 - val_loss1: 1.8010 - val_loss2: 6.2955
# Epoch 289/300
# 2/2 [==============================] - 2s 2s/step - loss: 2.9506 - model_loss: 0.2227 - model_1_loss: 0.2437 - model_2_loss: 0.3233 - model_3_loss: 0.2442 - model_4_loss: 0.1251 - model_accuracy: 0.8889 - model_1_accuracy: 0.9444 - model_2_accuracy: 0.9444 - model_3_accuracy: 1.0000 - model_4_accuracy: 1.0000 - loss1: 1.5954 - loss2: 6.1957 - val_loss: 14.3124 - val_model_loss: 2.7025 - val_model_1_loss: 2.4676 - val_model_2_loss: 2.2587 - val_model_3_loss: 2.4181 - val_model_4_loss: 2.4834 - val_model_accuracy: 0.2817 - val_model_1_accuracy: 0.2683 - val_model_2_accuracy: 0.2763 - val_model_3_accuracy: 0.2771 - val_model_4_accuracy: 0.2954 - val_loss1: 1.7932 - val_loss2: 6.2994
# Epoch 290/300
# 2/2 [==============================] - 2s 2s/step - loss: 3.2107 - model_loss: 0.3401 - model_1_loss: 0.3811 - model_2_loss: 0.2568 - model_3_loss: 0.2533 - model_4_loss: 0.3410 - model_accuracy: 0.8889 - model_1_accuracy: 0.8333 - model_2_accuracy: 0.8889 - model_3_accuracy: 0.8889 - model_4_accuracy: 0.9444 - loss1: 1.4479 - loss2: 6.1585 - val_loss: 13.9813 - val_model_loss: 2.7167 - val_model_1_loss: 2.1933 - val_model_2_loss: 2.2954 - val_model_3_loss: 2.4717 - val_model_4_loss: 2.3479 - val_model_accuracy: 0.2742 - val_model_1_accuracy: 0.2850 - val_model_2_accuracy: 0.2942 - val_model_3_accuracy: 0.2837 - val_model_4_accuracy: 0.2904 - val_loss1: 1.7668 - val_loss2: 6.3161
# Epoch 291/300
# 2/2 [==============================] - 2s 2s/step - loss: 3.2888 - model_loss: 0.2610 - model_1_loss: 0.3686 - model_2_loss: 0.2853 - model_3_loss: 0.5351 - model_4_loss: 0.2521 - model_accuracy: 0.9444 - model_1_accuracy: 0.8889 - model_2_accuracy: 0.8333 - model_3_accuracy: 0.7222 - model_4_accuracy: 0.8889 - loss1: 1.3871 - loss2: 6.2638 - val_loss: 14.1609 - val_model_loss: 2.7737 - val_model_1_loss: 2.1928 - val_model_2_loss: 2.4533 - val_model_3_loss: 2.5114 - val_model_4_loss: 2.2819 - val_model_accuracy: 0.2692 - val_model_1_accuracy: 0.2821 - val_model_2_accuracy: 0.2937 - val_model_3_accuracy: 0.2788 - val_model_4_accuracy: 0.2933 - val_loss1: 1.7580 - val_loss2: 6.3296
# Epoch 292/300
# 2/2 [==============================] - 2s 2s/step - loss: 5.0069 - model_loss: 0.6628 - model_1_loss: 0.4456 - model_2_loss: 0.8506 - model_3_loss: 0.7201 - model_4_loss: 0.6233 - model_accuracy: 0.7222 - model_1_accuracy: 0.7778 - model_2_accuracy: 0.6667 - model_3_accuracy: 0.7778 - model_4_accuracy: 0.7778 - loss1: 1.5019 - loss2: 6.4002 - val_loss: 13.9832 - val_model_loss: 2.5517 - val_model_1_loss: 2.1966 - val_model_2_loss: 2.7271 - val_model_3_loss: 2.4453 - val_model_4_loss: 2.1225 - val_model_accuracy: 0.2925 - val_model_1_accuracy: 0.2779 - val_model_2_accuracy: 0.2533 - val_model_3_accuracy: 0.2925 - val_model_4_accuracy: 0.3150 - val_loss1: 1.7492 - val_loss2: 6.3560
# Epoch 293/300
# 2/2 [==============================] - 2s 2s/step - loss: 4.7001 - model_loss: 0.7323 - model_1_loss: 0.5366 - model_2_loss: 0.7704 - model_3_loss: 0.4476 - model_4_loss: 0.4439 - model_accuracy: 0.7778 - model_1_accuracy: 0.7778 - model_2_accuracy: 0.6667 - model_3_accuracy: 0.8333 - model_4_accuracy: 0.8333 - loss1: 1.5538 - loss2: 6.3038 - val_loss: 13.3634 - val_model_loss: 2.2813 - val_model_1_loss: 2.1220 - val_model_2_loss: 2.5297 - val_model_3_loss: 2.2901 - val_model_4_loss: 2.1938 - val_model_accuracy: 0.2967 - val_model_1_accuracy: 0.2817 - val_model_2_accuracy: 0.2537 - val_model_3_accuracy: 0.2929 - val_model_4_accuracy: 0.3017 - val_loss1: 1.7547 - val_loss2: 6.3925
# Epoch 294/300
# 2/2 [==============================] - 2s 2s/step - loss: 3.0730 - model_loss: 0.1442 - model_1_loss: 0.4069 - model_2_loss: 0.3206 - model_3_loss: 0.3915 - model_4_loss: 0.2135 - model_accuracy: 0.9444 - model_1_accuracy: 0.8333 - model_2_accuracy: 0.8889 - model_3_accuracy: 0.8889 - model_4_accuracy: 0.9444 - loss1: 1.3948 - loss2: 6.2394 - val_loss: 13.1557 - val_model_loss: 2.2764 - val_model_1_loss: 2.1012 - val_model_2_loss: 2.3049 - val_model_3_loss: 2.1837 - val_model_4_loss: 2.3396 - val_model_accuracy: 0.2904 - val_model_1_accuracy: 0.2950 - val_model_2_accuracy: 0.2717 - val_model_3_accuracy: 0.2958 - val_model_4_accuracy: 0.2962 - val_loss1: 1.7569 - val_loss2: 6.4279
# Epoch 295/300
# 2/2 [==============================] - 2s 2s/step - loss: 3.0795 - model_loss: 0.1650 - model_1_loss: 0.2190 - model_2_loss: 0.4500 - model_3_loss: 0.1040 - model_4_loss: 0.4788 - model_accuracy: 0.9444 - model_1_accuracy: 1.0000 - model_2_accuracy: 0.7778 - model_3_accuracy: 1.0000 - model_4_accuracy: 0.8333 - loss1: 1.4578 - loss2: 6.4064 - val_loss: 12.9141 - val_model_loss: 2.3675 - val_model_1_loss: 2.1815 - val_model_2_loss: 2.0383 - val_model_3_loss: 2.1714 - val_model_4_loss: 2.1942 - val_model_accuracy: 0.2633 - val_model_1_accuracy: 0.2958 - val_model_2_accuracy: 0.2958 - val_model_3_accuracy: 0.2954 - val_model_4_accuracy: 0.3029 - val_loss1: 1.7678 - val_loss2: 6.4488
# Epoch 296/300
# 2/2 [==============================] - 2s 2s/step - loss: 2.8219 - model_loss: 0.1311 - model_1_loss: 0.2217 - model_2_loss: 0.1686 - model_3_loss: 0.3348 - model_4_loss: 0.3232 - model_accuracy: 0.9444 - model_1_accuracy: 0.8889 - model_2_accuracy: 0.9444 - model_3_accuracy: 0.8889 - model_4_accuracy: 0.8889 - loss1: 1.4439 - loss2: 6.2225 - val_loss: 12.9438 - val_model_loss: 2.4687 - val_model_1_loss: 2.3132 - val_model_2_loss: 1.9834 - val_model_3_loss: 2.1160 - val_model_4_loss: 2.0839 - val_model_accuracy: 0.2421 - val_model_1_accuracy: 0.2683 - val_model_2_accuracy: 0.2892 - val_model_3_accuracy: 0.2862 - val_model_4_accuracy: 0.2746 - val_loss1: 1.7847 - val_loss2: 6.4615
# Epoch 297/300
# 2/2 [==============================] - 2s 2s/step - loss: 4.2654 - model_loss: 0.5501 - model_1_loss: 0.4646 - model_2_loss: 0.5291 - model_3_loss: 0.6731 - model_4_loss: 0.3394 - model_accuracy: 0.8333 - model_1_accuracy: 0.8333 - model_2_accuracy: 0.7778 - model_3_accuracy: 0.7222 - model_4_accuracy: 0.8333 - loss1: 1.4876 - loss2: 6.5634 - val_loss: 13.0835 - val_model_loss: 2.3976 - val_model_1_loss: 2.3905 - val_model_2_loss: 1.9899 - val_model_3_loss: 2.1212 - val_model_4_loss: 2.1787 - val_model_accuracy: 0.2537 - val_model_1_accuracy: 0.2592 - val_model_2_accuracy: 0.2937 - val_model_3_accuracy: 0.2721 - val_model_4_accuracy: 0.2571 - val_loss1: 1.8116 - val_loss2: 6.4691
# Epoch 298/300
# 2/2 [==============================] - 3s 2s/step - loss: 4.4172 - model_loss: 0.4809 - model_1_loss: 0.4357 - model_2_loss: 0.7420 - model_3_loss: 0.4563 - model_4_loss: 0.6222 - model_accuracy: 0.7778 - model_1_accuracy: 0.9444 - model_2_accuracy: 0.7222 - model_3_accuracy: 0.9444 - model_4_accuracy: 0.7778 - loss1: 1.4745 - loss2: 6.5184 - val_loss: 13.1319 - val_model_loss: 2.4140 - val_model_1_loss: 2.5186 - val_model_2_loss: 2.0340 - val_model_3_loss: 2.0691 - val_model_4_loss: 2.0669 - val_model_accuracy: 0.2688 - val_model_1_accuracy: 0.2438 - val_model_2_accuracy: 0.2912 - val_model_3_accuracy: 0.2946 - val_model_4_accuracy: 0.2600 - val_loss1: 1.8352 - val_loss2: 6.4711
# Epoch 299/300
# 2/2 [==============================] - 3s 2s/step - loss: 3.8674 - model_loss: 0.4885 - model_1_loss: 0.4168 - model_2_loss: 0.5654 - model_3_loss: 0.1821 - model_4_loss: 0.4186 - model_accuracy: 0.7778 - model_1_accuracy: 0.8333 - model_2_accuracy: 0.8333 - model_3_accuracy: 1.0000 - model_4_accuracy: 0.8333 - loss1: 1.5828 - loss2: 6.5044 - val_loss: 13.1433 - val_model_loss: 2.5082 - val_model_1_loss: 2.4793 - val_model_2_loss: 1.9985 - val_model_3_loss: 2.0844 - val_model_4_loss: 2.0376 - val_model_accuracy: 0.2833 - val_model_1_accuracy: 0.2529 - val_model_2_accuracy: 0.2879 - val_model_3_accuracy: 0.3113 - val_model_4_accuracy: 0.2771 - val_loss1: 1.8415 - val_loss2: 6.4644
# Epoch 300/300
# 2/2 [==============================] - 2s 2s/step - loss: 2.9676 - model_loss: 0.2694 - model_1_loss: 0.2613 - model_2_loss: 0.1992 - model_3_loss: 0.1151 - model_4_loss: 0.2581 - model_accuracy: 0.8889 - model_1_accuracy: 0.9444 - model_2_accuracy: 0.9444 - model_3_accuracy: 1.0000 - model_4_accuracy: 0.8889 - loss1: 1.6658 - loss2: 6.3528 - val_loss: 12.8531 - val_model_loss: 2.4019 - val_model_1_loss: 2.2257 - val_model_2_loss: 1.9874 - val_model_3_loss: 2.1396 - val_model_4_loss: 2.0642 - val_model_accuracy: 0.2862 - val_model_1_accuracy: 0.2738 - val_model_2_accuracy: 0.2771 - val_model_3_accuracy: 0.3067 - val_model_4_accuracy: 0.2596 - val_loss1: 1.8408 - val_loss2: 6.4467
# Epoch 00235: early stopping and save the model

# %%
#evaluation of the five base models
evaluate = model_train.evaluate(x_test,[keras.utils.to_categorical(y_test),keras.utils.to_categorical(y_test),keras.utils.to_categorical(y_test),keras.utils.to_categorical(y_test),keras.utils.to_categorical(y_test)],batch_size=10)
evaluate
# Out:
# 2160/2160 [==============================] - 25s 11ms/step - loss: 12.5926 - model_loss: 2.0679 - model_1_loss: 1.9666 - model_2_loss: 2.0104 - model_3_loss: 1.8882 - model_4_loss: 2.2784 - model_accuracy: 0.3299 - model_1_accuracy: 0.2812 - model_2_accuracy: 0.3028 - model_3_accuracy: 0.2977 - model_4_accuracy: 0.2544 - loss1: 2.1900 - loss2: 6.3690

# %%
#hard voting ensemble
class HardVotingEnsemble:
    def __init__(self, model, testdata ,batch_size):
        self.ensemble_model = model
        self.testdata = testdata
        self.batch_size = batch_size
        self.data_size = testdata[1].shape[0]
    def prediction(self):
        predictions =[]
        for i in range(int(self.data_size/self.batch_size)):
            batch_predictions = np.argmax(self.ensemble_model.predict(self.testdata[0][i*self.batch_size:(i+1)*self.batch_size]),axis=2) 
            batch_predictions = np.stack(batch_predictions, axis=1)
            batch_predictions = [np.argmax(np.bincount(pre)) for pre in batch_predictions]
            predictions = predictions+batch_predictions
        return np.array(predictions)

    def evaluate(self):
        predictions = self.prediction()
        accuracy = np.sum(
            predictions == self.testdata[1]) / self.data_size
        return accuracy
HEnsemble = HardVotingEnsemble(model = model_train,testdata = (x_test, y_test),batch_size=10)
HEnsemble.evaluate()
# Out:
# 0.3163888888888889

# %%
#soft voting ensemble
def SoftVotingEnsemble(model, x, y):
  data_size = x.shape[0]
  predictions = tf.argmax(tf.reduce_mean(model.predict(x), axis = 0),axis=1)
  accuracy = np.sum(
     predictions == y) / data_size
  return accuracy
SoftVotingEnsemble(model_train, x_test, y_test)
# Out:
# 0.3162962962962963

# %%
class eCustomEarlyStoppingAndSave(keras.callbacks.Callback):
    def __init__(self, save_path, patience=0):
        super(eCustomEarlyStoppingAndSave, self).__init__()
        #self.patience = patience
        self.save_path = save_path
        self.best_weights = None

    def on_train_begin(self, logs=None):
        #self.wait = 0
        self.stopped_epoch = 0
        #self.best_val_distance_loss = np.Inf
        self.best_val_acc = 0

    def on_epoch_end(self, epoch, logs=None):
        #val_distance_loss = logs.get('val_MMD_loss')
        val_acc = logs.get('val_accuracy') 

        if  np.greater(val_acc, self.best_val_acc):
            #self.best_val_distance_loss = val_distance_loss
            self.best_val_acc = val_acc
            #self.wait = 0
            # Record the best weights if current results is better (less).
            self.best_weights = self.model.get_weights()
            self.stopped_epoch = epoch
        #else:
            #self.wait += 1
            #if self.wait >= self.patience:
                #self.stopped_epoch = epoch
                #self.model.stop_training = True
                #print("Restoring model weights from the end of the best epoch.")
                #self.model.set_weights(self.best_weights)

    def on_train_end(self, logs=None):
        self.model.set_weights(self.best_weights)
        if self.stopped_epoch >= 0:
            print("Epoch %05d: early stopping and save the model" %
                  (self.stopped_epoch + 1))
        #self.model.save(self.save_path)

# %%
class eNEUdata(keras.utils.Sequence):
    def __init__(self, data_x, data_y, batch_size, train):
      self.data_x = data_x
      self.data_y = data_y
      self.train = train
      self.batch_size = batch_size

    def __len__(self):
      return int(np.ceil(len(self.data_y) / self.batch_size))

    def __getitem__(self, idx):
      batch_x = self.data_x[idx * self.batch_size:(idx + 1) * self.batch_size]
                            
      batch_y = self.data_y[idx * self.batch_size:(idx + 1) * self.batch_size]
      if self.train == True:
          batch_x = Data_Aug(batch_x)

      batch_x = np.clip(batch_x / 255.0, 0, 1).astype("float32")
      batch_y = keras.utils.to_categorical(batch_y, 6)
      return batch_x, batch_y

# %%
#feature fusion model
input_size = (64, 64, 3)
model_path = '50_samples_seed_fix.h5'
model = keras.models.load_model(model_path)
extractor_1 = keras.models.Model(inputs=model.layers[1].inputs,outputs=model.layers[1].layers[12].output)
extractor_2 = keras.models.Model(inputs=model.layers[2].inputs,outputs=model.layers[2].layers[12].output)
extractor_3 = keras.models.Model(inputs=model.layers[3].inputs,outputs=model.layers[3].layers[12].output)
extractor_4 = keras.models.Model(inputs=model.layers[4].inputs,outputs=model.layers[4].layers[12].output)
extractor_5 = keras.models.Model(inputs=model.layers[5].inputs,outputs=model.layers[5].layers[12].output)
extractor_1.trainable = False
extractor_2.trainable = False
extractor_3.trainable = False
extractor_4.trainable = False
extractor_5.trainable = False
inputs = keras.Input(shape = input_size)
features_1 = extractor_1(inputs, training = False)
features_2 = extractor_2(inputs, training = False)
features_3 = extractor_3(inputs, training = False)
features_4 = extractor_4(inputs, training = False)
features_5 = extractor_5(inputs, training = False)

x = keras.layers.Concatenate(axis=-1)([features_1,features_2,features_3,features_4,features_5])

x = keras.layers.Flatten()(x)
x = keras.layers.Dense(128,  name='dense_100')(x)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.Activation('relu')(x)
x = keras.layers.Dropout(0.5)(x)
outputs = keras.layers.Dense(6, activation='softmax', name='dense_101')(x)
ensemble = keras.Model(inputs = inputs, outputs = outputs)
ensemble.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-3),
                    loss='categorical_crossentropy',
                    metrics=['accuracy'])
train_sequence = eNEUdata(x_train, y_train, batch_size=10, train=True)
validation_sequence = eNEUdata(x_val, y_val, batch_size=10, train=False)
history = ensemble.fit(
    train_sequence,
    epochs=50,
    validation_data=validation_sequence,
    #validation_steps=200,
    callbacks=eCustomEarlyStoppingAndSave(
        save_path='ensemble.h5',
        patience=10))
evaluate = ensemble.evaluate(x_test,keras.utils.to_categorical(y_test),batch_size=10)
# Out:
# Epoch 1/50
# 2/2 [==============================] - 3s 2s/step - loss: 2.5062 - accuracy: 0.1667 - val_loss: 7.2335 - val_accuracy: 0.1875
# Epoch 2/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.9651 - accuracy: 0.6667 - val_loss: 10.8482 - val_accuracy: 0.1912
# Epoch 3/50
# 2/2 [==============================] - 2s 2s/step - loss: 1.0086 - accuracy: 0.7222 - val_loss: 12.4039 - val_accuracy: 0.1937
# Epoch 4/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.8732 - accuracy: 0.8333 - val_loss: 12.0217 - val_accuracy: 0.1958
# Epoch 5/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.7910 - accuracy: 0.7222 - val_loss: 11.2329 - val_accuracy: 0.2050
# Epoch 6/50
# 2/2 [==============================] - 2s 2s/step - loss: 1.0956 - accuracy: 0.5556 - val_loss: 10.1564 - val_accuracy: 0.2083
# Epoch 7/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.5236 - accuracy: 0.8333 - val_loss: 9.4012 - val_accuracy: 0.2125
# Epoch 8/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.8695 - accuracy: 0.7222 - val_loss: 8.6391 - val_accuracy: 0.2083
# Epoch 9/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.5659 - accuracy: 0.7222 - val_loss: 7.9574 - val_accuracy: 0.2087
# Epoch 10/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.7224 - accuracy: 0.7222 - val_loss: 7.5454 - val_accuracy: 0.2050
# Epoch 11/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.5714 - accuracy: 0.8333 - val_loss: 7.0283 - val_accuracy: 0.2037
# Epoch 12/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.8627 - accuracy: 0.6667 - val_loss: 6.6634 - val_accuracy: 0.2079
# Epoch 13/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.5350 - accuracy: 0.8333 - val_loss: 6.3130 - val_accuracy: 0.2121
# Epoch 14/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.3063 - accuracy: 0.9444 - val_loss: 5.8426 - val_accuracy: 0.2188
# Epoch 15/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.4066 - accuracy: 0.8333 - val_loss: 5.4386 - val_accuracy: 0.2212
# Epoch 16/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.4754 - accuracy: 0.8889 - val_loss: 5.0289 - val_accuracy: 0.2271
# Epoch 17/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.6395 - accuracy: 0.7222 - val_loss: 4.7064 - val_accuracy: 0.2329
# Epoch 18/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.3438 - accuracy: 0.8889 - val_loss: 4.4423 - val_accuracy: 0.2408
# Epoch 19/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.7255 - accuracy: 0.7778 - val_loss: 4.2217 - val_accuracy: 0.2454
# Epoch 20/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.4696 - accuracy: 0.7778 - val_loss: 3.9840 - val_accuracy: 0.2492
# Epoch 21/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.3690 - accuracy: 0.9444 - val_loss: 3.8096 - val_accuracy: 0.2512
# Epoch 22/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.3239 - accuracy: 0.8889 - val_loss: 3.6573 - val_accuracy: 0.2583
# Epoch 23/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.5283 - accuracy: 0.7222 - val_loss: 3.5271 - val_accuracy: 0.2575
# Epoch 24/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.2926 - accuracy: 0.8889 - val_loss: 3.3845 - val_accuracy: 0.2646
# Epoch 25/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.2126 - accuracy: 1.0000 - val_loss: 3.2726 - val_accuracy: 0.2612
# Epoch 26/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.3639 - accuracy: 0.8333 - val_loss: 3.1712 - val_accuracy: 0.2629
# Epoch 27/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.2625 - accuracy: 0.9444 - val_loss: 3.1341 - val_accuracy: 0.2600
# Epoch 28/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.4726 - accuracy: 0.8333 - val_loss: 3.1167 - val_accuracy: 0.2550
# Epoch 29/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.5472 - accuracy: 0.8333 - val_loss: 3.1521 - val_accuracy: 0.2521
# Epoch 30/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.2154 - accuracy: 1.0000 - val_loss: 3.1785 - val_accuracy: 0.2542
# Epoch 31/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.8051 - accuracy: 0.7222 - val_loss: 3.2034 - val_accuracy: 0.2537
# Epoch 32/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.1942 - accuracy: 1.0000 - val_loss: 3.1903 - val_accuracy: 0.2558
# Epoch 33/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.1483 - accuracy: 1.0000 - val_loss: 3.1487 - val_accuracy: 0.2625
# Epoch 34/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.4316 - accuracy: 0.8333 - val_loss: 3.1206 - val_accuracy: 0.2654
# Epoch 35/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.1623 - accuracy: 0.9444 - val_loss: 3.0926 - val_accuracy: 0.2688
# Epoch 36/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.1322 - accuracy: 1.0000 - val_loss: 3.0333 - val_accuracy: 0.2742
# Epoch 37/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.3836 - accuracy: 0.8889 - val_loss: 2.9657 - val_accuracy: 0.2779
# Epoch 38/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.7659 - accuracy: 0.7222 - val_loss: 2.9361 - val_accuracy: 0.2808
# Epoch 39/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.1056 - accuracy: 0.9444 - val_loss: 2.8850 - val_accuracy: 0.2804
# Epoch 40/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.1863 - accuracy: 0.9444 - val_loss: 2.8431 - val_accuracy: 0.2812
# Epoch 41/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.1163 - accuracy: 1.0000 - val_loss: 2.8168 - val_accuracy: 0.2792
# Epoch 42/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.2696 - accuracy: 0.9444 - val_loss: 2.7968 - val_accuracy: 0.2783
# Epoch 43/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.2361 - accuracy: 0.8889 - val_loss: 2.7616 - val_accuracy: 0.2763
# Epoch 44/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.5887 - accuracy: 0.8333 - val_loss: 2.7331 - val_accuracy: 0.2742
# Epoch 45/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.0724 - accuracy: 1.0000 - val_loss: 2.7067 - val_accuracy: 0.2754
# Epoch 46/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.4169 - accuracy: 0.8333 - val_loss: 2.6863 - val_accuracy: 0.2746
# Epoch 47/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.3472 - accuracy: 0.9444 - val_loss: 2.6618 - val_accuracy: 0.2733
# Epoch 48/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.1775 - accuracy: 0.9444 - val_loss: 2.5866 - val_accuracy: 0.2871
# Epoch 49/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.6483 - accuracy: 0.7778 - val_loss: 2.5432 - val_accuracy: 0.2850
# Epoch 50/50
# 2/2 [==============================] - 2s 2s/step - loss: 0.2501 - accuracy: 0.8889 - val_loss: 2.5068 - val_accuracy: 0.2887
# Epoch 00050: early stopping and save the model
# 2160/2160 [==============================] - 14s 6ms/step - loss: 2.4986 - accuracy: 0.2923

# %%
#finetuning
extractor_1.trainable = True
extractor_2.trainable = True
extractor_3.trainable = True
extractor_4.trainable = True
extractor_5.trainable = True
ensemble.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-5),
                    loss='categorical_crossentropy',
                    metrics=['accuracy'])
#train_sequence = ecifar10data(sampled_x_train, sampled_y_train, batch_size=10, train=False)
#validation_sequence = ecifar10data(x_val, y_val, batch_size=10, train=False)
history = ensemble.fit(
    train_sequence,
    epochs=20,
    validation_data=validation_sequence,
    #validation_steps=200,
    callbacks=eCustomEarlyStoppingAndSave(
        save_path='ensemble.h5',
        patience=10))
evaluate = ensemble.evaluate(x_test,keras.utils.to_categorical(y_test),batch_size=10)
# Out:
# Epoch 1/20
# 2/2 [==============================] - 4s 2s/step - loss: 0.0595 - accuracy: 1.0000 - val_loss: 2.4328 - val_accuracy: 0.2867
# Epoch 2/20
# 2/2 [==============================] - 2s 2s/step - loss: 0.1861 - accuracy: 0.9444 - val_loss: 2.4169 - val_accuracy: 0.2892
# Epoch 3/20
# 2/2 [==============================] - 2s 2s/step - loss: 0.0996 - accuracy: 1.0000 - val_loss: 2.3912 - val_accuracy: 0.2862
# Epoch 4/20
# 2/2 [==============================] - 2s 2s/step - loss: 0.5050 - accuracy: 0.8889 - val_loss: 2.3684 - val_accuracy: 0.2879
# Epoch 5/20
# 2/2 [==============================] - 2s 2s/step - loss: 0.2729 - accuracy: 0.8889 - val_loss: 2.3494 - val_accuracy: 0.2858
# Epoch 6/20
# 2/2 [==============================] - 2s 2s/step - loss: 0.3641 - accuracy: 0.8889 - val_loss: 2.3383 - val_accuracy: 0.2850
# Epoch 7/20
# 2/2 [==============================] - 2s 2s/step - loss: 0.1544 - accuracy: 1.0000 - val_loss: 2.3354 - val_accuracy: 0.2833
# Epoch 8/20
# 2/2 [==============================] - 2s 2s/step - loss: 0.3637 - accuracy: 0.8889 - val_loss: 2.3434 - val_accuracy: 0.2754
# Epoch 9/20
# 2/2 [==============================] - 2s 2s/step - loss: 0.1793 - accuracy: 0.9444 - val_loss: 2.3489 - val_accuracy: 0.2733
# Epoch 10/20
# 2/2 [==============================] - 2s 2s/step - loss: 0.2110 - accuracy: 0.9444 - val_loss: 2.3384 - val_accuracy: 0.2750
# Epoch 11/20
# 2/2 [==============================] - 2s 2s/step - loss: 0.3957 - accuracy: 0.8333 - val_loss: 2.3162 - val_accuracy: 0.2725
# Epoch 12/20
# 2/2 [==============================] - 2s 2s/step - loss: 0.3258 - accuracy: 0.9444 - val_loss: 2.2929 - val_accuracy: 0.2771
# Epoch 13/20
# 2/2 [==============================] - 2s 2s/step - loss: 0.2395 - accuracy: 0.9444 - val_loss: 2.2778 - val_accuracy: 0.2750
# Epoch 14/20
# 2/2 [==============================] - 2s 2s/step - loss: 0.6034 - accuracy: 0.8333 - val_loss: 2.2679 - val_accuracy: 0.2750
# Epoch 15/20
# 2/2 [==============================] - 2s 2s/step - loss: 0.1174 - accuracy: 1.0000 - val_loss: 2.2511 - val_accuracy: 0.2725
# Epoch 16/20
# 2/2 [==============================] - 2s 2s/step - loss: 0.3069 - accuracy: 0.9444 - val_loss: 2.2376 - val_accuracy: 0.2738
# Epoch 17/20
# 2/2 [==============================] - 2s 2s/step - loss: 0.6228 - accuracy: 0.7778 - val_loss: 2.2275 - val_accuracy: 0.2738
# Epoch 18/20
# 2/2 [==============================] - 2s 2s/step - loss: 0.3317 - accuracy: 0.8333 - val_loss: 2.2162 - val_accuracy: 0.2733
# Epoch 19/20
# 2/2 [==============================] - 2s 2s/step - loss: 0.3144 - accuracy: 0.8889 - val_loss: 2.2140 - val_accuracy: 0.2725
# Epoch 20/20
# 2/2 [==============================] - 2s 2s/step - loss: 0.2026 - accuracy: 0.8889 - val_loss: 2.2043 - val_accuracy: 0.2729
# Epoch 00002: early stopping and save the model
# 2160/2160 [==============================] - 14s 6ms/step - loss: 2.4042 - accuracy: 0.2927

# %%
#f1 score
predict = tf.argmax(ensemble.predict(x_test),axis=-1)
classification_report(y_test, predict,digits=4)
# Out:
# '              precision    recall  f1-score   support\n\n           0     0.3969    0.2081    0.2730      3600\n           1     0.1613    0.0028    0.0055      3600\n           2     0.4004    0.5486    0.4629      3600\n           3     0.2022    0.1958    0.1990      3600\n           4     0.3272    0.4961    0.3943      3600\n           5     0.1900    0.3047    0.2341      3600\n\n    accuracy                         0.2927     21600\n   macro avg     0.2797    0.2927    0.2615     21600\nweighted avg     0.2797    0.2927    0.2615     21600\n'
