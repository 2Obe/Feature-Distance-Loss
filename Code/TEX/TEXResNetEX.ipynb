#   inflating: /content/TEX_test/thread (104966).png
#   inflating: /content/TEX_test/thread (104967).png
#   inflating: /content/TEX_test/thread (104968).png
#   inflating: /content/TEX_test/thread (104969).png
#   inflating: /content/TEX_test/thread (104970).png
#   inflating: /content/TEX_test/thread (104971).png
#   inflating: /content/TEX_test/thread (104972).png
#   inflating: /content/TEX_test/thread (104973).png
#   inflating: /content/TEX_test/thread (104974).png
#   inflating: /content/TEX_test/thread (104975).png
#   inflating: /content/TEX_test/thread (104976).png
#   inflating: /content/TEX_test/thread (104977).png
#   inflating: /content/TEX_test/thread (104978).png
#   inflating: /content/TEX_test/thread (104979).png
#   inflating: /content/TEX_test/thread (104980).png
#   inflating: /content/TEX_test/thread (104981).png
#   inflating: /content/TEX_test/thread (104982).png
#   inflating: /content/TEX_test/thread (104983).png
#   inflating: /content/TEX_test/thread (104984).png
#   inflating: /content/TEX_test/thread (104985).png
# ...
#   inflating: /content/50_samples/metal_contamination (48041).png
#   inflating: /content/50_samples/metal_contamination (48042).png
#   inflating: /content/50_samples/metal_contamination (48043).png
#   inflating: /content/50_samples/metal_contamination (48044).png
#   inflating: /content/50_samples/metal_contamination (48045).png
#   inflating: /content/50_samples/metal_contamination (48046).png
#   inflating: /content/50_samples/metal_contamination (48047).png
#   inflating: /content/50_samples/metal_contamination (48048).png
#   inflating: /content/50_samples/metal_contamination (48049).png
#   inflating: /content/50_samples/thread (60000).png
#   inflating: /content/50_samples/thread (60001).png
#   inflating: /content/50_samples/thread (60002).png
#   inflating: /content/50_samples/thread (60003).png
#   inflating: /content/50_samples/thread (60004).png
#   inflating: /content/50_samples/thread (60005).png
#   inflating: /content/50_samples/thread (60006).png
#   inflating: /content/50_samples/thread (60007).png
#   inflating: /content/50_samples/thread (60008).png
#   inflating: /content/50_samples/thread (60009).png
#   inflating: /content/50_samples/thread (60010).png
#   inflating: /content/50_samples/thread (60011).png
#   inflating: /content/50_samples/thread (60012).png
#   inflating: /content/50_samples/thread (60013).png
#   inflating: /content/50_samples/thread (60014).png
#   inflating: /content/50_samples/thread (60015).png
#   inflating: /content/50_samples/thread (60016).png
#   inflating: /content/50_samples/thread (60017).png
#   inflating: /content/50_samples/thread (60018).png
#   inflating: /content/50_samples/thread (60019).png
#   inflating: /content/50_samples/thread (60020).png
#   inflating: /content/50_samples/thread (60021).png
#   inflating: /content/50_samples/thread (60022).png
#   inflating: /content/50_samples/thread (60023).png
#   inflating: /content/50_samples/thread (60024).png
#   inflating: /content/50_samples/thread (60025).png
#   inflating: /content/50_samples/thread (60026).png
#   inflating: /content/50_samples/thread (60027).png
#   inflating: /content/50_samples/thread (60028).png
#   inflating: /content/50_samples/thread (60029).png
#   inflating: /content/50_samples/thread (60030).png
#   inflating: /content/50_samples/thread (60031).png
#   inflating: /content/50_samples/thread (60032).png
#   inflating: /content/50_samples/thread (60033).png
#   inflating: /content/50_samples/thread (60034).png
#   inflating: /content/50_samples/thread (60035).png
#   inflating: /content/50_samples/thread (60036).png
#   inflating: /content/50_samples/thread (60037).png
#   inflating: /content/50_samples/thread (60038).png
#   inflating: /content/5_samples/good (24004).png
#   inflating: /content/5_samples/hole (36000).png
#   inflating: /content/5_samples/hole (36001).png
#   inflating: /content/5_samples/hole (36002).png
#   inflating: /content/5_samples/hole (36003).png
#   inflating: /content/5_samples/hole (36004).png
#   inflating: /content/5_samples/metal_contamination (48000).png
#   inflating: /content/5_samples/metal_contamination (48001).png
#   inflating: /content/5_samples/metal_contamination (48002).png
#   inflating: /content/5_samples/metal_contamination (48003).png
#   inflating: /content/5_samples/metal_contamination (48004).png
#   inflating: /content/5_samples/thread (60000).png
#   inflating: /content/5_samples/thread (60001).png
#   inflating: /content/5_samples/thread (60002).png
#   inflating: /content/5_samples/thread (60003).png
#   inflating: /content/5_samples/thread (60004).png
# Archive:  /content/drive/MyDrive/TEX/3_samples.zip
#    creating: /content/3_samples/
#   inflating: /content/3_samples/color (0).png
#   inflating: /content/3_samples/color (1).png
#   inflating: /content/3_samples/color (2).png
#   inflating: /content/3_samples/cut (12000).png
#   inflating: /content/3_samples/cut (12001).png
#   inflating: /content/3_samples/cut (12002).png
#   inflating: /content/3_samples/good (24000).png
#   inflating: /content/3_samples/good (24001).png
#   inflating: /content/3_samples/good (24002).png
#   inflating: /content/3_samples/hole (36000).png
#   inflating: /content/3_samples/hole (36001).png
#   inflating: /content/3_samples/hole (36002).png
#   inflating: /content/3_samples/metal_contamination (48000).png
#   inflating: /content/3_samples/metal_contamination (48001).png
#   inflating: /content/3_samples/metal_contamination (48002).png
#   inflating: /content/3_samples/thread (60000).png
#   inflating: /content/3_samples/thread (60001).png
#   inflating: /content/3_samples/thread (60002).png

# %%
import random
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import tensorflow.keras.backend as K
from tensorflow import keras
from sklearn import model_selection
from sklearn.metrics import classification_report
import imgaug.augmenters as iaa
import imgaug as ia
import os

# %%
ia.seed(1)
def Data_Aug(samples):
    randomaug = iaa.Sometimes(
        0.5,
        iaa.OneOf([
            iaa.Sequential([
                iaa.AllChannelsCLAHE(clip_limit=(1, 10)),
                iaa.Affine(rotate=(-5, 5))
            ]),
            iaa.Sequential([
                iaa.Affine(translate_percent={
                    "x": (-0.2, 0.2),
                    "y": (-0.2, 0.2)
                }),
                iaa.Multiply((0.7, 1.3)),
                iaa.AdditiveLaplaceNoise(scale=0.03 * 255, per_channel=True),
                iaa.Fliplr(0.3),
                iaa.Flipud(0.3)
            ]),
            iaa.Sequential([
                iaa.Affine(rotate=(-10, 10)),
                iaa.Multiply((0.7, 1.3)),
                iaa.AdditiveLaplaceNoise(scale=0.03 * 255, per_channel=True),
                iaa.Fliplr(0.3),
                iaa.Flipud(0.3)
            ]),
            iaa.Sequential([
                iaa.PerspectiveTransform(scale=(0, 0.15)),
                iaa.Multiply((0.7, 1.3)),
                iaa.AdditiveLaplaceNoise(scale=0.03 * 255, per_channel=True),
                iaa.Fliplr(0.3),
                iaa.Flipud(0.3)
            ])
        ]))


    return randomaug.augment_images(samples)

def resize_images(imgs, hight, width):
    seq = iaa.Resize({"height": hight, "width": width})
    aug = seq.augment_images(imgs)
    return aug

# %%
#load NEU dataset
def load_data(dir_path, labels_dict):
  all_names = os.listdir(dir_path)
  data_x = []
  data_y = []
  for name in all_names:
    img = keras.preprocessing.image.load_img(os.path.join(dir_path, name))
    img = keras.preprocessing.image.img_to_array(img,dtype='uint8')
    data_x.append(img)
    lab = labels_dict[name.split(' ')[0]]
    data_y.append(lab)
  data_x = np.array(data_x)
  data_y = np.array(data_y)
  return data_x, data_y
class TEXdata(keras.utils.Sequence):
    def __init__(self, data_x, data_y, batch_size, train):
      self.data_x = data_x
      self.data_y = data_y
      self.train = train
      self.batch_size = batch_size

    def __len__(self):
      return int(np.ceil(len(self.data_y) / self.batch_size))

    def __getitem__(self, idx):
      batch_x = self.data_x[idx * self.batch_size:(idx + 1) * self.batch_size]
                            
      batch_y = self.data_y[idx * self.batch_size:(idx + 1) * self.batch_size]
      if self.train == True:
          batch_x = Data_Aug(batch_x)

      batch_x = np.clip(batch_x / 255.0, 0, 1).astype("float32")
      batch_y = keras.utils.to_categorical(batch_y, 6)
      return batch_x, [batch_y, batch_y, batch_y, batch_y, batch_y]

# %%
#save the best model during training 
class CustomEarlyStoppingAndSave(keras.callbacks.Callback):
    def __init__(self, save_path, patience=0):
        super(CustomEarlyStoppingAndSave, self).__init__()
        #self.patience = patience
        self.save_path = save_path
        self.best_weights = None

    def on_train_begin(self, logs=None):
        #self.wait = 0
        self.stopped_epoch = 0
        #self.best_val_distance_loss = np.Inf
        self.best_val_acc = 0

    def on_epoch_end(self, epoch, logs=None):
        #val_distance_loss = logs.get('val_MMD_loss')
        val_acc = logs.get('val_model_accuracy') + logs.get(
            'val_model_1_accuracy') + logs.get(
                'val_model_2_accuracy') 
                #+ logs.get(
                 #   'val_model_3_accuracy') + logs.get('val_model_4_accuracy')

        if  np.greater(val_acc, self.best_val_acc):
            #self.best_val_distance_loss = val_distance_loss
            self.best_val_acc = val_acc
            #self.wait = 0
            # Record the best weights if current results is better (less).
            self.best_weights = self.model.get_weights()
            self.stopped_epoch = epoch
        #else:
            #self.wait += 1
            #if self.wait >= self.patience:
                #self.stopped_epoch = epoch
                #self.model.stop_training = True
                #print("Restoring model weights from the end of the best epoch.")
                #self.model.set_weights(self.best_weights)

    def on_train_end(self, logs=None):
        self.model.set_weights(self.best_weights)
        if self.stopped_epoch >= 0:
            print("Epoch %05d: early stopping and save the model" %
                  (self.stopped_epoch + 1))
        self.model.save(self.save_path)

# %%
#Cosine&Euclidean distance loss
def descriptor(X, mask = False, max_norm = False):
  X = tf.reduce_mean(X, axis=3)
  if mask:
    mean_X = tf.reduce_mean(X, axis = [1,2], keepdims= True)
    X = tf.where(X > mean_X, X , tf.zeros_like(X, dtype=tf.float32))
  if max_norm:
    max_X=tf.reduce_max(X, axis = [1,2], keepdims= True)
    X = tf.math.divide_no_nan(X, max_X)
  return X 
  
def compute_euclidean_sum(X, Y):
  L2_distance = tf.reduce_mean(tf.exp(-(X - Y)**2), axis= [1,2])
  return tf.reduce_mean(L2_distance)

def compute_cosine_sum(X, Y):
  X = tf.reshape(X, [tf.shape(X)[0], -1])
  Y = tf.reshape(Y, [tf.shape(Y)[0], -1])
  loss = -keras.losses.cosine_similarity(X,Y,axis=-1)
  return tf.reduce_mean(loss)

def cosine_euclidean_sum_loss(x, cosine_weight, euclidean_weight, mask, max_norm):
  descriptor0 = descriptor(x[0], mask=mask, max_norm=max_norm)
  descriptor1 = descriptor(x[1], mask=mask, max_norm=max_norm)
  descriptor2 = descriptor(x[2], mask=mask, max_norm=max_norm)
  descriptor3 = descriptor(x[3], mask=mask, max_norm=max_norm)
  descriptor4 = descriptor(x[4], mask=mask, max_norm=max_norm)
  cosine_sum = compute_cosine_sum(descriptor0, descriptor1)+compute_cosine_sum(descriptor0, descriptor2)+compute_cosine_sum(descriptor0, descriptor3)+compute_cosine_sum(descriptor0, descriptor4)+compute_cosine_sum(descriptor1, descriptor2)+compute_cosine_sum(descriptor1, descriptor3)+compute_cosine_sum(descriptor1, descriptor4)+compute_cosine_sum(descriptor2, descriptor3)+compute_cosine_sum(descriptor2, descriptor4)+compute_cosine_sum(descriptor3, descriptor4)
  euclidean_sum = compute_euclidean_sum(descriptor0, descriptor1)+compute_euclidean_sum(descriptor0, descriptor2)+compute_euclidean_sum(descriptor0, descriptor3)+compute_euclidean_sum(descriptor0, descriptor4)+compute_euclidean_sum(descriptor1, descriptor2)+compute_euclidean_sum(descriptor1, descriptor3)+compute_euclidean_sum(descriptor1, descriptor4)+compute_euclidean_sum(descriptor2, descriptor3)+compute_euclidean_sum(descriptor2, descriptor4)+compute_euclidean_sum(descriptor3, descriptor4)
  return cosine_sum, euclidean_sum, cosine_weight*cosine_sum+euclidean_weight*euclidean_sum

# %%
#create single ResNet model
def create_ResNet(input_shape, num_classes=6, num_filters = 64, random_seed=None):
  inputs = keras.Input(shape=input_shape)
  y = keras.layers.Conv2D(num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(inputs)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  y = keras.layers.Conv2D(num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(y)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  y = keras.layers.Conv2D(num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(y)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  x = keras.layers.Conv2D(num_filters, (1, 1), kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(inputs)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.add([x, y])
  x = keras.layers.LeakyReLU(alpha=0.1)(x)
  x = keras.layers.MaxPooling2D((2,2))(x)

  y = keras.layers.Conv2D(2*num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  y = keras.layers.Conv2D(2*num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(y)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  y = keras.layers.Conv2D(2*num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(y)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  x = keras.layers.Conv2D(2*num_filters, (1, 1), kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.add([x, y])
  x = keras.layers.LeakyReLU(alpha=0.1)(x)
  x = keras.layers.MaxPooling2D((2,2))(x) 

  y = keras.layers.Conv2D(4*num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  y = keras.layers.Conv2D(4*num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(y)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  y = keras.layers.Conv2D(4*num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(y)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  x = keras.layers.Conv2D(4*num_filters, (1, 1), kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.add([x, y])
  x = keras.layers.LeakyReLU(alpha=0.1)(x)
  x = keras.layers.MaxPooling2D((2,2))(x) 

  y = keras.layers.Conv2D(8*num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  y = keras.layers.Conv2D(8*num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(y)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  y = keras.layers.Conv2D(8*num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(y)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  x = keras.layers.Conv2D(8*num_filters, (1, 1), kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.add([x, y])
  x = keras.layers.LeakyReLU(alpha=0.1)(x)
  last_acti = keras.layers.MaxPooling2D((2,2))(x) 

  x = keras.layers.GlobalAveragePooling2D()(last_acti)
  outputs = keras.layers.Dense(num_classes, activation='softmax', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  model = keras.Model(inputs=inputs, outputs=[outputs,last_acti])
  return model

# %%
#load training, validation and testing images
training_data_path = '5_samples'
validation_data_path = 'TEX_validation'
test_data_path = 'TEX_test'
labels_dict = {'color': 0, 'cut': 1, 'good': 2, 'hole': 3, 'metal_contamination': 4, 'thread': 5}
x_train, y_train = load_data(training_data_path, labels_dict)
x_val, y_val = load_data(validation_data_path, labels_dict)
x_test, y_test = load_data(test_data_path, labels_dict)
_, x_val, _, y_val = model_selection.train_test_split(
    x_val,
    y_val,
    test_size=2400,
    random_state=0,
    stratify=y_val)
x_test = x_test/255.0

# %%
#construct joint training for the five base models
input_size = (64, 64, 3)
model0 = create_ResNet(input_shape=input_size, num_classes=6, num_filters = 64, random_seed=1)
model1 = create_ResNet(input_shape=input_size, num_classes=6, num_filters = 64, random_seed=2)
model2 = create_ResNet(input_shape=input_size, num_classes=6, num_filters = 64, random_seed=3)
model3 = create_ResNet(input_shape=input_size, num_classes=6, num_filters = 64, random_seed=4)
model4 = create_ResNet(input_shape=input_size, num_classes=6, num_filters = 64, random_seed=5)
allinputs = keras.Input(shape=input_size)
output0, feature_maps0 = model0(allinputs)
output1, feature_maps1 = model1(allinputs)
output2, feature_maps2 = model2(allinputs)
output3, feature_maps3 = model3(allinputs)
output4, feature_maps4 = model4(allinputs)
model_train = keras.Model(
    inputs=allinputs, outputs=[output0, output1, output2, output3, output4])

#implement distance loss
loss1, loss2, loss = cosine_euclidean_sum_loss(x=[feature_maps0, feature_maps1, feature_maps2, feature_maps3, feature_maps4], 
                                      cosine_weight=1, euclidean_weight=0.1, mask=True, max_norm=False)

model_train.add_loss(loss)
model_train.add_metric(loss1, name="loss1", aggregation='mean')
model_train.add_metric(loss2, name="loss2", aggregation='mean')

model_train.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4),
                    loss=['categorical_crossentropy','categorical_crossentropy','categorical_crossentropy','categorical_crossentropy','categorical_crossentropy'],
                    metrics=['accuracy'])

#construct training and validation samples
train_sequence = TEXdata(x_train, y_train, batch_size=10, train=True)
validation_sequence = TEXdata(x_val, y_val, batch_size=10, train=False)

#training 
history = model_train.fit(
    train_sequence,
    epochs=300,
    validation_data=validation_sequence,
    #validation_steps=36,
    callbacks=CustomEarlyStoppingAndSave(
        save_path='50_samples_seed_fix.h5',
        patience=10))
frame = pd.DataFrame({
    'loss':
    history.history['loss'],
    'loss1':
    history.history['loss1'],
    'loss2':
    history.history['loss2'],
    'model_0_loss':
    history.history['model_loss'],
    'model_1_loss':
    history.history['model_1_loss'],
    'model_2_loss':
    history.history['model_2_loss'],
    'model_3_loss':
    history.history['model_3_loss'],
    'model_4_loss':
    history.history['model_4_loss'],
    'model_0_accuracy':
    history.history['model_accuracy'],
    'model_1_accuracy':
    history.history['model_1_accuracy'],
    'model_2_accuracy':
    history.history['model_2_accuracy'],
    'model_3_accuracy':
    history.history['model_3_accuracy'],
    'model_4_accuracy':
    history.history['model_4_accuracy'],
    'val_loss':
    history.history['val_loss'],
    'val_loss1':
    history.history['val_loss1'],
    'val_loss2':
    history.history['val_loss2'],
    'val_model_0_loss':
    history.history['val_model_loss'],
    'val_model_1_loss':
    history.history['val_model_1_loss'],
    'val_model_2_loss':
    history.history['val_model_2_loss'],
    'val_model_3_loss':
    history.history['val_model_3_loss'],
    'val_model_4_loss':
    history.history['val_model_4_loss'],
    'val_model_0_accuracy':
    history.history['val_model_accuracy'],
    'val_model_1_accuracy':
    history.history['val_model_1_accuracy'],
    'val_model_2_accuracy':
    history.history['val_model_2_accuracy'],
    'val_model_3_accuracy':
    history.history['val_model_3_accuracy'],
# 3/3 [==============================] - 5s 3s/step - loss: 1.4727 - model_loss: 0.2165 - model_1_loss: 0.0643 - model_2_loss: 0.1412 - model_3_loss: 0.0943 - model_4_loss: 0.0933 - model_accuracy: 0.9333 - model_1_accuracy: 1.0000 - model_2_accuracy: 0.9667 - model_3_accuracy: 0.9667 - model_4_accuracy: 0.9667 - loss1: 0.2795 - loss2: 5.8369 - val_loss: 16.2026 - val_model_loss: 2.9506 - val_model_1_loss: 3.0560 - val_model_2_loss: 2.5859 - val_model_3_loss: 2.8309 - val_model_4_loss: 3.5260 - val_model_accuracy: 0.2442 - val_model_1_accuracy: 0.2383 - val_model_2_accuracy: 0.2904 - val_model_3_accuracy: 0.2750 - val_model_4_accuracy: 0.1863 - val_loss1: 0.6980 - val_loss2: 5.5526
# Epoch 299/300
# 3/3 [==============================] - 5s 3s/step - loss: 0.8955 - model_loss: 0.0333 - model_1_loss: 0.0132 - model_2_loss: 0.0281 - model_3_loss: 0.0128 - model_4_loss: 0.0204 - model_accuracy: 1.0000 - model_1_accuracy: 1.0000 - model_2_accuracy: 1.0000 - model_3_accuracy: 1.0000 - model_4_accuracy: 1.0000 - loss1: 0.1935 - loss2: 5.9409 - val_loss: 16.2051 - val_model_loss: 2.8684 - val_model_1_loss: 2.9621 - val_model_2_loss: 2.6485 - val_model_3_loss: 3.0423 - val_model_4_loss: 3.4391 - val_model_accuracy: 0.2463 - val_model_1_accuracy: 0.2533 - val_model_2_accuracy: 0.2875 - val_model_3_accuracy: 0.2817 - val_model_4_accuracy: 0.1713 - val_loss1: 0.6887 - val_loss2: 5.5602
# Epoch 300/300
# 3/3 [==============================] - 5s 3s/step - loss: 0.8362 - model_loss: 0.0294 - model_1_loss: 0.0074 - model_2_loss: 0.0245 - model_3_loss: 0.0195 - model_4_loss: 0.0103 - model_accuracy: 1.0000 - model_1_accuracy: 1.0000 - model_2_accuracy: 1.0000 - model_3_accuracy: 1.0000 - model_4_accuracy: 1.0000 - loss1: 0.1529 - loss2: 5.9212 - val_loss: 16.7957 - val_model_loss: 3.0249 - val_model_1_loss: 2.9305 - val_model_2_loss: 2.7759 - val_model_3_loss: 3.3483 - val_model_4_loss: 3.4610 - val_model_accuracy: 0.2367 - val_model_1_accuracy: 0.2683 - val_model_2_accuracy: 0.2821 - val_model_3_accuracy: 0.2750 - val_model_4_accuracy: 0.1729 - val_loss1: 0.6992 - val_loss2: 5.5586
# Epoch 00288: early stopping and save the model

# %%
#evaluation of the five base models
evaluate = model_train.evaluate(x_test,[keras.utils.to_categorical(y_test),keras.utils.to_categorical(y_test),keras.utils.to_categorical(y_test),keras.utils.to_categorical(y_test),keras.utils.to_categorical(y_test)],batch_size=10)
evaluate
# Out:
# 2160/2160 [==============================] - 51s 22ms/step - loss: 14.9405 - model_loss: 2.5651 - model_1_loss: 2.5331 - model_2_loss: 2.9577 - model_3_loss: 2.7639 - model_4_loss: 2.7724 - model_accuracy: 0.3486 - model_1_accuracy: 0.3621 - model_2_accuracy: 0.3236 - model_3_accuracy: 0.3380 - model_4_accuracy: 0.3213 - loss1: 0.7888 - loss2: 5.5949

# %%
#hard voting ensemble
class HardVotingEnsemble:
    def __init__(self, model, testdata ,batch_size):
        self.ensemble_model = model
        self.testdata = testdata
        self.batch_size = batch_size
        self.data_size = testdata[1].shape[0]
    def prediction(self):
        predictions =[]
        for i in range(int(self.data_size/self.batch_size)):
            batch_predictions = np.argmax(self.ensemble_model.predict(self.testdata[0][i*self.batch_size:(i+1)*self.batch_size]),axis=2) 
            batch_predictions = np.stack(batch_predictions, axis=1)
            batch_predictions = [np.argmax(np.bincount(pre)) for pre in batch_predictions]
            predictions = predictions+batch_predictions
        return np.array(predictions)

    def evaluate(self):
        predictions = self.prediction()
        accuracy = np.sum(
            predictions == self.testdata[1]) / self.data_size
        return accuracy
HEnsemble = HardVotingEnsemble(model = model_train,testdata = (x_test, y_test),batch_size=10)
HEnsemble.evaluate()
# Out:
# 0.3439351851851852

# %%
#soft voting ensemble
def SoftVotingEnsemble(model, x, y):
  data_size = x.shape[0]
  predictions = tf.argmax(tf.reduce_mean(model.predict(x), axis = 0),axis=1)
  accuracy = np.sum(
     predictions == y) / data_size
  return accuracy
SoftVotingEnsemble(model_train, x_test, y_test)
# Out:
# 0.3526851851851852

# %%
class eCustomEarlyStoppingAndSave(keras.callbacks.Callback):
    def __init__(self, save_path, patience=0):
        super(eCustomEarlyStoppingAndSave, self).__init__()
        #self.patience = patience
        self.save_path = save_path
        self.best_weights = None

    def on_train_begin(self, logs=None):
        #self.wait = 0
        self.stopped_epoch = 0
        #self.best_val_distance_loss = np.Inf
        self.best_val_acc = 0

    def on_epoch_end(self, epoch, logs=None):
        #val_distance_loss = logs.get('val_MMD_loss')
        val_acc = logs.get('val_accuracy') 

        if  np.greater(val_acc, self.best_val_acc):
            #self.best_val_distance_loss = val_distance_loss
            self.best_val_acc = val_acc
            #self.wait = 0
            # Record the best weights if current results is better (less).
            self.best_weights = self.model.get_weights()
            self.stopped_epoch = epoch
        #else:
            #self.wait += 1
            #if self.wait >= self.patience:
                #self.stopped_epoch = epoch
                #self.model.stop_training = True
                #print("Restoring model weights from the end of the best epoch.")
                #self.model.set_weights(self.best_weights)

    def on_train_end(self, logs=None):
        self.model.set_weights(self.best_weights)
        if self.stopped_epoch >= 0:
            print("Epoch %05d: early stopping and save the model" %
                  (self.stopped_epoch + 1))
        #self.model.save(self.save_path)

# %%
class eNEUdata(keras.utils.Sequence):
    def __init__(self, data_x, data_y, batch_size, train):
      self.data_x = data_x
      self.data_y = data_y
      self.train = train
      self.batch_size = batch_size

    def __len__(self):
      return int(np.ceil(len(self.data_y) / self.batch_size))

    def __getitem__(self, idx):
      batch_x = self.data_x[idx * self.batch_size:(idx + 1) * self.batch_size]
                            
      batch_y = self.data_y[idx * self.batch_size:(idx + 1) * self.batch_size]
      if self.train == True:
          batch_x = Data_Aug(batch_x)

      batch_x = np.clip(batch_x / 255.0, 0, 1).astype("float32")
      batch_y = keras.utils.to_categorical(batch_y, 6)
      return batch_x, batch_y

# %%
#feature fusion model
input_size = (64, 64, 3)
model_path = '/content/drive/MyDrive/TEXexperiment/ResNet/experiment/5_samples_seed_fix_m1_m0.1.h5'
model = keras.models.load_model(model_path)
extractor_1 = keras.models.Model(inputs=model.layers[1].inputs,outputs=model.layers[1].layers[56].output)
extractor_2 = keras.models.Model(inputs=model.layers[2].inputs,outputs=model.layers[2].layers[56].output)
extractor_3 = keras.models.Model(inputs=model.layers[3].inputs,outputs=model.layers[3].layers[56].output)
extractor_4 = keras.models.Model(inputs=model.layers[4].inputs,outputs=model.layers[4].layers[56].output)
extractor_5 = keras.models.Model(inputs=model.layers[5].inputs,outputs=model.layers[5].layers[56].output)
extractor_1.trainable = False
extractor_2.trainable = False
extractor_3.trainable = False
extractor_4.trainable = False
extractor_5.trainable = False
inputs = keras.Input(shape = input_size)
features_1 = extractor_1(inputs, training = False)
features_2 = extractor_2(inputs, training = False)
features_3 = extractor_3(inputs, training = False)
features_4 = extractor_4(inputs, training = False)
features_5 = extractor_5(inputs, training = False)

x = keras.layers.Concatenate(axis=-1)([features_1,features_2,features_3,features_4,features_5])

x = keras.layers.Flatten()(x)
x = keras.layers.Dense(128,  name='dense_100')(x)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.Activation('relu')(x)
x = keras.layers.Dropout(0.5)(x)
outputs = keras.layers.Dense(6, activation='softmax', name='dense_101')(x)
ensemble = keras.Model(inputs = inputs, outputs = outputs)
ensemble.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-5),
                    loss='categorical_crossentropy',
                    metrics=['accuracy'])
train_sequence = eNEUdata(x_train, y_train, batch_size=10, train=False)
validation_sequence = eNEUdata(x_val, y_val, batch_size=10, train=False)
history = ensemble.fit(
    train_sequence,
    epochs=50,
    validation_data=validation_sequence,
    #validation_steps=200,
    callbacks=eCustomEarlyStoppingAndSave(
        save_path='ensemble.h5',
        patience=10))
evaluate = ensemble.evaluate(x_test,keras.utils.to_categorical(y_test),batch_size=10)
# Out:
# Epoch 1/50
# 3/3 [==============================] - 11s 3s/step - loss: 2.4322 - accuracy: 0.2000 - val_loss: 3.0125 - val_accuracy: 0.1821
# Epoch 2/50
# 3/3 [==============================] - 5s 2s/step - loss: 1.9817 - accuracy: 0.3667 - val_loss: 3.0345 - val_accuracy: 0.1850
# Epoch 3/50
# 3/3 [==============================] - 5s 2s/step - loss: 1.1647 - accuracy: 0.6000 - val_loss: 3.0444 - val_accuracy: 0.1912
# Epoch 4/50
# 3/3 [==============================] - 5s 2s/step - loss: 1.1044 - accuracy: 0.6000 - val_loss: 3.0521 - val_accuracy: 0.1946
# Epoch 5/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.7773 - accuracy: 0.8000 - val_loss: 3.0510 - val_accuracy: 0.1983
# Epoch 6/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.5843 - accuracy: 0.7667 - val_loss: 3.0325 - val_accuracy: 0.2058
# Epoch 7/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.4304 - accuracy: 0.9667 - val_loss: 3.0019 - val_accuracy: 0.2125
# Epoch 8/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.4223 - accuracy: 0.9000 - val_loss: 2.9598 - val_accuracy: 0.2188
# Epoch 9/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.3745 - accuracy: 0.9333 - val_loss: 2.9201 - val_accuracy: 0.2237
# Epoch 10/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.2652 - accuracy: 1.0000 - val_loss: 2.8716 - val_accuracy: 0.2296
# Epoch 11/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.2878 - accuracy: 1.0000 - val_loss: 2.8250 - val_accuracy: 0.2329
# Epoch 12/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.2442 - accuracy: 1.0000 - val_loss: 2.7789 - val_accuracy: 0.2417
# Epoch 13/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.1915 - accuracy: 0.9667 - val_loss: 2.7376 - val_accuracy: 0.2454
# Epoch 14/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.1908 - accuracy: 0.9667 - val_loss: 2.6955 - val_accuracy: 0.2500
# Epoch 15/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.1229 - accuracy: 1.0000 - val_loss: 2.6540 - val_accuracy: 0.2546
# Epoch 16/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.1720 - accuracy: 0.9667 - val_loss: 2.6141 - val_accuracy: 0.2554
# Epoch 17/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.1100 - accuracy: 1.0000 - val_loss: 2.5864 - val_accuracy: 0.2596
# Epoch 18/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.1241 - accuracy: 1.0000 - val_loss: 2.5595 - val_accuracy: 0.2612
# Epoch 19/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.1399 - accuracy: 0.9667 - val_loss: 2.5343 - val_accuracy: 0.2608
# Epoch 20/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.1046 - accuracy: 1.0000 - val_loss: 2.5103 - val_accuracy: 0.2629
# Epoch 21/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.0963 - accuracy: 1.0000 - val_loss: 2.4832 - val_accuracy: 0.2625
# Epoch 22/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.1818 - accuracy: 0.9667 - val_loss: 2.4567 - val_accuracy: 0.2625
# Epoch 23/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.1203 - accuracy: 1.0000 - val_loss: 2.4318 - val_accuracy: 0.2637
# Epoch 24/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.0923 - accuracy: 1.0000 - val_loss: 2.4066 - val_accuracy: 0.2683
# Epoch 25/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.0993 - accuracy: 1.0000 - val_loss: 2.3862 - val_accuracy: 0.2688
# Epoch 26/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.1021 - accuracy: 1.0000 - val_loss: 2.3685 - val_accuracy: 0.2721
# Epoch 27/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.0597 - accuracy: 1.0000 - val_loss: 2.3512 - val_accuracy: 0.2721
# Epoch 28/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.0767 - accuracy: 1.0000 - val_loss: 2.3329 - val_accuracy: 0.2717
# Epoch 29/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.1378 - accuracy: 1.0000 - val_loss: 2.3156 - val_accuracy: 0.2721
# Epoch 30/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.0798 - accuracy: 1.0000 - val_loss: 2.2974 - val_accuracy: 0.2713
# Epoch 31/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.0952 - accuracy: 1.0000 - val_loss: 2.2794 - val_accuracy: 0.2738
# Epoch 32/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.0737 - accuracy: 1.0000 - val_loss: 2.2609 - val_accuracy: 0.2729
# Epoch 33/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.0721 - accuracy: 1.0000 - val_loss: 2.2440 - val_accuracy: 0.2721
# Epoch 34/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.0633 - accuracy: 1.0000 - val_loss: 2.2271 - val_accuracy: 0.2742
# Epoch 35/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.0754 - accuracy: 1.0000 - val_loss: 2.2107 - val_accuracy: 0.2746
# Epoch 36/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.1065 - accuracy: 1.0000 - val_loss: 2.1967 - val_accuracy: 0.2738
# Epoch 37/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.0431 - accuracy: 1.0000 - val_loss: 2.1822 - val_accuracy: 0.2758
# Epoch 38/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.0555 - accuracy: 1.0000 - val_loss: 2.1687 - val_accuracy: 0.2771
# Epoch 39/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.0841 - accuracy: 1.0000 - val_loss: 2.1561 - val_accuracy: 0.2796
# Epoch 40/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.1004 - accuracy: 1.0000 - val_loss: 2.1546 - val_accuracy: 0.2800
# Epoch 41/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.0641 - accuracy: 1.0000 - val_loss: 2.1502 - val_accuracy: 0.2783
# Epoch 42/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.0811 - accuracy: 1.0000 - val_loss: 2.1433 - val_accuracy: 0.2775
# Epoch 43/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.0735 - accuracy: 1.0000 - val_loss: 2.1352 - val_accuracy: 0.2783
# Epoch 44/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.0856 - accuracy: 1.0000 - val_loss: 2.1262 - val_accuracy: 0.2779
# Epoch 45/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.0595 - accuracy: 1.0000 - val_loss: 2.1171 - val_accuracy: 0.2808
# Epoch 46/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.0645 - accuracy: 1.0000 - val_loss: 2.1076 - val_accuracy: 0.2837
# Epoch 47/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.0771 - accuracy: 1.0000 - val_loss: 2.0973 - val_accuracy: 0.2862
# Epoch 48/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.0373 - accuracy: 1.0000 - val_loss: 2.0874 - val_accuracy: 0.2887
# Epoch 49/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.0678 - accuracy: 1.0000 - val_loss: 2.0787 - val_accuracy: 0.2900
# Epoch 50/50
# 3/3 [==============================] - 5s 2s/step - loss: 0.0681 - accuracy: 1.0000 - val_loss: 2.0711 - val_accuracy: 0.2904
# Epoch 00050: early stopping and save the model
# 2160/2160 [==============================] - 45s 20ms/step - loss: 2.0825 - accuracy: 0.2902

# %%
#finetuning
extractor_1.trainable = True
extractor_2.trainable = True
extractor_3.trainable = True
extractor_4.trainable = True
extractor_5.trainable = True
ensemble.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-5),
                    loss='categorical_crossentropy',
                    metrics=['accuracy'])
#train_sequence = ecifar10data(sampled_x_train, sampled_y_train, batch_size=10, train=False)
#validation_sequence = ecifar10data(x_val, y_val, batch_size=10, train=False)
history = ensemble.fit(
    train_sequence,
    epochs=20,
    validation_data=validation_sequence,
    #validation_steps=200,
    callbacks=eCustomEarlyStoppingAndSave(
        save_path='ensemble.h5',
        patience=10))
evaluate = ensemble.evaluate(x_test,keras.utils.to_categorical(y_test),batch_size=10)
# Out:
# Epoch 1/20
# 3/3 [==============================] - 14s 3s/step - loss: 0.0464 - accuracy: 1.0000 - val_loss: 2.0628 - val_accuracy: 0.2912
# Epoch 2/20
# 3/3 [==============================] - 5s 3s/step - loss: 0.0525 - accuracy: 1.0000 - val_loss: 2.0614 - val_accuracy: 0.2946
# Epoch 3/20
# 3/3 [==============================] - 5s 3s/step - loss: 0.0336 - accuracy: 1.0000 - val_loss: 2.0646 - val_accuracy: 0.2988
# Epoch 4/20
# 3/3 [==============================] - 5s 2s/step - loss: 0.0349 - accuracy: 1.0000 - val_loss: 2.0656 - val_accuracy: 0.2971
# Epoch 5/20
# 3/3 [==============================] - 5s 2s/step - loss: 0.0383 - accuracy: 1.0000 - val_loss: 2.0740 - val_accuracy: 0.2975
# Epoch 6/20
# 3/3 [==============================] - 5s 2s/step - loss: 0.0712 - accuracy: 1.0000 - val_loss: 2.0933 - val_accuracy: 0.2979
# Epoch 7/20
# 3/3 [==============================] - 5s 2s/step - loss: 0.0643 - accuracy: 1.0000 - val_loss: 2.1041 - val_accuracy: 0.2954
# Epoch 8/20
# 3/3 [==============================] - 5s 2s/step - loss: 0.0556 - accuracy: 1.0000 - val_loss: 2.1044 - val_accuracy: 0.2921
# Epoch 9/20
# 3/3 [==============================] - 5s 2s/step - loss: 0.0313 - accuracy: 1.0000 - val_loss: 2.0977 - val_accuracy: 0.2996
# Epoch 10/20
# 3/3 [==============================] - 5s 2s/step - loss: 0.0383 - accuracy: 1.0000 - val_loss: 2.0873 - val_accuracy: 0.3004
# Epoch 11/20
# 3/3 [==============================] - 5s 2s/step - loss: 0.0513 - accuracy: 1.0000 - val_loss: 2.0777 - val_accuracy: 0.3017
# Epoch 12/20
# 3/3 [==============================] - 5s 2s/step - loss: 0.0370 - accuracy: 1.0000 - val_loss: 2.0738 - val_accuracy: 0.3038
# Epoch 13/20
# 3/3 [==============================] - 5s 2s/step - loss: 0.0277 - accuracy: 1.0000 - val_loss: 2.0717 - val_accuracy: 0.3017
# Epoch 14/20
# 3/3 [==============================] - 5s 2s/step - loss: 0.0757 - accuracy: 1.0000 - val_loss: 2.0686 - val_accuracy: 0.3004
# Epoch 15/20
# 3/3 [==============================] - 5s 2s/step - loss: 0.0331 - accuracy: 1.0000 - val_loss: 2.0675 - val_accuracy: 0.3000
# Epoch 16/20
# 3/3 [==============================] - 5s 2s/step - loss: 0.0508 - accuracy: 1.0000 - val_loss: 2.0595 - val_accuracy: 0.2992
# Epoch 17/20
# 3/3 [==============================] - 5s 2s/step - loss: 0.0511 - accuracy: 1.0000 - val_loss: 2.0481 - val_accuracy: 0.3004
# Epoch 18/20
# 3/3 [==============================] - 5s 2s/step - loss: 0.0556 - accuracy: 1.0000 - val_loss: 2.0374 - val_accuracy: 0.2988
# Epoch 19/20
# 3/3 [==============================] - 5s 2s/step - loss: 0.0305 - accuracy: 1.0000 - val_loss: 2.0303 - val_accuracy: 0.3004
# Epoch 20/20
# 3/3 [==============================] - 5s 2s/step - loss: 0.0294 - accuracy: 1.0000 - val_loss: 2.0216 - val_accuracy: 0.3013
# Epoch 00012: early stopping and save the model
# 2160/2160 [==============================] - 44s 20ms/step - loss: 2.0942 - accuracy: 0.2994

# %%
#f1 score
predict = tf.argmax(ensemble.predict(x_test),axis=-1)
classification_report(y_test, predict,digits=4)
# Out:
# '              precision    recall  f1-score   support\n\n           0     0.7352    0.0517    0.0965      3600\n           1     0.2160    0.4167    0.2845      3600\n           2     0.2879    0.6733    0.4033      3600\n           3     0.2060    0.0322    0.0557      3600\n           4     0.3974    0.5064    0.4453      3600\n           5     0.5024    0.1164    0.1890      3600\n\n    accuracy                         0.2994     21600\n   macro avg     0.3908    0.2994    0.2457     21600\nweighted avg     0.3908    0.2994    0.2457     21600\n'
