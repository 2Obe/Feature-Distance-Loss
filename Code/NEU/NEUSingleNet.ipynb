# %%
#unzip NEU datasets
# !unzip '/content/drive/MyDrive/NEU/NEU_validation.zip' -d '/content'
# !unzip '/content/drive/MyDrive/NEU/NEU_test.zip' -d '/content'
# !unzip '/content/drive/MyDrive/NEU/100_samples.zip' -d '/content'
# !unzip '/content/drive/MyDrive/NEU/50_samples.zip' -d '/content'
# !unzip '/content/drive/MyDrive/NEU/20_samples.zip' -d '/content'
# !unzip '/content/drive/MyDrive/NEU/10_samples.zip' -d '/content'
# !unzip '/content/drive/MyDrive/NEU/5_samples.zip' -d '/content'
# !unzip '/content/drive/MyDrive/NEU/3_samples.zip' -d '/content'
# Out:
# "!unzip '/content/drive/MyDrive/NEU/NEU_validation.zip' -d '/content'\n!unzip '/content/drive/MyDrive/NEU/NEU_test.zip' -d '/content'\n!unzip '/content/drive/MyDrive/NEU/100_samples.zip' -d '/content'\n!unzip '/content/drive/MyDrive/NEU/50_samples.zip' -d '/content'\n!unzip '/content/drive/MyDrive/NEU/20_samples.zip' -d '/content'\n!unzip '/content/drive/MyDrive/NEU/10_samples.zip' -d '/content'\n!unzip '/content/drive/MyDrive/NEU/5_samples.zip' -d '/content'\n!unzip '/content/drive/MyDrive/NEU/3_samples.zip' -d '/content'\n"

# %%
import random
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import tensorflow.keras.backend as K
from tensorflow import keras
from sklearn import model_selection
import imgaug.augmenters as iaa
import imgaug as ia
import os

# %%
#image augmentation
ia.seed(1)
def Data_Aug(samples):
    randomaug = iaa.Sometimes(
        0.5,
        iaa.OneOf([
            iaa.Sequential([
                iaa.AllChannelsCLAHE(clip_limit=(1, 10)),
                iaa.Affine(rotate=(-5, 5))
            ]),
            iaa.Sequential([
                iaa.Affine(translate_percent={
                    "x": (-0.2, 0.2),
                    "y": (-0.2, 0.2)
                }),
                iaa.Multiply((0.7, 1.3)),
                iaa.AdditiveLaplaceNoise(scale=0.03 * 255, per_channel=True),
                iaa.Fliplr(0.3),
                iaa.Flipud(0.3)
            ]),
            iaa.Sequential([
                iaa.Affine(rotate=(-10, 10)),
                iaa.Multiply((0.7, 1.3)),
                iaa.AdditiveLaplaceNoise(scale=0.03 * 255, per_channel=True),
                iaa.Fliplr(0.3),
                iaa.Flipud(0.3)
            ]),
            iaa.Sequential([
                iaa.PerspectiveTransform(scale=(0, 0.15)),
                iaa.Multiply((0.7, 1.3)),
                iaa.AdditiveLaplaceNoise(scale=0.03 * 255, per_channel=True),
                iaa.Fliplr(0.3),
                iaa.Flipud(0.3)
            ])
        ]))


    return randomaug.augment_images(samples)

def resize_images(imgs, hight, width):
    seq = iaa.Resize({"height": hight, "width": width})
    aug = seq.augment_images(imgs)
    return aug

# %%
#load NEU images
def load_data(dir_path, labels_dict):
  all_names = os.listdir(dir_path)
  data_x = []
  data_y = []
  for name in all_names:
    img = keras.preprocessing.image.load_img(os.path.join(dir_path, name))
    img = keras.preprocessing.image.img_to_array(img,dtype='uint8')
    data_x.append(img)
    lab = labels_dict[name[:2]]
    data_y.append(lab)
  data_x = np.array(data_x)
  data_y = np.array(data_y)
  return data_x, data_y
class NEUdata(keras.utils.Sequence):
    def __init__(self, data_x, data_y, batch_size, train):
      self.data_x = data_x
      self.data_y = data_y
      self.train = train
      self.batch_size = batch_size

    def __len__(self):
      return int(np.ceil(len(self.data_y) / self.batch_size))

    def __getitem__(self, idx):
      batch_x = self.data_x[idx * self.batch_size:(idx + 1) * self.batch_size]
                            
      batch_y = self.data_y[idx * self.batch_size:(idx + 1) * self.batch_size]
      if self.train == True:
          batch_x = Data_Aug(batch_x)

      batch_x = np.clip(batch_x / 255.0, 0, 1).astype("float32")
      batch_y = keras.utils.to_categorical(batch_y, 6)
      return batch_x, batch_y

# %%
#save the best model during training
class CustomEarlyStoppingAndSave(keras.callbacks.Callback):
    def __init__(self, save_path, patience=0):
        super(CustomEarlyStoppingAndSave, self).__init__()
        #self.patience = patience
        self.save_path = save_path
        self.best_weights = None

    def on_train_begin(self, logs=None):
        #self.wait = 0
        self.stopped_epoch = 0
        #self.best_val_distance_loss = np.Inf
        self.best_val_acc = 0

    def on_epoch_end(self, epoch, logs=None):
        #val_distance_loss = logs.get('val_MMD_loss')
        val_acc = logs.get('val_accuracy') 

        if  np.greater(val_acc, self.best_val_acc):
            #self.best_val_distance_loss = val_distance_loss
            self.best_val_acc = val_acc
            #self.wait = 0
            # Record the best weights if current results is better (less).
            self.best_weights = self.model.get_weights()
            self.stopped_epoch = epoch
        #else:
            #self.wait += 1
            #if self.wait >= self.patience:
                #self.stopped_epoch = epoch
                #self.model.stop_training = True
                #print("Restoring model weights from the end of the best epoch.")
                #self.model.set_weights(self.best_weights)

    def on_train_end(self, logs=None):
        self.model.set_weights(self.best_weights)
        if self.stopped_epoch >= 0:
            print("Epoch %05d: early stopping and save the model" %
                  (self.stopped_epoch + 1))
        self.model.save(self.save_path)

# %%
#create single AlexNet
def create_AlexNet(input_shape, num_classes=6, random_seed=None):
  inputs = keras.Input(shape=input_shape)
  x = keras.layers.Conv2D(96, (3,3), strides=(2,2), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(inputs)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x)
  x = keras.layers.MaxPooling2D(pool_size=(3,3),strides=(2,2),padding='same')(x)
  
  x = keras.layers.Conv2D(256, (3,3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x) 
  x = keras.layers.MaxPooling2D(pool_size=(3,3),strides=(2,2),padding='same')(x)
 
  x = keras.layers.Conv2D(384, (3,3), padding='same', activation='relu', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x) 
  x = keras.layers.Conv2D(384, (3,3), padding='same', activation='relu', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x) 
  x = keras.layers.Conv2D(256, (3,3), padding='same', activation='relu', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  feature_maps = keras.layers.MaxPooling2D(pool_size=(3,3),strides=(2,2),padding='same')(x)
  
  x = keras.layers.Flatten()(feature_maps)
  #x = keras.layers.Dense(256,activation='relu')(x)
  #x = keras.layers.Dropout(0.5)(x)
  x = keras.layers.Dense(128,activation='relu')(x)
  x = keras.layers.Dropout(0.5)(x)
  outputs = keras.layers.Dense(num_classes, activation='softmax')(x)
  model = keras.Model(inputs=inputs, outputs=outputs)
  return model

# %%
def create_VGGNet(input_shape, num_classes,  random_seed=None):
  inputs = keras.Input(shape=input_shape)
  x = keras.layers.Conv2D(64, (3, 3), padding='same',  kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(inputs)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x)
  x = keras.layers.Conv2D(64, (3, 3), padding='same',  kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x)
  x = keras.layers.MaxPooling2D((2, 2))(x)
  x = keras.layers.Dropout(0.2)(x)

  x = keras.layers.Conv2D(128, (3, 3), padding='same',  kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x)
  x = keras.layers.Conv2D(128, (3, 3), padding='same',  kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x)
  x = keras.layers.MaxPooling2D((2, 2))(x)
  x = keras.layers.Dropout(0.3)(x)

  x = keras.layers.Conv2D(256, (3, 3), padding='same',  kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x)
  x = keras.layers.Conv2D(256, (3, 3), padding='same',  kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x)
  x = keras.layers.Conv2D(256, (3, 3), padding='same',  kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x)
  x = keras.layers.MaxPooling2D((2, 2))(x)
  x = keras.layers.Dropout(0.4)(x)


    
  x = keras.layers.Conv2D(512, (3, 3), padding='same',  kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x)
  x = keras.layers.Conv2D(512, (3, 3), padding='same',  kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x)
  x = keras.layers.Conv2D(512, (3, 3), padding='same',  kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x)
  p3 = keras.layers.MaxPooling2D((2, 2))(x)
  x = keras.layers.Dropout(0.5)(p3)


 
  '''
  x = keras.layers.Conv2D(512, (3, 3), padding='same',  kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x)
  x = keras.layers.Conv2D(512, (3, 3), padding='same',  kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x)
  x = keras.layers.Conv2D(512, (3, 3), padding='same',  kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x)
  x = keras.layers.MaxPooling2D((2, 2))(x)
  x = keras.layers.Dropout(0.5)(x)
  ''' 
 

  #x = keras.layers.GlobalAveragePooling2D()(x)
  x = keras.layers.Flatten()(x)
  x = keras.layers.Dense(128,  kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x)
  x = keras.layers.Dropout(0.5)(x)
  outputs = keras.layers.Dense(num_classes, activation='softmax')(x)
  return keras.Model(inputs=inputs, outputs=outputs)

# %%
def create_ResNet(input_shape, num_classes=6, num_filters = 64, random_seed=None):
  inputs = keras.Input(shape=input_shape)
  y = keras.layers.Conv2D(num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(inputs)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  y = keras.layers.Conv2D(num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(y)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  y = keras.layers.Conv2D(num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(y)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  x = keras.layers.Conv2D(num_filters, (1, 1), kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(inputs)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.add([x, y])
  x = keras.layers.LeakyReLU(alpha=0.1)(x)
  x = keras.layers.MaxPooling2D((2,2))(x)

  y = keras.layers.Conv2D(2*num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  y = keras.layers.Conv2D(2*num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(y)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  y = keras.layers.Conv2D(2*num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(y)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  x = keras.layers.Conv2D(2*num_filters, (1, 1), kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.add([x, y])
  x = keras.layers.LeakyReLU(alpha=0.1)(x)
  x = keras.layers.MaxPooling2D((2,2))(x) 

  y = keras.layers.Conv2D(4*num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  y = keras.layers.Conv2D(4*num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(y)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  y = keras.layers.Conv2D(4*num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(y)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  x = keras.layers.Conv2D(4*num_filters, (1, 1), kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.add([x, y])
  x = keras.layers.LeakyReLU(alpha=0.1)(x)
  x = keras.layers.MaxPooling2D((2,2))(x) 

    
  y = keras.layers.Conv2D(8*num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  y = keras.layers.Conv2D(8*num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(y)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  y = keras.layers.Conv2D(8*num_filters, (3, 3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(y)
  y = keras.layers.BatchNormalization()(y)
  y = keras.layers.LeakyReLU(alpha=0.1)(y)
  x = keras.layers.Conv2D(8*num_filters, (1, 1), kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.add([x, y])
  x = keras.layers.LeakyReLU(alpha=0.1)(x)
  x = keras.layers.MaxPooling2D((2,2))(x) 
  

  x = keras.layers.GlobalAveragePooling2D()(x)
  outputs = keras.layers.Dense(num_classes, activation='softmax', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  model = keras.Model(inputs=inputs, outputs=outputs)
  return model

# %%
#load training, validation and testing images
training_data_path = '3_samples'
validation_data_path = 'NEU_validation'
test_data_path = 'NEU_test'
labels_dict = {'Cr': 0, 'In': 1, 'Pa': 2, 'PS': 3, 'RS': 4, 'Sc': 5}
x_train, y_train = load_data(training_data_path, labels_dict)
x_val, y_val = load_data(validation_data_path, labels_dict)
x_test, y_test = load_data(test_data_path, labels_dict)

# %%
#construct model
input_size = (200, 200, 3)

model = create_AlexNet(input_shape=input_size, num_classes=6,  random_seed=None)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4),
                    loss=['categorical_crossentropy'],
                    metrics=['accuracy'])

train_sequence = NEUdata(x_train, y_train, batch_size=10, train=True)
validation_sequence = NEUdata(x_val, y_val, batch_size=10, train=False)

#training
history = model.fit(
    train_sequence,
    epochs=300,
    validation_data=validation_sequence,
    #validation_steps=12,
    callbacks=CustomEarlyStoppingAndSave(
        save_path='100_samples_seed_fix.h5',
        patience=10))
# Out:
# Epoch 1/300
# 2/2 [==============================] - 6s 1s/step - loss: 4.7656 - accuracy: 0.2222 - val_loss: 2.5764 - val_accuracy: 0.2028
# Epoch 2/300
# 2/2 [==============================] - 1s 521ms/step - loss: 5.9096 - accuracy: 0.1111 - val_loss: 2.4250 - val_accuracy: 0.1667
# Epoch 3/300
# 2/2 [==============================] - 1s 514ms/step - loss: 4.4949 - accuracy: 0.1667 - val_loss: 2.4464 - val_accuracy: 0.1556
# Epoch 4/300
# 2/2 [==============================] - 1s 511ms/step - loss: 3.9739 - accuracy: 0.1667 - val_loss: 1.9759 - val_accuracy: 0.1583
# Epoch 5/300
# 2/2 [==============================] - 1s 500ms/step - loss: 3.2706 - accuracy: 0.2222 - val_loss: 1.8643 - val_accuracy: 0.1667
# Epoch 6/300
# 2/2 [==============================] - 1s 504ms/step - loss: 1.9534 - accuracy: 0.4444 - val_loss: 1.8529 - val_accuracy: 0.1667
# Epoch 7/300
# 2/2 [==============================] - 1s 541ms/step - loss: 1.6407 - accuracy: 0.5556 - val_loss: 1.8460 - val_accuracy: 0.1667
# Epoch 8/300
# 2/2 [==============================] - 1s 505ms/step - loss: 1.7180 - accuracy: 0.5556 - val_loss: 1.8048 - val_accuracy: 0.1694
# Epoch 9/300
# 2/2 [==============================] - 1s 564ms/step - loss: 1.7967 - accuracy: 0.3333 - val_loss: 1.7775 - val_accuracy: 0.1694
# Epoch 10/300
# 2/2 [==============================] - 1s 533ms/step - loss: 1.3812 - accuracy: 0.4444 - val_loss: 1.7610 - val_accuracy: 0.1694
# Epoch 11/300
# 2/2 [==============================] - 1s 491ms/step - loss: 1.3228 - accuracy: 0.4444 - val_loss: 1.7572 - val_accuracy: 0.1722
# Epoch 12/300
# 2/2 [==============================] - 1s 546ms/step - loss: 1.2894 - accuracy: 0.3333 - val_loss: 1.7797 - val_accuracy: 0.1833
# Epoch 13/300
# 2/2 [==============================] - 1s 511ms/step - loss: 1.3748 - accuracy: 0.5000 - val_loss: 1.7955 - val_accuracy: 0.1694
# Epoch 14/300
# 2/2 [==============================] - 1s 519ms/step - loss: 1.3947 - accuracy: 0.5556 - val_loss: 1.7853 - val_accuracy: 0.1667
# Epoch 15/300
# 2/2 [==============================] - 1s 473ms/step - loss: 1.2504 - accuracy: 0.5000 - val_loss: 1.7804 - val_accuracy: 0.1667
# Epoch 16/300
# 2/2 [==============================] - 1s 503ms/step - loss: 1.2449 - accuracy: 0.6111 - val_loss: 1.7594 - val_accuracy: 0.1667
# Epoch 17/300
# 2/2 [==============================] - 1s 507ms/step - loss: 1.0449 - accuracy: 0.6111 - val_loss: 1.7464 - val_accuracy: 0.1667
# Epoch 18/300
# 2/2 [==============================] - 1s 524ms/step - loss: 1.0999 - accuracy: 0.6111 - val_loss: 1.7358 - val_accuracy: 0.1722
# Epoch 19/300
# 2/2 [==============================] - 1s 523ms/step - loss: 1.1597 - accuracy: 0.4444 - val_loss: 1.7232 - val_accuracy: 0.1972
# Epoch 20/300
# 2/2 [==============================] - 1s 536ms/step - loss: 1.3492 - accuracy: 0.3889 - val_loss: 1.7186 - val_accuracy: 0.2194
# Epoch 21/300
# 2/2 [==============================] - 1s 531ms/step - loss: 1.4623 - accuracy: 0.3889 - val_loss: 1.7166 - val_accuracy: 0.2361
# Epoch 22/300
# 2/2 [==============================] - 1s 521ms/step - loss: 1.3169 - accuracy: 0.5000 - val_loss: 1.7167 - val_accuracy: 0.2250
# Epoch 23/300
# 2/2 [==============================] - 1s 514ms/step - loss: 0.8587 - accuracy: 0.7778 - val_loss: 1.7105 - val_accuracy: 0.2278
# Epoch 24/300
# 2/2 [==============================] - 1s 503ms/step - loss: 1.1388 - accuracy: 0.5000 - val_loss: 1.7007 - val_accuracy: 0.2306
# Epoch 25/300
# 2/2 [==============================] - 1s 566ms/step - loss: 1.0211 - accuracy: 0.6667 - val_loss: 1.6757 - val_accuracy: 0.2694
# Epoch 26/300
# 2/2 [==============================] - 1s 530ms/step - loss: 0.8647 - accuracy: 0.7778 - val_loss: 1.6540 - val_accuracy: 0.2861
# Epoch 27/300
# 2/2 [==============================] - 1s 503ms/step - loss: 0.9457 - accuracy: 0.6667 - val_loss: 1.6337 - val_accuracy: 0.3306
# Epoch 28/300
# 2/2 [==============================] - 1s 524ms/step - loss: 0.7831 - accuracy: 0.6111 - val_loss: 1.6125 - val_accuracy: 0.2611
# Epoch 29/300
# 2/2 [==============================] - 1s 536ms/step - loss: 0.7851 - accuracy: 0.6667 - val_loss: 1.6046 - val_accuracy: 0.2389
# Epoch 30/300
# Epoch 109/300
# 2/2 [==============================] - 1s 477ms/step - loss: 0.6558 - accuracy: 0.9444 - val_loss: 2.6792 - val_accuracy: 0.2583
# Epoch 110/300
# 2/2 [==============================] - 1s 509ms/step - loss: 0.8534 - accuracy: 0.8333 - val_loss: 2.6794 - val_accuracy: 0.2778
# Epoch 111/300
# 2/2 [==============================] - 1s 512ms/step - loss: 0.7121 - accuracy: 0.7778 - val_loss: 2.4940 - val_accuracy: 0.2944
# Epoch 112/300
# 2/2 [==============================] - 1s 490ms/step - loss: 0.3335 - accuracy: 0.8889 - val_loss: 2.3301 - val_accuracy: 0.3000
# Epoch 113/300
# 2/2 [==============================] - 1s 538ms/step - loss: 0.6442 - accuracy: 0.7222 - val_loss: 2.3487 - val_accuracy: 0.2667
# Epoch 114/300
# 2/2 [==============================] - 1s 521ms/step - loss: 0.4709 - accuracy: 0.7222 - val_loss: 2.3441 - val_accuracy: 0.2611
# Epoch 115/300
# 2/2 [==============================] - 1s 524ms/step - loss: 0.7723 - accuracy: 0.8333 - val_loss: 2.3277 - val_accuracy: 0.2806
# Epoch 116/300
# 2/2 [==============================] - 1s 513ms/step - loss: 0.7826 - accuracy: 0.7222 - val_loss: 2.2250 - val_accuracy: 0.3222
# Epoch 117/300
# 2/2 [==============================] - 1s 537ms/step - loss: 0.5582 - accuracy: 0.7222 - val_loss: 2.0405 - val_accuracy: 0.3556
# Epoch 118/300
# 2/2 [==============================] - 1s 535ms/step - loss: 1.1184 - accuracy: 0.5556 - val_loss: 1.8537 - val_accuracy: 0.3750
# Epoch 119/300
# 2/2 [==============================] - 1s 496ms/step - loss: 0.7371 - accuracy: 0.7222 - val_loss: 1.7919 - val_accuracy: 0.3639
# Epoch 120/300
# 2/2 [==============================] - 1s 506ms/step - loss: 0.5442 - accuracy: 0.7778 - val_loss: 1.8552 - val_accuracy: 0.3139
# Epoch 121/300
# 2/2 [==============================] - 1s 490ms/step - loss: 0.5134 - accuracy: 0.7778 - val_loss: 1.8508 - val_accuracy: 0.3556
# Epoch 122/300
# 2/2 [==============================] - 1s 557ms/step - loss: 0.6903 - accuracy: 0.7222 - val_loss: 1.8791 - val_accuracy: 0.3722
# Epoch 123/300
# 2/2 [==============================] - 1s 547ms/step - loss: 0.5907 - accuracy: 0.7222 - val_loss: 1.9348 - val_accuracy: 0.3556
# Epoch 124/300
# 2/2 [==============================] - 1s 497ms/step - loss: 0.4877 - accuracy: 0.8889 - val_loss: 2.0178 - val_accuracy: 0.3333
# Epoch 125/300
# 2/2 [==============================] - 1s 498ms/step - loss: 0.6267 - accuracy: 0.7778 - val_loss: 2.0524 - val_accuracy: 0.3472
# Epoch 126/300
# 2/2 [==============================] - 1s 503ms/step - loss: 0.2966 - accuracy: 0.9444 - val_loss: 2.1088 - val_accuracy: 0.3528
# Epoch 127/300
# 2/2 [==============================] - 1s 520ms/step - loss: 0.4929 - accuracy: 0.7778 - val_loss: 2.1872 - val_accuracy: 0.3694
# Epoch 128/300
# Epoch 187/300
# 2/2 [==============================] - 1s 494ms/step - loss: 0.4318 - accuracy: 0.8889 - val_loss: 2.0714 - val_accuracy: 0.4917
# Epoch 188/300
# 2/2 [==============================] - 1s 524ms/step - loss: 0.6009 - accuracy: 0.8889 - val_loss: 2.0602 - val_accuracy: 0.4889
# Epoch 189/300
# 2/2 [==============================] - 1s 491ms/step - loss: 0.3942 - accuracy: 0.7778 - val_loss: 2.0719 - val_accuracy: 0.4833
# Epoch 190/300
# 2/2 [==============================] - 1s 504ms/step - loss: 0.8262 - accuracy: 0.7222 - val_loss: 2.1239 - val_accuracy: 0.4917
# Epoch 191/300
# 2/2 [==============================] - 1s 488ms/step - loss: 0.2719 - accuracy: 0.8889 - val_loss: 2.2194 - val_accuracy: 0.4889
# Epoch 192/300
# 2/2 [==============================] - 1s 455ms/step - loss: 0.4047 - accuracy: 0.8333 - val_loss: 2.2759 - val_accuracy: 0.4861
# Epoch 193/300
# 2/2 [==============================] - 1s 470ms/step - loss: 0.5844 - accuracy: 0.7778 - val_loss: 2.1826 - val_accuracy: 0.5139
# Epoch 194/300
# 2/2 [==============================] - 1s 501ms/step - loss: 0.4954 - accuracy: 0.7222 - val_loss: 2.1848 - val_accuracy: 0.5111
# Epoch 195/300
# 2/2 [==============================] - 1s 498ms/step - loss: 0.5947 - accuracy: 0.7778 - val_loss: 2.2084 - val_accuracy: 0.5111
# Epoch 196/300
# 2/2 [==============================] - 1s 495ms/step - loss: 0.3694 - accuracy: 0.8889 - val_loss: 2.0900 - val_accuracy: 0.5000
# Epoch 197/300
# 2/2 [==============================] - 1s 480ms/step - loss: 0.5527 - accuracy: 0.9444 - val_loss: 1.9997 - val_accuracy: 0.4806
# Epoch 198/300
# 2/2 [==============================] - 1s 484ms/step - loss: 0.7127 - accuracy: 0.8333 - val_loss: 1.9046 - val_accuracy: 0.4861
# Epoch 199/300
# 2/2 [==============================] - 1s 477ms/step - loss: 0.4963 - accuracy: 0.7222 - val_loss: 1.8352 - val_accuracy: 0.4778
# Epoch 200/300
# 2/2 [==============================] - 1s 499ms/step - loss: 0.3759 - accuracy: 0.8333 - val_loss: 1.8650 - val_accuracy: 0.4750
# Epoch 201/300
# 2/2 [==============================] - 1s 458ms/step - loss: 0.2564 - accuracy: 0.9444 - val_loss: 1.9126 - val_accuracy: 0.4750
# Epoch 202/300
# 2/2 [==============================] - 1s 488ms/step - loss: 0.5594 - accuracy: 0.7778 - val_loss: 1.9691 - val_accuracy: 0.4917
# Epoch 203/300
# 2/2 [==============================] - 1s 488ms/step - loss: 0.3222 - accuracy: 0.8889 - val_loss: 2.0641 - val_accuracy: 0.4889
# Epoch 204/300
# 2/2 [==============================] - 1s 508ms/step - loss: 0.5593 - accuracy: 0.8333 - val_loss: 2.1903 - val_accuracy: 0.4944
# Epoch 205/300
# 2/2 [==============================] - 1s 503ms/step - loss: 0.3575 - accuracy: 0.9444 - val_loss: 2.3311 - val_accuracy: 0.4889
# Epoch 206/300
# Epoch 246/300
# 2/2 [==============================] - 1s 486ms/step - loss: 0.8637 - accuracy: 0.6667 - val_loss: 1.9216 - val_accuracy: 0.4111
# Epoch 247/300
# 2/2 [==============================] - 1s 481ms/step - loss: 0.5080 - accuracy: 0.7778 - val_loss: 1.9183 - val_accuracy: 0.4389
# Epoch 248/300
# 2/2 [==============================] - 1s 484ms/step - loss: 0.8739 - accuracy: 0.7222 - val_loss: 1.9087 - val_accuracy: 0.4417
# Epoch 249/300
# 2/2 [==============================] - 1s 524ms/step - loss: 0.4345 - accuracy: 0.8333 - val_loss: 1.9427 - val_accuracy: 0.4167
# Epoch 250/300
# 2/2 [==============================] - 1s 472ms/step - loss: 0.3978 - accuracy: 0.8889 - val_loss: 2.0175 - val_accuracy: 0.4028
# Epoch 251/300
# 2/2 [==============================] - 1s 532ms/step - loss: 0.2417 - accuracy: 0.8889 - val_loss: 2.1286 - val_accuracy: 0.3861
# Epoch 252/300
# 2/2 [==============================] - 1s 536ms/step - loss: 0.3997 - accuracy: 0.8889 - val_loss: 2.2445 - val_accuracy: 0.3972
# Epoch 253/300
# 2/2 [==============================] - 1s 527ms/step - loss: 0.3640 - accuracy: 0.8333 - val_loss: 2.3559 - val_accuracy: 0.4250
# Epoch 254/300
# 2/2 [==============================] - 1s 495ms/step - loss: 0.2402 - accuracy: 0.9444 - val_loss: 2.4601 - val_accuracy: 0.4750
# Epoch 255/300
# 2/2 [==============================] - 1s 491ms/step - loss: 0.3636 - accuracy: 0.8889 - val_loss: 2.6698 - val_accuracy: 0.4250
# Epoch 256/300
# 2/2 [==============================] - 1s 464ms/step - loss: 0.0817 - accuracy: 1.0000 - val_loss: 3.2116 - val_accuracy: 0.3417
# Epoch 257/300
# 2/2 [==============================] - 1s 518ms/step - loss: 0.6164 - accuracy: 0.8333 - val_loss: 2.5338 - val_accuracy: 0.4639
# Epoch 258/300
# 2/2 [==============================] - 1s 506ms/step - loss: 0.3914 - accuracy: 0.8333 - val_loss: 2.5162 - val_accuracy: 0.4722
# Epoch 259/300
# 2/2 [==============================] - 1s 507ms/step - loss: 0.3905 - accuracy: 0.7778 - val_loss: 2.5967 - val_accuracy: 0.4639
# Epoch 260/300
# 2/2 [==============================] - 1s 509ms/step - loss: 0.3500 - accuracy: 0.8889 - val_loss: 2.6990 - val_accuracy: 0.4639
# Epoch 261/300
# 2/2 [==============================] - 1s 519ms/step - loss: 0.9643 - accuracy: 0.6667 - val_loss: 2.7205 - val_accuracy: 0.4556
# Epoch 262/300
# 2/2 [==============================] - 1s 467ms/step - loss: 0.2621 - accuracy: 0.8889 - val_loss: 2.6547 - val_accuracy: 0.4639
# Epoch 263/300
# 2/2 [==============================] - 1s 487ms/step - loss: 0.8803 - accuracy: 0.7778 - val_loss: 2.3505 - val_accuracy: 0.4611
# Epoch 264/300
# 2/2 [==============================] - 1s 485ms/step - loss: 0.2190 - accuracy: 0.9444 - val_loss: 2.1960 - val_accuracy: 0.3972
# Epoch 265/300
# 2/2 [==============================] - 1s 458ms/step - loss: 0.3336 - accuracy: 0.8889 - val_loss: 2.1455 - val_accuracy: 0.3861
# Epoch 266/300
# 2/2 [==============================] - 1s 484ms/step - loss: 0.1136 - accuracy: 1.0000 - val_loss: 2.1502 - val_accuracy: 0.3944
# Epoch 267/300
# 2/2 [==============================] - 1s 485ms/step - loss: 0.1786 - accuracy: 0.9444 - val_loss: 2.2037 - val_accuracy: 0.3972
# Epoch 268/300
# 2/2 [==============================] - 1s 485ms/step - loss: 0.4443 - accuracy: 0.8333 - val_loss: 2.2674 - val_accuracy: 0.3944
# Epoch 269/300
# 2/2 [==============================] - 1s 443ms/step - loss: 0.4122 - accuracy: 0.8889 - val_loss: 2.3021 - val_accuracy: 0.3944
# Epoch 270/300
# 2/2 [==============================] - 1s 489ms/step - loss: 0.3872 - accuracy: 0.8333 - val_loss: 2.3005 - val_accuracy: 0.3917
# Epoch 271/300
# 2/2 [==============================] - 1s 515ms/step - loss: 0.4668 - accuracy: 0.7778 - val_loss: 2.2818 - val_accuracy: 0.4111
# Epoch 272/300
# 2/2 [==============================] - 1s 513ms/step - loss: 0.5959 - accuracy: 0.6667 - val_loss: 2.3054 - val_accuracy: 0.4083
# Epoch 273/300
# 2/2 [==============================] - 1s 503ms/step - loss: 0.6752 - accuracy: 0.7222 - val_loss: 2.3421 - val_accuracy: 0.3667
# Epoch 274/300
# 2/2 [==============================] - 1s 499ms/step - loss: 0.1958 - accuracy: 0.8889 - val_loss: 2.3724 - val_accuracy: 0.3556
# Epoch 275/300
# 2/2 [==============================] - 1s 500ms/step - loss: 0.4853 - accuracy: 0.8333 - val_loss: 2.3101 - val_accuracy: 0.4000
# Epoch 276/300
# 2/2 [==============================] - 1s 497ms/step - loss: 0.4391 - accuracy: 0.8333 - val_loss: 2.2321 - val_accuracy: 0.4667
# Epoch 277/300
# 2/2 [==============================] - 1s 546ms/step - loss: 0.3910 - accuracy: 0.8889 - val_loss: 2.2091 - val_accuracy: 0.4778
# Epoch 278/300
# 2/2 [==============================] - 1s 531ms/step - loss: 0.4962 - accuracy: 0.7778 - val_loss: 2.1760 - val_accuracy: 0.4861
# Epoch 279/300
# 2/2 [==============================] - 1s 489ms/step - loss: 0.4424 - accuracy: 0.7778 - val_loss: 2.1773 - val_accuracy: 0.4861
# Epoch 280/300
# 2/2 [==============================] - 1s 461ms/step - loss: 0.3432 - accuracy: 0.8889 - val_loss: 2.1812 - val_accuracy: 0.4917
# Epoch 281/300
# 2/2 [==============================] - 1s 488ms/step - loss: 0.2190 - accuracy: 0.9444 - val_loss: 2.2400 - val_accuracy: 0.4833
# Epoch 282/300
# 2/2 [==============================] - 1s 555ms/step - loss: 0.6344 - accuracy: 0.7222 - val_loss: 2.2823 - val_accuracy: 0.4778
# Epoch 283/300
# 2/2 [==============================] - 1s 529ms/step - loss: 0.2993 - accuracy: 0.9444 - val_loss: 2.3513 - val_accuracy: 0.4750
# Epoch 284/300
# 2/2 [==============================] - 1s 477ms/step - loss: 0.2811 - accuracy: 0.8333 - val_loss: 2.4295 - val_accuracy: 0.4667
# Epoch 285/300
# 2/2 [==============================] - 1s 485ms/step - loss: 0.2456 - accuracy: 0.8889 - val_loss: 2.5239 - val_accuracy: 0.4639
# Epoch 286/300
# 2/2 [==============================] - 1s 486ms/step - loss: 0.3871 - accuracy: 0.8333 - val_loss: 2.6511 - val_accuracy: 0.4750
# Epoch 287/300
# 2/2 [==============================] - 1s 464ms/step - loss: 0.0624 - accuracy: 1.0000 - val_loss: 2.8194 - val_accuracy: 0.4778
# Epoch 288/300
# 2/2 [==============================] - 1s 456ms/step - loss: 0.1279 - accuracy: 0.9444 - val_loss: 2.9943 - val_accuracy: 0.4778
# Epoch 289/300
# 2/2 [==============================] - 0s 456ms/step - loss: 0.2969 - accuracy: 0.8333 - val_loss: 3.0561 - val_accuracy: 0.4861
# Epoch 290/300
# 2/2 [==============================] - 1s 508ms/step - loss: 0.6985 - accuracy: 0.7778 - val_loss: 3.0134 - val_accuracy: 0.4806
# Epoch 291/300
# 2/2 [==============================] - 1s 484ms/step - loss: 0.3044 - accuracy: 0.8889 - val_loss: 2.8710 - val_accuracy: 0.4806
# Epoch 292/300
# 2/2 [==============================] - 1s 485ms/step - loss: 0.1848 - accuracy: 0.9444 - val_loss: 2.8460 - val_accuracy: 0.4722
# Epoch 293/300
# 2/2 [==============================] - 1s 469ms/step - loss: 0.3788 - accuracy: 0.8889 - val_loss: 2.7355 - val_accuracy: 0.4722
# Epoch 294/300
# 2/2 [==============================] - 1s 485ms/step - loss: 0.4783 - accuracy: 0.7778 - val_loss: 2.6217 - val_accuracy: 0.4778
# Epoch 295/300
# 2/2 [==============================] - 1s 521ms/step - loss: 0.7384 - accuracy: 0.7222 - val_loss: 2.4098 - val_accuracy: 0.4722
# Epoch 296/300
# 2/2 [==============================] - 1s 532ms/step - loss: 0.4449 - accuracy: 0.8333 - val_loss: 2.2896 - val_accuracy: 0.4778
# Epoch 297/300
# 2/2 [==============================] - 1s 511ms/step - loss: 0.1488 - accuracy: 1.0000 - val_loss: 2.2491 - val_accuracy: 0.4639
# Epoch 298/300
# 2/2 [==============================] - 1s 477ms/step - loss: 0.8848 - accuracy: 0.7778 - val_loss: 2.3031 - val_accuracy: 0.4194
# Epoch 299/300
# 2/2 [==============================] - 1s 519ms/step - loss: 0.7702 - accuracy: 0.7222 - val_loss: 2.2455 - val_accuracy: 0.4111
# Epoch 300/300
# 2/2 [==============================] - 1s 509ms/step - loss: 0.2371 - accuracy: 0.9444 - val_loss: 2.0651 - val_accuracy: 0.4111
# Epoch 00060: early stopping and save the model

# %%
x_test = x_test/255.0

# %%
evaluate1 = model.evaluate(x_test, keras.utils.to_categorical(y_test,6))
evaluate1
# Out:
# 12/12 [==============================] - 1s 24ms/step - loss: 1.8855 - accuracy: 0.3861
# [1.8854811191558838, 0.3861111104488373]

# %%
model_train = keras.models.load_model('100_samples_seed_fix.h5')
evaluate2 = model_train.evaluate(x_test, keras.utils.to_categorical(y_test,6))
evaluate2
# Out:
# 12/12 [==============================] - 0s 17ms/step - loss: 1.8855 - accuracy: 0.3861
# [1.8854811191558838, 0.3861111104488373]
