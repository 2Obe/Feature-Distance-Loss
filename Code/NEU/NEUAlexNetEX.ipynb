# %%
#unzip NEU dataset
# !unzip '/content/drive/MyDrive/NEU/100_samples.zip' -d '/content'
# !unzip '/content/drive/MyDrive/NEU/NEU_validation.zip' -d '/content'
# !unzip '/content/drive/MyDrive/NEU/NEU_test.zip' -d '/content'
# !unzip '/content/drive/MyDrive/NEU/50_samples.zip' -d '/content'
# !unzip '/content/drive/MyDrive/NEU/20_samples.zip' -d '/content'
# !unzip '/content/drive/MyDrive/NEU/10_samples.zip' -d '/content'
# !unzip '/content/drive/MyDrive/NEU/5_samples.zip' -d '/content'
# !unzip '/content/drive/MyDrive/NEU/3_samples.zip' -d '/content'
# Out:
# "\n!unzip '/content/drive/MyDrive/NEU/100_samples.zip' -d '/content'\n!unzip '/content/drive/MyDrive/NEU/NEU_validation.zip' -d '/content'\n!unzip '/content/drive/MyDrive/NEU/NEU_test.zip' -d '/content'\n!unzip '/content/drive/MyDrive/NEU/50_samples.zip' -d '/content'\n!unzip '/content/drive/MyDrive/NEU/20_samples.zip' -d '/content'\n!unzip '/content/drive/MyDrive/NEU/10_samples.zip' -d '/content'\n!unzip '/content/drive/MyDrive/NEU/5_samples.zip' -d '/content'\n!unzip '/content/drive/MyDrive/NEU/3_samples.zip' -d '/content'\n"

# %%
import random
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import tensorflow.keras.backend as K
from tensorflow import keras
from sklearn import model_selection
from sklearn.metrics import classification_report
import imgaug.augmenters as iaa
import imgaug as ia
import os

# %%
ia.seed(1)
def Data_Aug(samples):
    randomaug = iaa.Sometimes(
        0.5,
        iaa.OneOf([
            iaa.Sequential([
                iaa.AllChannelsCLAHE(clip_limit=(1, 10)),
                iaa.Affine(rotate=(-5, 5))
            ]),
            iaa.Sequential([
                iaa.Affine(translate_percent={
                    "x": (-0.2, 0.2),
                    "y": (-0.2, 0.2)
                }),
                iaa.Multiply((0.7, 1.3)),
                iaa.AdditiveLaplaceNoise(scale=0.03 * 255, per_channel=True),
                iaa.Fliplr(0.3),
                iaa.Flipud(0.3)
            ]),
            iaa.Sequential([
                iaa.Affine(rotate=(-10, 10)),
                iaa.Multiply((0.7, 1.3)),
                iaa.AdditiveLaplaceNoise(scale=0.03 * 255, per_channel=True),
                iaa.Fliplr(0.3),
                iaa.Flipud(0.3)
            ]),
            iaa.Sequential([
                iaa.PerspectiveTransform(scale=(0, 0.15)),
                iaa.Multiply((0.7, 1.3)),
                iaa.AdditiveLaplaceNoise(scale=0.03 * 255, per_channel=True),
                iaa.Fliplr(0.3),
                iaa.Flipud(0.3)
            ])
        ]))


    return randomaug.augment_images(samples)

def resize_images(imgs, hight, width):
    seq = iaa.Resize({"height": hight, "width": width})
    aug = seq.augment_images(imgs)
    return aug

# %%
#load NEU dataset
def load_data(dir_path, labels_dict):
  all_names = os.listdir(dir_path)
  data_x = []
  data_y = []
  for name in all_names:
    img = keras.preprocessing.image.load_img(os.path.join(dir_path, name))
    img = keras.preprocessing.image.img_to_array(img,dtype='uint8')
    data_x.append(img)
    lab = labels_dict[name[:2]]
    data_y.append(lab)
  data_x = np.array(data_x)
  data_y = np.array(data_y)
  return data_x, data_y
class NEUdata(keras.utils.Sequence):
    def __init__(self, data_x, data_y, batch_size, train):
      self.data_x = data_x
      self.data_y = data_y
      self.train = train
      self.batch_size = batch_size

    def __len__(self):
      return int(np.ceil(len(self.data_y) / self.batch_size))

    def __getitem__(self, idx):
      batch_x = self.data_x[idx * self.batch_size:(idx + 1) * self.batch_size]
                            
      batch_y = self.data_y[idx * self.batch_size:(idx + 1) * self.batch_size]
      if self.train == True:
          batch_x = Data_Aug(batch_x)

      batch_x = np.clip(batch_x / 255.0, 0, 1).astype("float32")
      batch_y = keras.utils.to_categorical(batch_y, 6)
      return batch_x, [batch_y, batch_y, batch_y, batch_y, batch_y]

# %%
#save the best model during training 
class CustomEarlyStoppingAndSave(keras.callbacks.Callback):
    def __init__(self, save_path, patience=0):
        super(CustomEarlyStoppingAndSave, self).__init__()
        #self.patience = patience
        self.save_path = save_path
        self.best_weights = None

    def on_train_begin(self, logs=None):
        #self.wait = 0
        self.stopped_epoch = 0
        #self.best_val_distance_loss = np.Inf
        self.best_val_acc = 0

    def on_epoch_end(self, epoch, logs=None):
        #val_distance_loss = logs.get('val_MMD_loss')
        val_acc = logs.get('val_model_accuracy') + logs.get(
            'val_model_1_accuracy') + logs.get(
                'val_model_2_accuracy') 
                #+ logs.get(
                 #   'val_model_3_accuracy') + logs.get('val_model_4_accuracy')

        if  np.greater(val_acc, self.best_val_acc):
            #self.best_val_distance_loss = val_distance_loss
            self.best_val_acc = val_acc
            #self.wait = 0
            # Record the best weights if current results is better (less).
            self.best_weights = self.model.get_weights()
            self.stopped_epoch = epoch
        #else:
            #self.wait += 1
            #if self.wait >= self.patience:
                #self.stopped_epoch = epoch
                #self.model.stop_training = True
                #print("Restoring model weights from the end of the best epoch.")
                #self.model.set_weights(self.best_weights)

    def on_train_end(self, logs=None):
        self.model.set_weights(self.best_weights)
        if self.stopped_epoch >= 0:
            print("Epoch %05d: early stopping and save the model" %
                  (self.stopped_epoch + 1))
        self.model.save(self.save_path)

# %%
#Cosine&Euclidean distance loss
def descriptor(X, mask = False, max_norm = False):
  X = tf.reduce_mean(X, axis=3)
  if mask:
    mean_X = tf.reduce_mean(X, axis = [1,2], keepdims= True)
    X = tf.where(X > mean_X, X , tf.zeros_like(X, dtype=tf.float32))
  if max_norm:
    max_X=tf.reduce_max(X, axis = [1,2], keepdims= True)
    X = tf.math.divide_no_nan(X, max_X)
  return X 
  
def compute_euclidean_sum(X, Y):
  L2_distance = tf.reduce_mean(tf.exp(-(X - Y)**2), axis= [1,2])
  return tf.reduce_mean(L2_distance)

def compute_cosine_sum(X, Y):
  X = tf.reshape(X, [tf.shape(X)[0], -1])
  Y = tf.reshape(Y, [tf.shape(Y)[0], -1])
  loss = -keras.losses.cosine_similarity(X,Y,axis=-1)
  return tf.reduce_mean(loss)

def cosine_euclidean_sum_loss(x, cosine_weight, euclidean_weight, mask, max_norm):
  descriptor0 = descriptor(x[0], mask=mask, max_norm=max_norm)
  descriptor1 = descriptor(x[1], mask=mask, max_norm=max_norm)
  descriptor2 = descriptor(x[2], mask=mask, max_norm=max_norm)
  descriptor3 = descriptor(x[3], mask=mask, max_norm=max_norm)
  descriptor4 = descriptor(x[4], mask=mask, max_norm=max_norm)
  cosine_sum = compute_cosine_sum(descriptor0, descriptor1)+compute_cosine_sum(descriptor0, descriptor2)+compute_cosine_sum(descriptor0, descriptor3)+compute_cosine_sum(descriptor0, descriptor4)+compute_cosine_sum(descriptor1, descriptor2)+compute_cosine_sum(descriptor1, descriptor3)+compute_cosine_sum(descriptor1, descriptor4)+compute_cosine_sum(descriptor2, descriptor3)+compute_cosine_sum(descriptor2, descriptor4)+compute_cosine_sum(descriptor3, descriptor4)
  euclidean_sum = compute_euclidean_sum(descriptor0, descriptor1)+compute_euclidean_sum(descriptor0, descriptor2)+compute_euclidean_sum(descriptor0, descriptor3)+compute_euclidean_sum(descriptor0, descriptor4)+compute_euclidean_sum(descriptor1, descriptor2)+compute_euclidean_sum(descriptor1, descriptor3)+compute_euclidean_sum(descriptor1, descriptor4)+compute_euclidean_sum(descriptor2, descriptor3)+compute_euclidean_sum(descriptor2, descriptor4)+compute_euclidean_sum(descriptor3, descriptor4)
  return cosine_sum, euclidean_sum, cosine_weight*cosine_sum+euclidean_weight*euclidean_sum

# %%
#create single AlexNet model
def create_AlexNet(input_shape, num_classes=6, random_seed=None):
  inputs = keras.Input(shape=input_shape)
  x = keras.layers.Conv2D(96, (3,3), strides=(2,2), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(inputs)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x)
  x = keras.layers.MaxPooling2D(pool_size=(3,3),strides=(2,2),padding='same')(x)
  
  x = keras.layers.Conv2D(256, (3,3), padding='same', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.layers.Activation('relu')(x) 
  x = keras.layers.MaxPooling2D(pool_size=(3,3),strides=(2,2),padding='same')(x)
 
  x = keras.layers.Conv2D(384, (3,3), padding='same', activation='relu', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x) 
  x = keras.layers.Conv2D(384, (3,3), padding='same', activation='relu', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x) 
  x = keras.layers.Conv2D(256, (3,3), padding='same', activation='relu', kernel_initializer=keras.initializers.HeNormal(seed=random_seed))(x)
  feature_maps = keras.layers.MaxPooling2D(pool_size=(3,3),strides=(2,2),padding='same')(x)
  
  x = keras.layers.Flatten()(feature_maps)
  #x = keras.layers.Dense(256,activation='relu')(x)
  #x = keras.layers.Dropout(0.5)(x)
  x = keras.layers.Dense(128,activation='relu')(x)
  x = keras.layers.Dropout(0.5)(x)
  outputs = keras.layers.Dense(num_classes, activation='softmax')(x)
  model = keras.Model(inputs=inputs, outputs=[outputs,feature_maps])
  return model

# %%
#load training, validation and testing images
training_data_path = '3_samples'
validation_data_path = 'NEU_validation'
test_data_path = 'NEU_test'
labels_dict = {'Cr': 0, 'In': 1, 'Pa': 2, 'PS': 3, 'RS': 4, 'Sc': 5}
x_train, y_train = load_data(training_data_path, labels_dict)
x_val, y_val = load_data(validation_data_path, labels_dict)
x_test, y_test = load_data(test_data_path, labels_dict)
x_test = x_test/255.0

# %%
#construct joint training for the five base models
input_size = (200, 200, 3)
model0 = create_AlexNet(input_shape=input_size, num_classes=6,  random_seed=1)
model1 = create_AlexNet(input_shape=input_size, num_classes=6,  random_seed=2)
model2 = create_AlexNet(input_shape=input_size, num_classes=6,  random_seed=3)
model3 = create_AlexNet(input_shape=input_size, num_classes=6,  random_seed=4)
model4 = create_AlexNet(input_shape=input_size, num_classes=6,  random_seed=5)
allinputs = keras.Input(shape=input_size)
output0, feature_maps0 = model0(allinputs)
output1, feature_maps1 = model1(allinputs)
output2, feature_maps2 = model2(allinputs)
output3, feature_maps3 = model3(allinputs)
output4, feature_maps4 = model4(allinputs)
model_train = keras.Model(
    inputs=allinputs, outputs=[output0, output1, output2, output3, output4])

#implement distance loss
loss1, loss2, loss = cosine_euclidean_sum_loss(x=[feature_maps0, feature_maps1, feature_maps2, feature_maps3, feature_maps4], 
                                      cosine_weight=1, euclidean_weight=10, mask=True, max_norm=False)

model_train.add_loss(loss)
model_train.add_metric(loss1, name="loss1", aggregation='mean')
model_train.add_metric(loss2, name="loss2", aggregation='mean')

model_train.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4),
                    loss=['categorical_crossentropy','categorical_crossentropy','categorical_crossentropy','categorical_crossentropy','categorical_crossentropy'],
                    metrics=['accuracy'])

#construct training and validation samples
train_sequence = NEUdata(x_train, y_train, batch_size=10, train=True)
validation_sequence = NEUdata(x_val, y_val, batch_size=10, train=False)

#training 
history = model_train.fit(
    train_sequence,
    epochs=300,
    validation_data=validation_sequence,
    callbacks=CustomEarlyStoppingAndSave(
        save_path='100_samples_seed_fix.h5',
        patience=10))
frame = pd.DataFrame({
    'loss':
    history.history['loss'],
    'loss1':
    history.history['loss1'],
    'loss2':
    history.history['loss2'],
    'model_0_loss':
    history.history['model_loss'],
    'model_1_loss':
    history.history['model_1_loss'],
    'model_2_loss':
    history.history['model_2_loss'],
    'model_3_loss':
    history.history['model_3_loss'],
    'model_4_loss':
    history.history['model_4_loss'],
    'model_0_accuracy':
    history.history['model_accuracy'],
    'model_1_accuracy':
    history.history['model_1_accuracy'],
    'model_2_accuracy':
    history.history['model_2_accuracy'],
    'model_3_accuracy':
    history.history['model_3_accuracy'],
    'model_4_accuracy':
    history.history['model_4_accuracy'],
    'val_loss':
    history.history['val_loss'],
    'val_loss1':
    history.history['val_loss1'],
    'val_loss2':
    history.history['val_loss2'],
    'val_model_0_loss':
    history.history['val_model_loss'],
    'val_model_1_loss':
    history.history['val_model_1_loss'],
    'val_model_2_loss':
    history.history['val_model_2_loss'],
    'val_model_3_loss':
    history.history['val_model_3_loss'],
    'val_model_4_loss':
    history.history['val_model_4_loss'],
    'val_model_0_accuracy':
    history.history['val_model_accuracy'],
    'val_model_1_accuracy':
    history.history['val_model_1_accuracy'],
    'val_model_2_accuracy':
    history.history['val_model_2_accuracy'],
    'val_model_3_accuracy':
    history.history['val_model_3_accuracy'],
    'val_model_4_accuracy':
    history.history['val_model_4_accuracy'],
})
#frame.to_excel('table_{numsample}_samples_seed_{numseed}.xlsx'.format(numsample=100, numseed='fix'))
# Out:
# Epoch 1/300
# 2/2 [==============================] - 19s 6s/step - loss: 41.9142 - model_loss: 8.2094 - model_1_loss: 7.3877 - model_2_loss: 6.8176 - model_3_loss: 11.2966 - model_4_loss: 8.2029 - model_accuracy: 0.1111 - model_1_accuracy: 0.1111 - model_2_accuracy: 0.1111 - model_3_accuracy: 0.0000e+00 - model_4_accuracy: 0.1667 - loss1: 9.1927 - loss2: 9.3323 - val_loss: 13.5231 - val_model_loss: 3.7230 - val_model_1_loss: 2.7450 - val_model_2_loss: 2.2833 - val_model_3_loss: 1.9857 - val_model_4_loss: 2.7861 - val_model_accuracy: 0.1583 - val_model_1_accuracy: 0.1000 - val_model_2_accuracy: 0.1667 - val_model_3_accuracy: 0.1750 - val_model_4_accuracy: 0.1667 - val_loss1: 9.2729 - val_loss2: 9.8447
# Epoch 2/300
# 2/2 [==============================] - 1s 1s/step - loss: 25.3099 - model_loss: 5.9668 - model_1_loss: 4.3627 - model_2_loss: 4.5007 - model_3_loss: 4.2315 - model_4_loss: 6.2482 - model_accuracy: 0.2222 - model_1_accuracy: 0.3333 - model_2_accuracy: 0.2222 - model_3_accuracy: 0.2222 - model_4_accuracy: 0.2222 - loss1: 9.1710 - loss2: 9.4185 - val_loss: 12.7862 - val_model_loss: 3.0588 - val_model_1_loss: 2.8144 - val_model_2_loss: 2.2611 - val_model_3_loss: 2.0402 - val_model_4_loss: 2.6117 - val_model_accuracy: 0.1667 - val_model_1_accuracy: 0.1667 - val_model_2_accuracy: 0.1667 - val_model_3_accuracy: 0.1611 - val_model_4_accuracy: 0.1667 - val_loss1: 9.2373 - val_loss2: 9.8692
# Epoch 3/300
# 2/2 [==============================] - 1s 1s/step - loss: 27.3864 - model_loss: 7.5763 - model_1_loss: 6.3250 - model_2_loss: 4.0529 - model_3_loss: 5.1222 - model_4_loss: 4.3101 - model_accuracy: 0.1111 - model_1_accuracy: 0.2222 - model_2_accuracy: 0.3333 - model_3_accuracy: 0.1667 - model_4_accuracy: 0.1667 - loss1: 8.9609 - loss2: 9.4450 - val_loss: 12.0842 - val_model_loss: 3.0607 - val_model_1_loss: 2.5755 - val_model_2_loss: 2.2931 - val_model_3_loss: 2.1197 - val_model_4_loss: 2.0353 - val_model_accuracy: 0.1667 - val_model_1_accuracy: 0.1667 - val_model_2_accuracy: 0.1667 - val_model_3_accuracy: 0.1667 - val_model_4_accuracy: 0.1722 - val_loss1: 9.1489 - val_loss2: 9.8881
# Epoch 4/300
# 2/2 [==============================] - 1s 1s/step - loss: 17.4730 - model_loss: 4.5208 - model_1_loss: 3.5500 - model_2_loss: 3.5372 - model_3_loss: 2.8137 - model_4_loss: 3.0513 - model_accuracy: 0.2778 - model_1_accuracy: 0.2222 - model_2_accuracy: 0.2222 - model_3_accuracy: 0.3333 - model_4_accuracy: 0.3333 - loss1: 9.0501 - loss2: 9.5714 - val_loss: 10.0198 - val_model_loss: 1.8333 - val_model_1_loss: 2.0236 - val_model_2_loss: 2.4019 - val_model_3_loss: 1.8960 - val_model_4_loss: 1.8650 - val_model_accuracy: 0.1417 - val_model_1_accuracy: 0.1667 - val_model_2_accuracy: 0.1639 - val_model_3_accuracy: 0.1833 - val_model_4_accuracy: 0.1667 - val_loss1: 9.0986 - val_loss2: 9.9125
# Epoch 5/300
# 2/2 [==============================] - 1s 1s/step - loss: 14.8099 - model_loss: 3.5679 - model_1_loss: 3.5393 - model_2_loss: 3.1464 - model_3_loss: 2.6681 - model_4_loss: 1.8881 - model_accuracy: 0.1111 - model_1_accuracy: 0.2778 - model_2_accuracy: 0.1667 - model_3_accuracy: 0.2778 - model_4_accuracy: 0.2778 - loss1: 8.9794 - loss2: 9.6934 - val_loss: 9.8083 - val_model_loss: 1.9183 - val_model_1_loss: 2.0309 - val_model_2_loss: 2.0811 - val_model_3_loss: 1.8026 - val_model_4_loss: 1.9754 - val_model_accuracy: 0.1667 - val_model_1_accuracy: 0.1667 - val_model_2_accuracy: 0.1556 - val_model_3_accuracy: 0.1333 - val_model_4_accuracy: 0.1667 - val_loss1: 9.1249 - val_loss2: 9.9370
# Epoch 6/300
# 2/2 [==============================] - 1s 1s/step - loss: 9.3200 - model_loss: 1.6243 - model_1_loss: 1.4478 - model_2_loss: 2.0010 - model_3_loss: 2.0091 - model_4_loss: 2.2378 - model_accuracy: 0.2222 - model_1_accuracy: 0.3333 - model_2_accuracy: 0.3889 - model_3_accuracy: 0.3889 - model_4_accuracy: 0.2222 - loss1: 9.1357 - loss2: 9.7746 - val_loss: 9.6110 - val_model_loss: 1.8756 - val_model_1_loss: 2.0041 - val_model_2_loss: 1.9501 - val_model_3_loss: 1.8282 - val_model_4_loss: 1.9530 - val_model_accuracy: 0.1667 - val_model_1_accuracy: 0.1667 - val_model_2_accuracy: 0.1667 - val_model_3_accuracy: 0.1889 - val_model_4_accuracy: 0.1944 - val_loss1: 9.1320 - val_loss2: 9.9537
# Epoch 7/300
# 2/2 [==============================] - 1s 1s/step - loss: 10.3534 - model_loss: 1.8468 - model_1_loss: 2.0046 - model_2_loss: 2.5858 - model_3_loss: 2.2088 - model_4_loss: 1.7075 - model_accuracy: 0.4444 - model_1_accuracy: 0.4444 - model_2_accuracy: 0.1667 - model_3_accuracy: 0.3889 - model_4_accuracy: 0.5000 - loss1: 8.8969 - loss2: 9.8058 - val_loss: 9.4353 - val_model_loss: 1.8115 - val_model_1_loss: 1.9748 - val_model_2_loss: 1.8825 - val_model_3_loss: 1.8224 - val_model_4_loss: 1.9441 - val_model_accuracy: 0.1667 - val_model_1_accuracy: 0.1667 - val_model_2_accuracy: 0.1667 - val_model_3_accuracy: 0.1889 - val_model_4_accuracy: 0.1444 - val_loss1: 9.1442 - val_loss2: 9.9645
# Epoch 8/300
# 2/2 [==============================] - 1s 1s/step - loss: 9.3201 - model_loss: 2.1125 - model_1_loss: 1.3352 - model_2_loss: 1.5538 - model_3_loss: 2.5140 - model_4_loss: 1.8047 - model_accuracy: 0.5000 - model_1_accuracy: 0.3889 - model_2_accuracy: 0.5000 - model_3_accuracy: 0.2222 - model_4_accuracy: 0.2222 - loss1: 9.0424 - loss2: 9.8498 - val_loss: 9.4521 - val_model_loss: 1.9175 - val_model_1_loss: 1.9573 - val_model_2_loss: 1.8158 - val_model_3_loss: 1.8229 - val_model_4_loss: 1.9387 - val_model_accuracy: 0.1556 - val_model_1_accuracy: 0.1861 - val_model_2_accuracy: 0.1667 - val_model_3_accuracy: 0.1417 - val_model_4_accuracy: 0.1639 - val_loss1: 9.1557 - val_loss2: 9.9715
# Epoch 9/300
# 2/2 [==============================] - 1s 1s/step - loss: 8.9172 - model_loss: 2.0988 - model_1_loss: 1.6074 - model_2_loss: 1.6221 - model_3_loss: 1.9470 - model_4_loss: 1.6420 - model_accuracy: 0.2778 - model_1_accuracy: 0.3333 - model_2_accuracy: 0.4444 - model_3_accuracy: 0.3333 - model_4_accuracy: 0.3889 - loss1: 8.7463 - loss2: 9.8478 - val_loss: 9.3630 - val_model_loss: 1.9688 - val_model_1_loss: 1.9222 - val_model_2_loss: 1.7748 - val_model_3_loss: 1.8150 - val_model_4_loss: 1.8823 - val_model_accuracy: 0.1639 - val_model_1_accuracy: 0.2056 - val_model_2_accuracy: 0.1806 - val_model_3_accuracy: 0.1667 - val_model_4_accuracy: 0.1667 - val_loss1: 9.1549 - val_loss2: 9.9762
# Epoch 10/300
# 2/2 [==============================] - 1s 1s/step - loss: 8.1479 - model_loss: 1.6229 - model_1_loss: 1.9424 - model_2_loss: 1.5022 - model_3_loss: 1.6838 - model_4_loss: 1.3966 - model_accuracy: 0.3889 - model_1_accuracy: 0.3889 - model_2_accuracy: 0.5000 - model_3_accuracy: 0.5556 - model_4_accuracy: 0.5556 - loss1: 8.9097 - loss2: 9.8774 - val_loss: 9.0495 - val_model_loss: 1.8395 - val_model_1_loss: 1.8466 - val_model_2_loss: 1.7544 - val_model_3_loss: 1.8090 - val_model_4_loss: 1.8000 - val_model_accuracy: 0.1556 - val_model_1_accuracy: 0.1444 - val_model_2_accuracy: 0.1611 - val_model_3_accuracy: 0.1667 - val_model_4_accuracy: 0.1583 - val_loss1: 9.1423 - val_loss2: 9.9800
# Epoch 11/300
# 2/2 [==============================] - 1s 1s/step - loss: 8.1353 - model_loss: 1.6718 - model_1_loss: 1.2656 - model_2_loss: 1.8107 - model_3_loss: 1.7378 - model_4_loss: 1.6494 - model_accuracy: 0.3333 - model_1_accuracy: 0.5556 - model_2_accuracy: 0.2778 - model_3_accuracy: 0.2778 - model_4_accuracy: 0.3889 - loss1: 8.9473 - loss2: 9.8869 - val_loss: 8.8395 - val_model_loss: 1.7467 - val_model_1_loss: 1.8063 - val_model_2_loss: 1.7410 - val_model_3_loss: 1.7833 - val_model_4_loss: 1.7622 - val_model_accuracy: 0.1444 - val_model_1_accuracy: 0.1417 - val_model_2_accuracy: 0.1750 - val_model_3_accuracy: 0.1611 - val_model_4_accuracy: 0.1722 - val_loss1: 9.0892 - val_loss2: 9.9812
# Epoch 12/300
# 2/2 [==============================] - 1s 1s/step - loss: 7.2482 - model_loss: 1.3812 - model_1_loss: 1.4625 - model_2_loss: 1.6100 - model_3_loss: 1.4853 - model_4_loss: 1.3091 - model_accuracy: 0.3889 - model_1_accuracy: 0.3333 - model_2_accuracy: 0.3889 - model_3_accuracy: 0.4444 - model_4_accuracy: 0.5556 - loss1: 8.9610 - loss2: 9.8938 - val_loss: 8.7647 - val_model_loss: 1.7287 - val_model_1_loss: 1.7761 - val_model_2_loss: 1.7401 - val_model_3_loss: 1.7560 - val_model_4_loss: 1.7637 - val_model_accuracy: 0.2028 - val_model_1_accuracy: 0.1444 - val_model_2_accuracy: 0.2167 - val_model_3_accuracy: 0.1556 - val_model_4_accuracy: 0.2806 - val_loss1: 9.0250 - val_loss2: 9.9815
# Epoch 13/300
# 2/2 [==============================] - 1s 1s/step - loss: 6.2890 - model_loss: 1.1142 - model_1_loss: 1.2597 - model_2_loss: 1.2823 - model_3_loss: 1.2669 - model_4_loss: 1.3658 - model_accuracy: 0.6111 - model_1_accuracy: 0.6111 - model_2_accuracy: 0.4444 - model_3_accuracy: 0.4444 - model_4_accuracy: 0.3333 - loss1: 8.9907 - loss2: 9.9002 - val_loss: 8.7728 - val_model_loss: 1.7192 - val_model_1_loss: 1.7545 - val_model_2_loss: 1.7719 - val_model_3_loss: 1.7419 - val_model_4_loss: 1.7854 - val_model_accuracy: 0.2167 - val_model_1_accuracy: 0.1389 - val_model_2_accuracy: 0.1778 - val_model_3_accuracy: 0.1750 - val_model_4_accuracy: 0.2667 - val_loss1: 8.9478 - val_loss2: 9.9808
# Epoch 14/300
# 2/2 [==============================] - 1s 1s/step - loss: 6.3498 - model_loss: 1.3626 - model_1_loss: 1.2615 - model_2_loss: 1.2129 - model_3_loss: 1.1839 - model_4_loss: 1.3289 - model_accuracy: 0.4444 - model_1_accuracy: 0.5556 - model_2_accuracy: 0.5556 - model_3_accuracy: 0.6667 - model_4_accuracy: 0.4444 - loss1: 8.8325 - loss2: 9.9037 - val_loss: 8.7887 - val_model_loss: 1.7072 - val_model_1_loss: 1.7451 - val_model_2_loss: 1.7914 - val_model_3_loss: 1.7392 - val_model_4_loss: 1.8058 - val_model_accuracy: 0.2417 - val_model_1_accuracy: 0.1833 - val_model_2_accuracy: 0.1778 - val_model_3_accuracy: 0.1972 - val_model_4_accuracy: 0.2028 - val_loss1: 8.8848 - val_loss2: 9.9798
# Epoch 15/300
# 2/2 [==============================] - 1s 1s/step - loss: 6.4611 - model_loss: 1.3877 - model_1_loss: 1.3061 - model_2_loss: 1.2370 - model_3_loss: 1.1546 - model_4_loss: 1.3758 - model_accuracy: 0.5000 - model_1_accuracy: 0.5000 - model_2_accuracy: 0.6111 - model_3_accuracy: 0.7778 - model_4_accuracy: 0.3333 - loss1: 8.7442 - loss2: 9.9030 - val_loss: 8.7894 - val_model_loss: 1.6987 - val_model_1_loss: 1.7393 - val_model_2_loss: 1.7926 - val_model_3_loss: 1.7352 - val_model_4_loss: 1.8236 - val_model_accuracy: 0.2361 - val_model_1_accuracy: 0.1944 - val_model_2_accuracy: 0.2028 - val_model_3_accuracy: 0.2556 - val_model_4_accuracy: 0.2000 - val_loss1: 8.8328 - val_loss2: 9.9795
# Epoch 16/300
# 2/2 [==============================] - 1s 1s/step - loss: 6.1127 - model_loss: 1.0411 - model_1_loss: 1.4554 - model_2_loss: 1.0129 - model_3_loss: 1.4639 - model_4_loss: 1.1394 - model_accuracy: 0.6667 - model_1_accuracy: 0.3333 - model_2_accuracy: 0.6111 - model_3_accuracy: 0.3333 - model_4_accuracy: 0.5000 - loss1: 8.7134 - loss2: 9.9061 - val_loss: 8.8342 - val_model_loss: 1.6925 - val_model_1_loss: 1.7499 - val_model_2_loss: 1.7987 - val_model_3_loss: 1.7332 - val_model_4_loss: 1.8597 - val_model_accuracy: 0.2222 - val_model_1_accuracy: 0.2083 - val_model_2_accuracy: 0.2333 - val_model_3_accuracy: 0.2694 - val_model_4_accuracy: 0.2000 - val_loss1: 8.8055 - val_loss2: 9.9791
# Epoch 17/300
# 2/2 [==============================] - 1s 1s/step - loss: 5.3103 - model_loss: 0.9333 - model_1_loss: 1.3023 - model_2_loss: 0.9889 - model_3_loss: 0.9767 - model_4_loss: 1.1091 - model_accuracy: 0.6111 - model_1_accuracy: 0.5000 - model_2_accuracy: 0.6111 - model_3_accuracy: 0.7222 - model_4_accuracy: 0.6111 - loss1: 8.6432 - loss2: 9.8888 - val_loss: 8.8580 - val_model_loss: 1.6976 - val_model_1_loss: 1.7664 - val_model_2_loss: 1.8070 - val_model_3_loss: 1.7294 - val_model_4_loss: 1.8577 - val_model_accuracy: 0.2083 - val_model_1_accuracy: 0.2306 - val_model_2_accuracy: 0.2639 - val_model_3_accuracy: 0.2972 - val_model_4_accuracy: 0.2083 - val_loss1: 8.7832 - val_loss2: 9.9787
# Epoch 18/300
# 2/2 [==============================] - 1s 1s/step - loss: 5.6342 - model_loss: 1.1182 - model_1_loss: 1.0889 - model_2_loss: 1.0224 - model_3_loss: 1.1346 - model_4_loss: 1.2700 - model_accuracy: 0.6667 - model_1_accuracy: 0.5556 - model_2_accuracy: 0.6667 - model_3_accuracy: 0.6667 - model_4_accuracy: 0.6111 - loss1: 8.7813 - loss2: 9.8986 - val_loss: 8.9255 - val_model_loss: 1.7000 - val_model_1_loss: 1.8143 - val_model_2_loss: 1.8299 - val_model_3_loss: 1.7273 - val_model_4_loss: 1.8541 - val_model_accuracy: 0.2167 - val_model_1_accuracy: 0.2139 - val_model_2_accuracy: 0.2222 - val_model_3_accuracy: 0.2750 - val_model_4_accuracy: 0.2167 - val_loss1: 8.7393 - val_loss2: 9.9773
# Epoch 19/300
# 2/2 [==============================] - 1s 1s/step - loss: 4.7195 - model_loss: 0.8631 - model_1_loss: 1.1150 - model_2_loss: 0.8512 - model_3_loss: 0.9023 - model_4_loss: 0.9880 - model_accuracy: 0.6111 - model_1_accuracy: 0.6111 - model_2_accuracy: 0.6111 - model_3_accuracy: 0.7778 - model_4_accuracy: 0.6111 - loss1: 8.6847 - loss2: 9.8863 - val_loss: 8.9526 - val_model_loss: 1.6860 - val_model_1_loss: 1.8653 - val_model_2_loss: 1.8383 - val_model_3_loss: 1.7218 - val_model_4_loss: 1.8412 - val_model_accuracy: 0.2278 - val_model_1_accuracy: 0.2167 - val_model_2_accuracy: 0.1778 - val_model_3_accuracy: 0.2333 - val_model_4_accuracy: 0.2417 - val_loss1: 8.6617 - val_loss2: 9.9748
# Epoch 20/300
# 2/2 [==============================] - 1s 1s/step - loss: 6.6681 - model_loss: 1.3429 - model_1_loss: 1.3253 - model_2_loss: 1.5702 - model_3_loss: 1.3079 - model_4_loss: 1.1218 - model_accuracy: 0.4444 - model_1_accuracy: 0.3889 - model_2_accuracy: 0.3333 - model_3_accuracy: 0.5000 - model_4_accuracy: 0.4444 - loss1: 8.7109 - loss2: 9.8842 - val_loss: 9.0068 - val_model_loss: 1.6850 - val_model_1_loss: 1.9034 - val_model_2_loss: 1.8583 - val_model_3_loss: 1.7192 - val_model_4_loss: 1.8408 - val_model_accuracy: 0.1889 - val_model_1_accuracy: 0.2194 - val_model_2_accuracy: 0.1972 - val_model_3_accuracy: 0.2056 - val_model_4_accuracy: 0.2306 - val_loss1: 8.6078 - val_loss2: 9.9732
# Epoch 21/300
# 2/2 [==============================] - 1s 1s/step - loss: 7.0046 - model_loss: 1.1891 - model_1_loss: 1.6134 - model_2_loss: 1.3511 - model_3_loss: 1.3464 - model_4_loss: 1.5046 - model_accuracy: 0.4444 - model_1_accuracy: 0.5556 - model_2_accuracy: 0.5556 - model_3_accuracy: 0.3889 - model_4_accuracy: 0.5000 - loss1: 8.5965 - loss2: 9.8755 - val_loss: 8.9996 - val_model_loss: 1.6838 - val_model_1_loss: 1.8873 - val_model_2_loss: 1.8647 - val_model_3_loss: 1.7157 - val_model_4_loss: 1.8481 - val_model_accuracy: 0.2056 - val_model_1_accuracy: 0.2333 - val_model_2_accuracy: 0.2028 - val_model_3_accuracy: 0.1972 - val_model_4_accuracy: 0.2444 - val_loss1: 8.5712 - val_loss2: 9.9732
# Epoch 22/300
# 2/2 [==============================] - 1s 1s/step - loss: 7.0273 - model_loss: 1.1858 - model_1_loss: 1.7581 - model_2_loss: 1.3979 - model_3_loss: 1.4649 - model_4_loss: 1.2206 - model_accuracy: 0.6667 - model_1_accuracy: 0.2778 - model_2_accuracy: 0.5000 - model_3_accuracy: 0.3333 - model_4_accuracy: 0.5000 - loss1: 8.6385 - loss2: 9.8858 - val_loss: 8.9264 - val_model_loss: 1.6763 - val_model_1_loss: 1.8244 - val_model_2_loss: 1.8558 - val_model_3_loss: 1.7158 - val_model_4_loss: 1.8541 - val_model_accuracy: 0.2000 - val_model_1_accuracy: 0.1944 - val_model_2_accuracy: 0.2056 - val_model_3_accuracy: 0.1944 - val_model_4_accuracy: 0.2639 - val_loss1: 8.5369 - val_loss2: 9.9743
# Epoch 23/300
# 2/2 [==============================] - 1s 1s/step - loss: 5.5320 - model_loss: 0.9362 - model_1_loss: 1.2941 - model_2_loss: 1.0284 - model_3_loss: 0.9283 - model_4_loss: 1.3451 - model_accuracy: 0.5556 - model_1_accuracy: 0.5000 - model_2_accuracy: 0.4444 - model_3_accuracy: 0.7222 - model_4_accuracy: 0.5556 - loss1: 8.8742 - loss2: 9.9025 - val_loss: 8.8021 - val_model_loss: 1.6647 - val_model_1_loss: 1.7827 - val_model_2_loss: 1.7979 - val_model_3_loss: 1.7112 - val_model_4_loss: 1.8456 - val_model_accuracy: 0.2306 - val_model_1_accuracy: 0.2000 - val_model_2_accuracy: 0.1972 - val_model_3_accuracy: 0.1972 - val_model_4_accuracy: 0.2694 - val_loss1: 8.5194 - val_loss2: 9.9762
# Epoch 24/300
# 2/2 [==============================] - 1s 1s/step - loss: 3.6984 - model_loss: 0.7166 - model_1_loss: 0.7375 - model_2_loss: 0.7403 - model_3_loss: 0.5727 - model_4_loss: 0.9313 - model_accuracy: 0.6667 - model_1_accuracy: 0.7222 - model_2_accuracy: 0.7778 - model_3_accuracy: 0.8889 - model_4_accuracy: 0.6667 - loss1: 8.8249 - loss2: 9.9109 - val_loss: 8.6647 - val_model_loss: 1.6539 - val_model_1_loss: 1.7417 - val_model_2_loss: 1.7666 - val_model_3_loss: 1.7015 - val_model_4_loss: 1.8010 - val_model_accuracy: 0.2694 - val_model_1_accuracy: 0.2167 - val_model_2_accuracy: 0.1889 - val_model_3_accuracy: 0.1944 - val_model_4_accuracy: 0.2750 - val_loss1: 8.5289 - val_loss2: 9.9785
# Epoch 25/300
# 2/2 [==============================] - 1s 1s/step - loss: 4.9843 - model_loss: 0.8860 - model_1_loss: 0.8947 - model_2_loss: 0.9750 - model_3_loss: 1.0922 - model_4_loss: 1.1365 - model_accuracy: 0.6667 - model_1_accuracy: 0.6111 - model_2_accuracy: 0.5556 - model_3_accuracy: 0.6111 - model_4_accuracy: 0.5556 - loss1: 8.5565 - loss2: 9.9087 - val_loss: 8.5538 - val_model_loss: 1.6516 - val_model_1_loss: 1.7264 - val_model_2_loss: 1.7402 - val_model_3_loss: 1.6875 - val_model_4_loss: 1.7481 - val_model_accuracy: 0.2750 - val_model_1_accuracy: 0.2139 - val_model_2_accuracy: 0.1889 - val_model_3_accuracy: 0.2250 - val_model_4_accuracy: 0.2389 - val_loss1: 8.5160 - val_loss2: 9.9793
# Epoch 26/300
# 2/2 [==============================] - 1s 1s/step - loss: 5.5071 - model_loss: 1.0449 - model_1_loss: 1.0016 - model_2_loss: 1.2055 - model_3_loss: 1.0663 - model_4_loss: 1.1888 - model_accuracy: 0.5556 - model_1_accuracy: 0.5000 - model_2_accuracy: 0.5556 - model_3_accuracy: 0.5556 - model_4_accuracy: 0.5556 - loss1: 8.7640 - loss2: 9.9108 - val_loss: 8.4758 - val_model_loss: 1.6423 - val_model_1_loss: 1.7340 - val_model_2_loss: 1.7238 - val_model_3_loss: 1.6774 - val_model_4_loss: 1.6983 - val_model_accuracy: 0.2583 - val_model_1_accuracy: 0.1972 - val_model_2_accuracy: 0.1972 - val_model_3_accuracy: 0.2111 - val_model_4_accuracy: 0.2417 - val_loss1: 8.4912 - val_loss2: 9.9794
# Epoch 27/300
# 2/2 [==============================] - 1s 1s/step - loss: 6.0636 - model_loss: 1.1554 - model_1_loss: 1.1178 - model_2_loss: 1.6116 - model_3_loss: 1.0226 - model_4_loss: 1.1563 - model_accuracy: 0.5000 - model_1_accuracy: 0.6111 - model_2_accuracy: 0.2778 - model_3_accuracy: 0.6667 - model_4_accuracy: 0.5556 - loss1: 8.5667 - loss2: 9.9053 - val_loss: 8.4587 - val_model_loss: 1.6397 - val_model_1_loss: 1.7556 - val_model_2_loss: 1.7083 - val_model_3_loss: 1.6806 - val_model_4_loss: 1.6746 - val_model_accuracy: 0.2306 - val_model_1_accuracy: 0.1889 - val_model_2_accuracy: 0.2250 - val_model_3_accuracy: 0.2083 - val_model_4_accuracy: 0.2361 - val_loss1: 8.4816 - val_loss2: 9.9796
# Epoch 28/300
# 2/2 [==============================] - 1s 1s/step - loss: 4.0276 - model_loss: 0.7220 - model_1_loss: 0.9614 - model_2_loss: 0.8537 - model_3_loss: 0.7977 - model_4_loss: 0.6929 - model_accuracy: 0.6667 - model_1_accuracy: 0.5556 - model_2_accuracy: 0.6667 - model_3_accuracy: 0.7778 - model_4_accuracy: 0.6111 - loss1: 8.9036 - loss2: 9.9147 - val_loss: 8.4621 - val_model_loss: 1.6533 - val_model_1_loss: 1.7719 - val_model_2_loss: 1.6883 - val_model_3_loss: 1.6767 - val_model_4_loss: 1.6719 - val_model_accuracy: 0.1861 - val_model_1_accuracy: 0.2000 - val_model_2_accuracy: 0.2389 - val_model_3_accuracy: 0.2194 - val_model_4_accuracy: 0.2139 - val_loss1: 8.4668 - val_loss2: 9.9791
# Epoch 29/300
# 2/2 [==============================] - 1s 1s/step - loss: 3.9588 - model_loss: 0.8595 - model_1_loss: 0.9910 - model_2_loss: 0.8185 - model_3_loss: 0.5791 - model_4_loss: 0.7108 - model_accuracy: 0.6667 - model_1_accuracy: 0.5556 - model_2_accuracy: 0.7778 - model_3_accuracy: 0.8333 - model_4_accuracy: 0.8889 - loss1: 8.7447 - loss2: 9.9119 - val_loss: 8.4066 - val_model_loss: 1.6645 - val_model_1_loss: 1.7537 - val_model_2_loss: 1.6609 - val_model_3_loss: 1.6614 - val_model_4_loss: 1.6661 - val_model_accuracy: 0.2583 - val_model_1_accuracy: 0.2306 - val_model_2_accuracy: 0.2306 - val_model_3_accuracy: 0.2250 - val_model_4_accuracy: 0.2056 - val_loss1: 8.4258 - val_loss2: 9.9780
# Epoch 30/300
# 2/2 [==============================] - 1s 1s/step - loss: 4.8647 - model_loss: 1.0056 - model_1_loss: 1.1246 - model_2_loss: 0.9981 - model_3_loss: 0.8849 - model_4_loss: 0.8516 - model_accuracy: 0.5556 - model_1_accuracy: 0.3889 - model_2_accuracy: 0.5000 - model_3_accuracy: 0.6111 - model_4_accuracy: 0.6667 - loss1: 8.6360 - loss2: 9.9147 - val_loss: 8.3383 - val_model_loss: 1.6789 - val_model_1_loss: 1.7350 - val_model_2_loss: 1.6403 - val_model_3_loss: 1.6457 - val_model_4_loss: 1.6385 - val_model_accuracy: 0.2917 - val_model_1_accuracy: 0.2306 - val_model_2_accuracy: 0.2667 - val_model_3_accuracy: 0.2361 - val_model_4_accuracy: 0.2306 - val_loss1: 8.3948 - val_loss2: 9.9768
# Epoch 31/300
# 2/2 [==============================] - 1s 1s/step - loss: 4.3359 - model_loss: 1.0926 - model_1_loss: 0.7852 - model_2_loss: 0.8358 - model_3_loss: 0.8753 - model_4_loss: 0.7469 - model_accuracy: 0.5000 - model_1_accuracy: 0.7778 - model_2_accuracy: 0.6667 - model_3_accuracy: 0.7222 - model_4_accuracy: 0.6111 - loss1: 8.3911 - loss2: 9.8938 - val_loss: 8.2650 - val_model_loss: 1.6562 - val_model_1_loss: 1.7203 - val_model_2_loss: 1.6344 - val_model_3_loss: 1.6325 - val_model_4_loss: 1.6216 - val_model_accuracy: 0.2778 - val_model_1_accuracy: 0.2417 - val_model_2_accuracy: 0.2278 - val_model_3_accuracy: 0.2361 - val_model_4_accuracy: 0.3583 - val_loss1: 8.3479 - val_loss2: 9.9744
# Epoch 32/300
# 2/2 [==============================] - 1s 1s/step - loss: 5.4518 - model_loss: 1.1952 - model_1_loss: 0.9248 - model_2_loss: 1.1491 - model_3_loss: 1.0657 - model_4_loss: 1.1170 - model_accuracy: 0.5000 - model_1_accuracy: 0.6667 - model_2_accuracy: 0.6111 - model_3_accuracy: 0.6111 - model_4_accuracy: 0.5000 - loss1: 8.5618 - loss2: 9.8937 - val_loss: 8.2363 - val_model_loss: 1.6035 - val_model_1_loss: 1.7206 - val_model_2_loss: 1.6452 - val_model_3_loss: 1.6399 - val_model_4_loss: 1.6271 - val_model_accuracy: 0.3639 - val_model_1_accuracy: 0.2306 - val_model_2_accuracy: 0.2500 - val_model_3_accuracy: 0.2250 - val_model_4_accuracy: 0.3861 - val_loss1: 8.2940 - val_loss2: 9.9718
# Epoch 33/300
# 2/2 [==============================] - 1s 1s/step - loss: 4.7878 - model_loss: 0.8903 - model_1_loss: 0.6759 - model_2_loss: 0.9865 - model_3_loss: 0.9557 - model_4_loss: 1.2793 - model_accuracy: 0.6111 - model_1_accuracy: 0.8333 - model_2_accuracy: 0.5556 - model_3_accuracy: 0.5556 - model_4_accuracy: 0.6111 - loss1: 8.4955 - loss2: 9.8923 - val_loss: 8.2464 - val_model_loss: 1.6133 - val_model_1_loss: 1.7230 - val_model_2_loss: 1.6534 - val_model_3_loss: 1.6175 - val_model_4_loss: 1.6392 - val_model_accuracy: 0.2917 - val_model_1_accuracy: 0.2778 - val_model_2_accuracy: 0.2556 - val_model_3_accuracy: 0.2444 - val_model_4_accuracy: 0.3861 - val_loss1: 8.2261 - val_loss2: 9.9693
# Epoch 34/300
# 2/2 [==============================] - 1s 1s/step - loss: 4.3342 - model_loss: 0.8690 - model_1_loss: 0.9912 - model_2_loss: 0.8135 - model_3_loss: 0.6995 - model_4_loss: 0.9611 - model_accuracy: 0.7222 - model_1_accuracy: 0.4444 - model_2_accuracy: 0.6667 - model_3_accuracy: 0.7778 - model_4_accuracy: 0.6667 - loss1: 8.7592 - loss2: 9.9003 - val_loss: 8.2649 - val_model_loss: 1.6224 - val_model_1_loss: 1.7258 - val_model_2_loss: 1.6551 - val_model_3_loss: 1.5930 - val_model_4_loss: 1.6687 - val_model_accuracy: 0.2889 - val_model_1_accuracy: 0.3056 - val_model_2_accuracy: 0.2611 - val_model_3_accuracy: 0.2861 - val_model_4_accuracy: 0.3250 - val_loss1: 8.1256 - val_loss2: 9.9660
# Epoch 35/300
# 2/2 [==============================] - 1s 1s/step - loss: 5.1734 - model_loss: 1.0639 - model_1_loss: 0.8914 - model_2_loss: 1.3383 - model_3_loss: 0.9028 - model_4_loss: 0.9770 - model_accuracy: 0.6111 - model_1_accuracy: 0.6667 - model_2_accuracy: 0.7222 - model_3_accuracy: 0.6667 - model_4_accuracy: 0.6111 - loss1: 8.6607 - loss2: 9.8940 - val_loss: 8.2386 - val_model_loss: 1.6090 - val_model_1_loss: 1.7219 - val_model_2_loss: 1.6205 - val_model_3_loss: 1.5815 - val_model_4_loss: 1.7057 - val_model_accuracy: 0.3111 - val_model_1_accuracy: 0.3250 - val_model_2_accuracy: 0.3083 - val_model_3_accuracy: 0.3222 - val_model_4_accuracy: 0.3083 - val_loss1: 7.9846 - val_loss2: 9.9616
# Epoch 36/300
# 2/2 [==============================] - 1s 1s/step - loss: 4.8982 - model_loss: 0.9175 - model_1_loss: 0.8137 - model_2_loss: 0.9514 - model_3_loss: 1.0109 - model_4_loss: 1.2046 - model_accuracy: 0.5556 - model_1_accuracy: 0.7222 - model_2_accuracy: 0.6667 - model_3_accuracy: 0.7222 - model_4_accuracy: 0.5556 - loss1: 8.5278 - loss2: 9.8882 - val_loss: 8.2192 - val_model_loss: 1.5878 - val_model_1_loss: 1.7280 - val_model_2_loss: 1.6141 - val_model_3_loss: 1.5906 - val_model_4_loss: 1.6987 - val_model_accuracy: 0.3528 - val_model_1_accuracy: 0.3333 - val_model_2_accuracy: 0.3472 - val_model_3_accuracy: 0.3222 - val_model_4_accuracy: 0.3556 - val_loss1: 7.8537 - val_loss2: 9.9573
# Epoch 37/300
# 2/2 [==============================] - 1s 1s/step - loss: 3.8765 - model_loss: 0.7468 - model_1_loss: 0.8162 - model_2_loss: 0.8800 - model_3_loss: 0.6726 - model_4_loss: 0.7609 - model_accuracy: 0.5556 - model_1_accuracy: 0.7222 - model_2_accuracy: 0.5556 - model_3_accuracy: 0.7222 - model_4_accuracy: 0.7222 - loss1: 8.4184 - loss2: 9.8726 - val_loss: 8.2711 - val_model_loss: 1.5721 - val_model_1_loss: 1.7563 - val_model_2_loss: 1.6147 - val_model_3_loss: 1.6001 - val_model_4_loss: 1.7280 - val_model_accuracy: 0.3694 - val_model_1_accuracy: 0.3389 - val_model_2_accuracy: 0.3611 - val_model_3_accuracy: 0.3250 - val_model_4_accuracy: 0.3417 - val_loss1: 7.7535 - val_loss2: 9.9526
# Epoch 38/300
# 2/2 [==============================] - 1s 1s/step - loss: 4.5137 - model_loss: 0.5955 - model_1_loss: 0.9964 - model_2_loss: 0.9511 - model_3_loss: 0.9592 - model_4_loss: 1.0115 - model_accuracy: 0.8333 - model_1_accuracy: 0.5000 - model_2_accuracy: 0.6667 - model_3_accuracy: 0.7222 - model_4_accuracy: 0.5000 - loss1: 8.2660 - loss2: 9.8621 - val_loss: 8.4453 - val_model_loss: 1.5747 - val_model_1_loss: 1.8748 - val_model_2_loss: 1.6397 - val_model_3_loss: 1.6067 - val_model_4_loss: 1.7494 - val_model_accuracy: 0.3694 - val_model_1_accuracy: 0.3333 - val_model_2_accuracy: 0.3278 - val_model_3_accuracy: 0.3083 - val_model_4_accuracy: 0.3444 - val_loss1: 7.7346 - val_loss2: 9.9496
# Epoch 39/300
# 2/2 [==============================] - 1s 1s/step - loss: 5.3488 - model_loss: 0.9678 - model_1_loss: 1.3386 - model_2_loss: 0.9680 - model_3_loss: 1.0341 - model_4_loss: 1.0403 - model_accuracy: 0.6111 - model_1_accuracy: 0.5000 - model_2_accuracy: 0.7778 - model_3_accuracy: 0.5556 - model_4_accuracy: 0.5556 - loss1: 8.3605 - loss2: 9.8572 - val_loss: 8.4947 - val_model_loss: 1.5892 - val_model_1_loss: 1.9055 - val_model_2_loss: 1.6815 - val_model_3_loss: 1.5885 - val_model_4_loss: 1.7301 - val_model_accuracy: 0.4083 - val_model_1_accuracy: 0.3472 - val_model_2_accuracy: 0.2861 - val_model_3_accuracy: 0.3083 - val_model_4_accuracy: 0.3444 - val_loss1: 7.7875 - val_loss2: 9.9514
# Epoch 40/300
# 2/2 [==============================] - 1s 1s/step - loss: 4.6473 - model_loss: 1.0838 - model_1_loss: 1.0564 - model_2_loss: 0.8374 - model_3_loss: 0.6599 - model_4_loss: 1.0098 - model_accuracy: 0.6667 - model_1_accuracy: 0.6111 - model_2_accuracy: 0.6111 - model_3_accuracy: 0.7222 - model_4_accuracy: 0.5556 - loss1: 8.4874 - loss2: 9.8593 - val_loss: 8.4982 - val_model_loss: 1.5965 - val_model_1_loss: 1.8626 - val_model_2_loss: 1.7606 - val_model_3_loss: 1.5927 - val_model_4_loss: 1.6857 - val_model_accuracy: 0.4139 - val_model_1_accuracy: 0.3417 - val_model_2_accuracy: 0.3000 - val_model_3_accuracy: 0.3056 - val_model_4_accuracy: 0.3361 - val_loss1: 7.8240 - val_loss2: 9.9542
# Epoch 41/300
# 2/2 [==============================] - 1s 1s/step - loss: 4.1313 - model_loss: 0.8221 - model_1_loss: 0.9566 - model_2_loss: 0.8239 - model_3_loss: 0.7371 - model_4_loss: 0.7915 - model_accuracy: 0.6667 - model_1_accuracy: 0.6667 - model_2_accuracy: 0.7222 - model_3_accuracy: 0.7222 - model_4_accuracy: 0.7778 - loss1: 8.4332 - loss2: 9.8695 - val_loss: 8.4629 - val_model_loss: 1.6278 - val_model_1_loss: 1.7546 - val_model_2_loss: 1.8174 - val_model_3_loss: 1.6067 - val_model_4_loss: 1.6565 - val_model_accuracy: 0.3778 - val_model_1_accuracy: 0.3306 - val_model_2_accuracy: 0.2833 - val_model_3_accuracy: 0.2861 - val_model_4_accuracy: 0.3333 - val_loss1: 7.8168 - val_loss2: 9.9549
# Epoch 42/300
# 2/2 [==============================] - 1s 1s/step - loss: 5.0512 - model_loss: 0.9584 - model_1_loss: 0.9703 - model_2_loss: 1.3125 - model_3_loss: 0.9261 - model_4_loss: 0.8840 - model_accuracy: 0.6667 - model_1_accuracy: 0.6667 - model_2_accuracy: 0.5556 - model_3_accuracy: 0.7778 - model_4_accuracy: 0.6667 - loss1: 8.3532 - loss2: 9.8657 - val_loss: 8.3997 - val_model_loss: 1.6662 - val_model_1_loss: 1.6405 - val_model_2_loss: 1.8040 - val_model_3_loss: 1.6428 - val_model_4_loss: 1.6461 - val_model_accuracy: 0.3528 - val_model_1_accuracy: 0.3056 - val_model_2_accuracy: 0.2889 - val_model_3_accuracy: 0.2583 - val_model_4_accuracy: 0.3167 - val_loss1: 7.8019 - val_loss2: 9.9546
# Epoch 43/300
# 2/2 [==============================] - 1s 1s/step - loss: 4.2072 - model_loss: 0.7578 - model_1_loss: 0.9639 - model_2_loss: 0.9252 - model_3_loss: 0.8913 - model_4_loss: 0.6689 - model_accuracy: 0.7778 - model_1_accuracy: 0.5556 - model_2_accuracy: 0.5556 - model_3_accuracy: 0.7222 - model_4_accuracy: 0.7778 - loss1: 8.2867 - loss2: 9.8644 - val_loss: 8.4262 - val_model_loss: 1.6986 - val_model_1_loss: 1.6128 - val_model_2_loss: 1.7769 - val_model_3_loss: 1.6939 - val_model_4_loss: 1.6441 - val_model_accuracy: 0.3167 - val_model_1_accuracy: 0.2778 - val_model_2_accuracy: 0.2944 - val_model_3_accuracy: 0.2056 - val_model_4_accuracy: 0.3722 - val_loss1: 7.7952 - val_loss2: 9.9532
# Epoch 44/300
# 2/2 [==============================] - 1s 1s/step - loss: 4.0215 - model_loss: 0.6641 - model_1_loss: 0.9174 - model_2_loss: 0.5953 - model_3_loss: 0.9634 - model_4_loss: 0.8812 - model_accuracy: 0.8333 - model_1_accuracy: 0.5000 - model_2_accuracy: 0.7778 - model_3_accuracy: 0.5556 - model_4_accuracy: 0.6111 - loss1: 8.5120 - loss2: 9.8717 - val_loss: 8.3643 - val_model_loss: 1.6887 - val_model_1_loss: 1.6075 - val_model_2_loss: 1.7155 - val_model_3_loss: 1.7055 - val_model_4_loss: 1.6471 - val_model_accuracy: 0.3444 - val_model_1_accuracy: 0.3389 - val_model_2_accuracy: 0.3000 - val_model_3_accuracy: 0.2028 - val_model_4_accuracy: 0.3694 - val_loss1: 7.8276 - val_loss2: 9.9519
# Epoch 45/300
# 2/2 [==============================] - 1s 1s/step - loss: 5.8249 - model_loss: 1.4846 - model_1_loss: 1.3116 - model_2_loss: 1.0279 - model_3_loss: 1.0531 - model_4_loss: 0.9478 - model_accuracy: 0.6111 - model_1_accuracy: 0.4444 - model_2_accuracy: 0.5000 - model_3_accuracy: 0.6111 - model_4_accuracy: 0.6111 - loss1: 8.5319 - loss2: 9.8818 - val_loss: 8.0631 - val_model_loss: 1.5678 - val_model_1_loss: 1.5782 - val_model_2_loss: 1.6103 - val_model_3_loss: 1.6392 - val_model_4_loss: 1.6676 - val_model_accuracy: 0.3917 - val_model_1_accuracy: 0.3778 - val_model_2_accuracy: 0.3639 - val_model_3_accuracy: 0.2861 - val_model_4_accuracy: 0.3667 - val_loss1: 7.8607 - val_loss2: 9.9530
# Epoch 46/300
# 2/2 [==============================] - 1s 1s/step - loss: 3.9677 - model_loss: 0.7175 - model_1_loss: 0.7966 - model_2_loss: 0.7342 - model_3_loss: 0.8012 - model_4_loss: 0.9182 - model_accuracy: 0.7222 - model_1_accuracy: 0.6667 - model_2_accuracy: 0.8333 - model_3_accuracy: 0.6111 - model_4_accuracy: 0.6667 - loss1: 8.4681 - loss2: 9.8721 - val_loss: 7.9449 - val_model_loss: 1.5655 - val_model_1_loss: 1.5787 - val_model_2_loss: 1.5623 - val_model_3_loss: 1.6122 - val_model_4_loss: 1.6264 - val_model_accuracy: 0.4694 - val_model_1_accuracy: 0.3972 - val_model_2_accuracy: 0.4333 - val_model_3_accuracy: 0.3472 - val_model_4_accuracy: 0.4167 - val_loss1: 7.8905 - val_loss2: 9.9536
# Epoch 47/300
# 2/2 [==============================] - 1s 1s/step - loss: 4.7147 - model_loss: 0.8635 - model_1_loss: 0.9171 - model_2_loss: 0.8749 - model_3_loss: 0.8589 - model_4_loss: 1.2002 - model_accuracy: 0.7222 - model_1_accuracy: 0.5556 - model_2_accuracy: 0.6111 - model_3_accuracy: 0.5556 - model_4_accuracy: 0.6111 - loss1: 8.2888 - loss2: 9.8635 - val_loss: 7.9502 - val_model_loss: 1.5892 - val_model_1_loss: 1.5855 - val_model_2_loss: 1.5715 - val_model_3_loss: 1.6046 - val_model_4_loss: 1.5995 - val_model_accuracy: 0.4667 - val_model_1_accuracy: 0.3889 - val_model_2_accuracy: 0.4667 - val_model_3_accuracy: 0.3111 - val_model_4_accuracy: 0.4444 - val_loss1: 7.8659 - val_loss2: 9.9536
# Epoch 48/300
# 2/2 [==============================] - 1s 1s/step - loss: 4.4582 - model_loss: 0.9157 - model_1_loss: 0.8812 - model_2_loss: 0.8686 - model_3_loss: 0.9376 - model_4_loss: 0.8550 - model_accuracy: 0.5556 - model_1_accuracy: 0.7778 - model_2_accuracy: 0.6667 - model_3_accuracy: 0.6111 - model_4_accuracy: 0.7778 - loss1: 8.3548 - loss2: 9.8612 - val_loss: 8.0212 - val_model_loss: 1.6111 - val_model_1_loss: 1.5910 - val_model_2_loss: 1.6088 - val_model_3_loss: 1.5994 - val_model_4_loss: 1.6109 - val_model_accuracy: 0.4222 - val_model_1_accuracy: 0.3639 - val_model_2_accuracy: 0.4528 - val_model_3_accuracy: 0.3306 - val_model_4_accuracy: 0.4306 - val_loss1: 7.8229 - val_loss2: 9.9509
# Epoch 49/300
# 2/2 [==============================] - 1s 1s/step - loss: 4.3529 - model_loss: 0.8082 - model_1_loss: 0.8059 - model_2_loss: 0.9265 - model_3_loss: 0.8899 - model_4_loss: 0.9224 - model_accuracy: 0.7222 - model_1_accuracy: 0.6111 - model_2_accuracy: 0.5556 - model_3_accuracy: 0.7222 - model_4_accuracy: 0.6667 - loss1: 8.4485 - loss2: 9.8736 - val_loss: 8.1246 - val_model_loss: 1.6283 - val_model_1_loss: 1.5992 - val_model_2_loss: 1.6587 - val_model_3_loss: 1.6038 - val_model_4_loss: 1.6346 - val_model_accuracy: 0.4000 - val_model_1_accuracy: 0.3222 - val_model_2_accuracy: 0.4417 - val_model_3_accuracy: 0.3194 - val_model_4_accuracy: 0.3889 - val_loss1: 7.7828 - val_loss2: 9.9480
# Epoch 50/300
# 2/2 [==============================] - 1s 1s/step - loss: 4.5565 - model_loss: 0.8123 - model_1_loss: 0.9827 - model_2_loss: 0.9868 - model_3_loss: 0.8874 - model_4_loss: 0.8874 - model_accuracy: 0.7778 - model_1_accuracy: 0.4444 - model_2_accuracy: 0.7222 - model_3_accuracy: 0.6667 - model_4_accuracy: 0.6111 - loss1: 8.3784 - loss2: 9.8606 - val_loss: 8.1705 - val_model_loss: 1.6349 - val_model_1_loss: 1.6096 - val_model_2_loss: 1.6802 - val_model_3_loss: 1.6019 - val_model_4_loss: 1.6439 - val_model_accuracy: 0.3861 - val_model_1_accuracy: 0.3056 - val_model_2_accuracy: 0.4167 - val_model_3_accuracy: 0.3278 - val_model_4_accuracy: 0.3444 - val_loss1: 7.7574 - val_loss2: 9.9446
# Epoch 51/300
# 2/2 [==============================] - 1s 1s/step - loss: 4.3566 - model_loss: 0.7741 - model_1_loss: 0.9812 - model_2_loss: 0.7478 - model_3_loss: 0.8747 - model_4_loss: 0.9788 - model_accuracy: 0.7222 - model_1_accuracy: 0.5556 - model_2_accuracy: 0.5556 - model_3_accuracy: 0.7222 - model_4_accuracy: 0.6667 - loss1: 8.3204 - loss2: 9.8482 - val_loss: 8.2325 - val_model_loss: 1.6588 - val_model_1_loss: 1.6259 - val_model_2_loss: 1.6943 - val_model_3_loss: 1.6072 - val_model_4_loss: 1.6463 - val_model_accuracy: 0.3750 - val_model_1_accuracy: 0.3056 - val_model_2_accuracy: 0.3833 - val_model_3_accuracy: 0.3250 - val_model_4_accuracy: 0.3583 - val_loss1: 7.7445 - val_loss2: 9.9410
# Epoch 52/300
# 2/2 [==============================] - 1s 1s/step - loss: 3.9663 - model_loss: 0.8503 - model_1_loss: 0.9252 - model_2_loss: 0.7371 - model_3_loss: 0.6872 - model_4_loss: 0.7664 - model_accuracy: 0.6111 - model_1_accuracy: 0.6667 - model_2_accuracy: 0.7222 - model_3_accuracy: 0.7778 - model_4_accuracy: 0.7778 - loss1: 8.4160 - loss2: 9.8398 - val_loss: 8.2756 - val_model_loss: 1.6759 - val_model_1_loss: 1.6457 - val_model_2_loss: 1.7032 - val_model_3_loss: 1.6172 - val_model_4_loss: 1.6336 - val_model_accuracy: 0.3722 - val_model_1_accuracy: 0.2917 - val_model_2_accuracy: 0.3722 - val_model_3_accuracy: 0.3222 - val_model_4_accuracy: 0.3639 - val_loss1: 7.7319 - val_loss2: 9.9370
# Epoch 53/300
# 2/2 [==============================] - 1s 1s/step - loss: 3.5902 - model_loss: 0.6643 - model_1_loss: 0.6732 - model_2_loss: 0.6914 - model_3_loss: 0.6628 - model_4_loss: 0.8985 - model_accuracy: 0.7778 - model_1_accuracy: 0.7778 - model_2_accuracy: 0.7778 - model_3_accuracy: 0.7778 - model_4_accuracy: 0.7222 - loss1: 8.4910 - loss2: 9.8443 - val_loss: 8.4312 - val_model_loss: 1.7570 - val_model_1_loss: 1.6894 - val_model_2_loss: 1.7300 - val_model_3_loss: 1.6410 - val_model_4_loss: 1.6138 - val_model_accuracy: 0.3333 - val_model_1_accuracy: 0.2722 - val_model_2_accuracy: 0.3500 - val_model_3_accuracy: 0.3167 - val_model_4_accuracy: 0.3889 - val_loss1: 7.7295 - val_loss2: 9.9304
# Epoch 54/300
# 2/2 [==============================] - 1s 1s/step - loss: 4.7523 - model_loss: 0.8647 - model_1_loss: 0.7839 - model_2_loss: 0.8351 - model_3_loss: 1.1789 - model_4_loss: 1.0897 - model_accuracy: 0.7222 - model_1_accuracy: 0.7222 - model_2_accuracy: 0.7778 - model_3_accuracy: 0.5556 - model_4_accuracy: 0.6667 - loss1: 8.1850 - loss2: 9.8060 - val_loss: 8.4845 - val_model_loss: 1.8354 - val_model_1_loss: 1.6645 - val_model_2_loss: 1.7447 - val_model_3_loss: 1.6477 - val_model_4_loss: 1.5921 - val_model_accuracy: 0.3056 - val_model_1_accuracy: 0.2806 - val_model_2_accuracy: 0.3472 - val_model_3_accuracy: 0.3167 - val_model_4_accuracy: 0.4861 - val_loss1: 7.7995 - val_loss2: 9.9282
# Epoch 55/300
# 2/2 [==============================] - 1s 1s/step - loss: 3.8179 - model_loss: 0.5735 - model_1_loss: 0.8620 - model_2_loss: 0.5923 - model_3_loss: 0.9156 - model_4_loss: 0.8746 - model_accuracy: 0.7778 - model_1_accuracy: 0.6111 - model_2_accuracy: 0.8333 - model_3_accuracy: 0.5556 - model_4_accuracy: 0.6667 - loss1: 8.2561 - loss2: 9.8201 - val_loss: 8.5878 - val_model_loss: 1.8779 - val_model_1_loss: 1.6512 - val_model_2_loss: 1.7760 - val_model_3_loss: 1.6543 - val_model_4_loss: 1.6285 - val_model_accuracy: 0.2611 - val_model_1_accuracy: 0.3083 - val_model_2_accuracy: 0.3667 - val_model_3_accuracy: 0.3028 - val_model_4_accuracy: 0.4500 - val_loss1: 7.8490 - val_loss2: 9.9272
# Epoch 56/300
# 2/2 [==============================] - 1s 1s/step - loss: 4.0965 - model_loss: 0.7576 - model_1_loss: 0.8096 - model_2_loss: 0.7711 - model_3_loss: 0.9063 - model_4_loss: 0.8519 - model_accuracy: 0.6667 - model_1_accuracy: 0.6667 - model_2_accuracy: 0.7222 - model_3_accuracy: 0.8333 - model_4_accuracy: 0.7222 - loss1: 8.3058 - loss2: 9.8279 - val_loss: 8.6156 - val_model_loss: 1.8126 - val_model_1_loss: 1.6804 - val_model_2_loss: 1.8177 - val_model_3_loss: 1.6469 - val_model_4_loss: 1.6580 - val_model_accuracy: 0.2917 - val_model_1_accuracy: 0.3278 - val_model_2_accuracy: 0.3917 - val_model_3_accuracy: 0.3028 - val_model_4_accuracy: 0.4028 - val_loss1: 7.8371 - val_loss2: 9.9235
# Epoch 57/300
# 2/2 [==============================] - 1s 1s/step - loss: 3.9098 - model_loss: 0.6552 - model_1_loss: 0.9207 - model_2_loss: 0.9009 - model_3_loss: 0.6748 - model_4_loss: 0.7582 - model_accuracy: 0.7222 - model_1_accuracy: 0.6667 - model_2_accuracy: 0.7778 - model_3_accuracy: 0.8333 - model_4_accuracy: 0.7222 - loss1: 8.3633 - loss2: 9.8337 - val_loss: 8.5963 - val_model_loss: 1.7790 - val_model_1_loss: 1.6673 - val_model_2_loss: 1.8809 - val_model_3_loss: 1.6132 - val_model_4_loss: 1.6559 - val_model_accuracy: 0.3472 - val_model_1_accuracy: 0.3500 - val_model_2_accuracy: 0.3917 - val_model_3_accuracy: 0.3000 - val_model_4_accuracy: 0.4139 - val_loss1: 7.8529 - val_loss2: 9.9224
# Epoch 58/300
# 2/2 [==============================] - 1s 1s/step - loss: 4.1385 - model_loss: 0.8134 - model_1_loss: 0.8017 - model_2_loss: 1.0783 - model_3_loss: 0.9110 - model_4_loss: 0.5342 - model_accuracy: 0.6667 - model_1_accuracy: 0.6667 - model_2_accuracy: 0.6111 - model_3_accuracy: 0.6111 - model_4_accuracy: 0.8333 - loss1: 8.6251 - loss2: 9.8384 - val_loss: 8.6274 - val_model_loss: 1.8517 - val_model_1_loss: 1.6275 - val_model_2_loss: 1.8817 - val_model_3_loss: 1.5642 - val_model_4_loss: 1.7023 - val_model_accuracy: 0.3667 - val_model_1_accuracy: 0.3833 - val_model_2_accuracy: 0.3889 - val_model_3_accuracy: 0.3194 - val_model_4_accuracy: 0.3833 - val_loss1: 7.8873 - val_loss2: 9.9191
# Epoch 59/300
# 2/2 [==============================] - 1s 1s/step - loss: 3.7744 - model_loss: 0.6459 - model_1_loss: 0.9898 - model_2_loss: 0.6120 - model_3_loss: 0.8015 - model_4_loss: 0.7252 - model_accuracy: 0.7222 - model_1_accuracy: 0.6667 - model_2_accuracy: 0.7778 - model_3_accuracy: 0.7222 - model_4_accuracy: 0.7222 - loss1: 8.2921 - loss2: 9.8229 - val_loss: 8.6779 - val_model_loss: 1.9066 - val_model_1_loss: 1.5992 - val_model_2_loss: 1.8620 - val_model_3_loss: 1.5658 - val_model_4_loss: 1.7443 - val_model_accuracy: 0.3250 - val_model_1_accuracy: 0.4417 - val_model_2_accuracy: 0.3833 - val_model_3_accuracy: 0.3167 - val_model_4_accuracy: 0.3889 - val_loss1: 7.9494 - val_loss2: 9.9192
# Epoch 60/300
# 2/2 [==============================] - 1s 1s/step - loss: 2.5107 - model_loss: 0.6202 - model_1_loss: 0.5429 - model_2_loss: 0.3636 - model_3_loss: 0.5050 - model_4_loss: 0.4791 - model_accuracy: 0.8333 - model_1_accuracy: 0.8333 - model_2_accuracy: 0.8333 - model_3_accuracy: 0.8333 - model_4_accuracy: 0.8333 - loss1: 8.5642 - loss2: 9.8358 - val_loss: 8.7984 - val_model_loss: 1.9651 - val_model_1_loss: 1.6070 - val_model_2_loss: 1.8393 - val_model_3_loss: 1.5717 - val_model_4_loss: 1.8153 - val_model_accuracy: 0.3139 - val_model_1_accuracy: 0.4556 - val_model_2_accuracy: 0.3833 - val_model_3_accuracy: 0.3222 - val_model_4_accuracy: 0.3556 - val_loss1: 7.9775 - val_loss2: 9.9148
# Epoch 61/300
# 2/2 [==============================] - 1s 1s/step - loss: 4.0605 - model_loss: 0.6546 - model_1_loss: 0.7892 - model_2_loss: 0.8420 - model_3_loss: 0.7593 - model_4_loss: 1.0154 - model_accuracy: 0.8333 - model_1_accuracy: 0.6667 - model_2_accuracy: 0.7778 - model_3_accuracy: 0.8333 - model_4_accuracy: 0.6667 - loss1: 8.5372 - loss2: 9.8178 - val_loss: 9.0388 - val_model_loss: 2.0794 - val_model_1_loss: 1.6385 - val_model_2_loss: 1.8077 - val_model_3_loss: 1.5897 - val_model_4_loss: 1.9235 - val_model_accuracy: 0.3083 - val_model_1_accuracy: 0.3889 - val_model_2_accuracy: 0.3972 - val_model_3_accuracy: 0.3361 - val_model_4_accuracy: 0.3278 - val_loss1: 7.9877 - val_loss2: 9.9093
# Epoch 62/300
# 2/2 [==============================] - 1s 1s/step - loss: 2.0142 - model_loss: 0.3099 - model_1_loss: 0.5433 - model_2_loss: 0.3732 - model_3_loss: 0.4211 - model_4_loss: 0.3667 - model_accuracy: 0.9444 - model_1_accuracy: 0.9444 - model_2_accuracy: 0.8889 - model_3_accuracy: 0.9444 - model_4_accuracy: 0.9444 - loss1: 8.4280 - loss2: 9.8211 - val_loss: 9.2277 - val_model_loss: 2.0994 - val_model_1_loss: 1.6915 - val_model_2_loss: 1.8455 - val_model_3_loss: 1.6093 - val_model_4_loss: 1.9819 - val_model_accuracy: 0.3056 - val_model_1_accuracy: 0.3306 - val_model_2_accuracy: 0.3500 - val_model_3_accuracy: 0.3417 - val_model_4_accuracy: 0.3528 - val_loss1: 7.9462 - val_loss2: 9.9002
# Epoch 63/300
# 2/2 [==============================] - 1s 1s/step - loss: 3.0928 - model_loss: 0.3771 - model_1_loss: 0.9731 - model_2_loss: 0.6098 - model_3_loss: 0.4119 - model_4_loss: 0.7209 - model_accuracy: 0.9444 - model_1_accuracy: 0.6667 - model_2_accuracy: 0.8333 - model_3_accuracy: 0.8333 - model_4_accuracy: 0.6667 - loss1: 8.6717 - loss2: 9.7990 - val_loss: 9.7986 - val_model_loss: 2.3143 - val_model_1_loss: 1.7737 - val_model_2_loss: 1.9454 - val_model_3_loss: 1.6624 - val_model_4_loss: 2.1027 - val_model_accuracy: 0.2500 - val_model_1_accuracy: 0.2583 - val_model_2_accuracy: 0.2833 - val_model_3_accuracy: 0.3306 - val_model_4_accuracy: 0.3417 - val_loss1: 7.9639 - val_loss2: 9.8925
# Epoch 64/300
# 2/2 [==============================] - 1s 1s/step - loss: 2.8808 - model_loss: 0.4558 - model_1_loss: 0.7642 - model_2_loss: 0.4516 - model_3_loss: 0.5236 - model_4_loss: 0.6856 - model_accuracy: 0.7778 - model_1_accuracy: 0.7222 - model_2_accuracy: 0.8333 - model_3_accuracy: 0.9444 - model_4_accuracy: 0.6667 - loss1: 8.6322 - loss2: 9.8036 - val_loss: 10.2814 - val_model_loss: 2.4086 - val_model_1_loss: 1.8135 - val_model_2_loss: 2.1216 - val_model_3_loss: 1.7225 - val_model_4_loss: 2.2152 - val_model_accuracy: 0.2278 - val_model_1_accuracy: 0.2333 - val_model_2_accuracy: 0.2361 - val_model_3_accuracy: 0.3056 - val_model_4_accuracy: 0.2306 - val_loss1: 8.0069 - val_loss2: 9.8868
# Epoch 65/300
# 2/2 [==============================] - 1s 1s/step - loss: 4.9504 - model_loss: 0.8515 - model_1_loss: 1.2870 - model_2_loss: 0.9165 - model_3_loss: 0.8548 - model_4_loss: 1.0405 - model_accuracy: 0.6111 - model_1_accuracy: 0.6111 - model_2_accuracy: 0.5556 - model_3_accuracy: 0.7778 - model_4_accuracy: 0.7778 - loss1: 8.2525 - loss2: 9.7615 - val_loss: 9.7287 - val_model_loss: 2.0968 - val_model_1_loss: 1.6927 - val_model_2_loss: 2.0063 - val_model_3_loss: 1.7241 - val_model_4_loss: 2.2089 - val_model_accuracy: 0.2417 - val_model_1_accuracy: 0.2611 - val_model_2_accuracy: 0.2722 - val_model_3_accuracy: 0.3139 - val_model_4_accuracy: 0.1861 - val_loss1: 7.9799 - val_loss2: 9.8876
# Epoch 66/300
# 2/2 [==============================] - 1s 1s/step - loss: 3.3970 - model_loss: 0.5949 - model_1_loss: 0.7175 - model_2_loss: 0.7135 - model_3_loss: 0.5608 - model_4_loss: 0.8102 - model_accuracy: 0.7222 - model_1_accuracy: 0.6667 - model_2_accuracy: 0.7778 - model_3_accuracy: 0.7222 - model_4_accuracy: 0.6111 - loss1: 8.3725 - loss2: 9.7790 - val_loss: 8.7660 - val_model_loss: 1.8376 - val_model_1_loss: 1.5896 - val_model_2_loss: 1.7548 - val_model_3_loss: 1.6535 - val_model_4_loss: 1.9304 - val_model_accuracy: 0.3611 - val_model_1_accuracy: 0.3611 - val_model_2_accuracy: 0.4528 - val_model_3_accuracy: 0.3389 - val_model_4_accuracy: 0.2417 - val_loss1: 7.9461 - val_loss2: 9.8993
# Epoch 67/300
# 2/2 [==============================] - 1s 1s/step - loss: 3.3755 - model_loss: 0.7549 - model_1_loss: 0.8965 - model_2_loss: 0.7703 - model_3_loss: 0.4273 - model_4_loss: 0.5265 - model_accuracy: 0.8333 - model_1_accuracy: 0.5556 - model_2_accuracy: 0.7778 - model_3_accuracy: 0.8889 - model_4_accuracy: 0.7778 - loss1: 8.5008 - loss2: 9.7962 - val_loss: 8.6956 - val_model_loss: 1.8044 - val_model_1_loss: 1.6020 - val_model_2_loss: 1.8553 - val_model_3_loss: 1.6410 - val_model_4_loss: 1.7929 - val_model_accuracy: 0.4194 - val_model_1_accuracy: 0.3861 - val_model_2_accuracy: 0.4000 - val_model_3_accuracy: 0.3611 - val_model_4_accuracy: 0.3556 - val_loss1: 7.9382 - val_loss2: 9.9046
# Epoch 68/300
# 2/2 [==============================] - 1s 1s/step - loss: 5.3483 - model_loss: 1.0744 - model_1_loss: 0.8450 - model_2_loss: 1.5922 - model_3_loss: 0.7829 - model_4_loss: 1.0538 - model_accuracy: 0.6111 - model_1_accuracy: 0.6111 - model_2_accuracy: 0.5000 - model_3_accuracy: 0.8333 - model_4_accuracy: 0.6667 - loss1: 8.5569 - loss2: 9.8120 - val_loss: 8.8939 - val_model_loss: 1.8293 - val_model_1_loss: 1.7005 - val_model_2_loss: 1.9001 - val_model_3_loss: 1.6407 - val_model_4_loss: 1.8233 - val_model_accuracy: 0.3556 - val_model_1_accuracy: 0.3306 - val_model_2_accuracy: 0.3917 - val_model_3_accuracy: 0.4028 - val_model_4_accuracy: 0.3917 - val_loss1: 7.9175 - val_loss2: 9.9073
# Epoch 69/300
# ...
# Epoch 279/300
# 2/2 [==============================] - 1s 1s/step - loss: 1.8770 - model_loss: 0.3969 - model_1_loss: 0.4103 - model_2_loss: 0.2315 - model_3_loss: 0.3801 - model_4_loss: 0.4582 - model_accuracy: 0.8889 - model_1_accuracy: 0.8333 - model_2_accuracy: 0.8889 - model_3_accuracy: 0.8333 - model_4_accuracy: 0.7778 - loss1: 8.7467 - loss2: 9.7049 - val_loss: 10.5798 - val_model_loss: 2.2942 - val_model_1_loss: 2.0479 - val_model_2_loss: 2.6255 - val_model_3_loss: 1.6810 - val_model_4_loss: 1.9313 - val_model_accuracy: 0.3694 - val_model_1_accuracy: 0.3667 - val_model_2_accuracy: 0.3611 - val_model_3_accuracy: 0.4639 - val_model_4_accuracy: 0.3611 - val_loss1: 8.4402 - val_loss2: 9.7796
# Epoch 280/300
# 2/2 [==============================] - 1s 1s/step - loss: 2.3050 - model_loss: 0.2815 - model_1_loss: 0.4687 - model_2_loss: 0.5670 - model_3_loss: 0.3666 - model_4_loss: 0.6212 - model_accuracy: 1.0000 - model_1_accuracy: 0.8333 - model_2_accuracy: 0.7778 - model_3_accuracy: 0.8889 - model_4_accuracy: 0.7222 - loss1: 8.8527 - loss2: 9.7132 - val_loss: 10.5712 - val_model_loss: 2.2482 - val_model_1_loss: 2.0098 - val_model_2_loss: 2.6228 - val_model_3_loss: 1.8243 - val_model_4_loss: 1.8661 - val_model_accuracy: 0.3917 - val_model_1_accuracy: 0.3722 - val_model_2_accuracy: 0.3639 - val_model_3_accuracy: 0.4500 - val_model_4_accuracy: 0.3917 - val_loss1: 8.4458 - val_loss2: 9.7740
# Epoch 281/300
# 2/2 [==============================] - 1s 1s/step - loss: 1.5515 - model_loss: 0.1808 - model_1_loss: 0.3434 - model_2_loss: 0.3572 - model_3_loss: 0.3671 - model_4_loss: 0.3029 - model_accuracy: 0.9444 - model_1_accuracy: 0.8333 - model_2_accuracy: 0.8889 - model_3_accuracy: 0.9444 - model_4_accuracy: 0.8889 - loss1: 9.0892 - loss2: 9.7109 - val_loss: 10.6620 - val_model_loss: 2.2671 - val_model_1_loss: 1.9994 - val_model_2_loss: 2.6286 - val_model_3_loss: 1.9610 - val_model_4_loss: 1.8059 - val_model_accuracy: 0.4111 - val_model_1_accuracy: 0.3750 - val_model_2_accuracy: 0.3667 - val_model_3_accuracy: 0.4333 - val_model_4_accuracy: 0.4028 - val_loss1: 8.4514 - val_loss2: 9.7676
# Epoch 282/300
# 2/2 [==============================] - 1s 1s/step - loss: 2.7216 - model_loss: 0.4320 - model_1_loss: 0.6014 - model_2_loss: 0.6916 - model_3_loss: 0.6747 - model_4_loss: 0.3220 - model_accuracy: 0.8333 - model_1_accuracy: 0.7222 - model_2_accuracy: 0.8333 - model_3_accuracy: 0.7222 - model_4_accuracy: 0.8889 - loss1: 8.9410 - loss2: 9.7290 - val_loss: 10.7470 - val_model_loss: 2.3327 - val_model_1_loss: 2.0075 - val_model_2_loss: 2.6130 - val_model_3_loss: 2.0004 - val_model_4_loss: 1.7934 - val_model_accuracy: 0.4139 - val_model_1_accuracy: 0.3806 - val_model_2_accuracy: 0.3667 - val_model_3_accuracy: 0.4417 - val_model_4_accuracy: 0.4361 - val_loss1: 8.4426 - val_loss2: 9.7651
# Epoch 283/300
# 2/2 [==============================] - 1s 1s/step - loss: 3.2140 - model_loss: 0.6373 - model_1_loss: 0.6002 - model_2_loss: 0.6445 - model_3_loss: 0.4738 - model_4_loss: 0.8580 - model_accuracy: 0.8333 - model_1_accuracy: 0.8333 - model_2_accuracy: 0.8333 - model_3_accuracy: 0.8889 - model_4_accuracy: 0.8333 - loss1: 9.0208 - loss2: 9.7099 - val_loss: 10.7677 - val_model_loss: 2.3928 - val_model_1_loss: 2.0587 - val_model_2_loss: 2.5407 - val_model_3_loss: 1.9103 - val_model_4_loss: 1.8653 - val_model_accuracy: 0.4139 - val_model_1_accuracy: 0.3778 - val_model_2_accuracy: 0.3639 - val_model_3_accuracy: 0.4556 - val_model_4_accuracy: 0.4500 - val_loss1: 8.4054 - val_loss2: 9.7742
# Epoch 284/300
# 2/2 [==============================] - 1s 1s/step - loss: 0.7099 - model_loss: 0.1709 - model_1_loss: 0.1889 - model_2_loss: 0.0567 - model_3_loss: 0.1472 - model_4_loss: 0.1462 - model_accuracy: 0.9444 - model_1_accuracy: 0.9444 - model_2_accuracy: 1.0000 - model_3_accuracy: 0.9444 - model_4_accuracy: 0.9444 - loss1: 8.9428 - loss2: 9.7220 - val_loss: 11.0070 - val_model_loss: 2.4626 - val_model_1_loss: 2.1344 - val_model_2_loss: 2.5529 - val_model_3_loss: 1.8961 - val_model_4_loss: 1.9610 - val_model_accuracy: 0.4194 - val_model_1_accuracy: 0.3722 - val_model_2_accuracy: 0.3972 - val_model_3_accuracy: 0.4694 - val_model_4_accuracy: 0.4500 - val_loss1: 8.3678 - val_loss2: 9.7766
# Epoch 285/300
# 2/2 [==============================] - 1s 1s/step - loss: 1.9668 - model_loss: 0.5904 - model_1_loss: 0.4121 - model_2_loss: 0.4188 - model_3_loss: 0.2054 - model_4_loss: 0.3401 - model_accuracy: 0.8889 - model_1_accuracy: 0.8333 - model_2_accuracy: 0.8889 - model_3_accuracy: 0.8889 - model_4_accuracy: 0.8333 - loss1: 8.7589 - loss2: 9.7117 - val_loss: 11.4414 - val_model_loss: 2.5411 - val_model_1_loss: 2.2487 - val_model_2_loss: 2.6244 - val_model_3_loss: 1.9483 - val_model_4_loss: 2.0791 - val_model_accuracy: 0.4056 - val_model_1_accuracy: 0.3750 - val_model_2_accuracy: 0.4056 - val_model_3_accuracy: 0.4722 - val_model_4_accuracy: 0.4722 - val_loss1: 8.2754 - val_loss2: 9.7734
# Epoch 286/300
# 2/2 [==============================] - 1s 1s/step - loss: 2.5827 - model_loss: 0.3479 - model_1_loss: 0.2988 - model_2_loss: 0.9242 - model_3_loss: 0.4234 - model_4_loss: 0.5885 - model_accuracy: 0.8333 - model_1_accuracy: 0.9444 - model_2_accuracy: 0.6667 - model_3_accuracy: 0.8333 - model_4_accuracy: 0.7778 - loss1: 8.7190 - loss2: 9.7379 - val_loss: 11.7522 - val_model_loss: 2.6313 - val_model_1_loss: 2.3695 - val_model_2_loss: 2.6428 - val_model_3_loss: 2.0137 - val_model_4_loss: 2.0949 - val_model_accuracy: 0.3944 - val_model_1_accuracy: 0.3694 - val_model_2_accuracy: 0.3806 - val_model_3_accuracy: 0.4611 - val_model_4_accuracy: 0.4833 - val_loss1: 8.1523 - val_loss2: 9.7665
# Epoch 287/300
# 2/2 [==============================] - 1s 1s/step - loss: 2.8202 - model_loss: 0.4090 - model_1_loss: 0.5407 - model_2_loss: 0.7301 - model_3_loss: 0.6876 - model_4_loss: 0.4528 - model_accuracy: 0.8333 - model_1_accuracy: 0.8889 - model_2_accuracy: 0.7778 - model_3_accuracy: 0.7778 - model_4_accuracy: 0.8333 - loss1: 8.7468 - loss2: 9.7111 - val_loss: 11.7939 - val_model_loss: 2.7147 - val_model_1_loss: 2.4348 - val_model_2_loss: 2.6483 - val_model_3_loss: 1.9718 - val_model_4_loss: 2.0243 - val_model_accuracy: 0.3639 - val_model_1_accuracy: 0.3778 - val_model_2_accuracy: 0.3639 - val_model_3_accuracy: 0.4722 - val_model_4_accuracy: 0.4944 - val_loss1: 8.0315 - val_loss2: 9.7604
# Epoch 288/300
# 2/2 [==============================] - 1s 1s/step - loss: 2.6935 - model_loss: 0.4546 - model_1_loss: 0.7005 - model_2_loss: 0.6867 - model_3_loss: 0.2609 - model_4_loss: 0.5908 - model_accuracy: 0.8889 - model_1_accuracy: 0.7778 - model_2_accuracy: 0.7222 - model_3_accuracy: 0.8889 - model_4_accuracy: 0.8333 - loss1: 8.3707 - loss2: 9.6971 - val_loss: 11.7533 - val_model_loss: 2.8087 - val_model_1_loss: 2.4479 - val_model_2_loss: 2.6077 - val_model_3_loss: 1.9776 - val_model_4_loss: 1.9115 - val_model_accuracy: 0.3528 - val_model_1_accuracy: 0.3806 - val_model_2_accuracy: 0.3611 - val_model_3_accuracy: 0.4694 - val_model_4_accuracy: 0.5000 - val_loss1: 7.9780 - val_loss2: 9.7590
# Epoch 289/300
# 2/2 [==============================] - 1s 1s/step - loss: 2.6063 - model_loss: 0.4385 - model_1_loss: 0.5820 - model_2_loss: 0.6504 - model_3_loss: 0.4935 - model_4_loss: 0.4419 - model_accuracy: 0.8333 - model_1_accuracy: 0.7222 - model_2_accuracy: 0.7222 - model_3_accuracy: 0.8889 - model_4_accuracy: 0.8889 - loss1: 8.3597 - loss2: 9.7402 - val_loss: 11.6351 - val_model_loss: 2.8921 - val_model_1_loss: 2.3875 - val_model_2_loss: 2.5066 - val_model_3_loss: 2.0189 - val_model_4_loss: 1.8299 - val_model_accuracy: 0.3444 - val_model_1_accuracy: 0.3833 - val_model_2_accuracy: 0.3917 - val_model_3_accuracy: 0.4417 - val_model_4_accuracy: 0.4917 - val_loss1: 7.9523 - val_loss2: 9.7617
# Epoch 290/300
# 2/2 [==============================] - 1s 1s/step - loss: 1.6130 - model_loss: 0.2559 - model_1_loss: 0.2931 - model_2_loss: 0.2146 - model_3_loss: 0.3735 - model_4_loss: 0.4760 - model_accuracy: 0.8889 - model_1_accuracy: 0.8333 - model_2_accuracy: 0.9444 - model_3_accuracy: 0.8333 - model_4_accuracy: 0.8333 - loss1: 8.6218 - loss2: 9.7203 - val_loss: 11.6697 - val_model_loss: 2.9328 - val_model_1_loss: 2.3867 - val_model_2_loss: 2.4286 - val_model_3_loss: 2.0893 - val_model_4_loss: 1.8322 - val_model_accuracy: 0.3389 - val_model_1_accuracy: 0.3833 - val_model_2_accuracy: 0.3917 - val_model_3_accuracy: 0.4611 - val_model_4_accuracy: 0.4639 - val_loss1: 7.9461 - val_loss2: 9.7588
# Epoch 291/300
# 2/2 [==============================] - 1s 1s/step - loss: 1.6865 - model_loss: 0.2797 - model_1_loss: 0.3756 - model_2_loss: 0.2622 - model_3_loss: 0.1882 - model_4_loss: 0.5808 - model_accuracy: 0.8333 - model_1_accuracy: 0.9444 - model_2_accuracy: 0.8333 - model_3_accuracy: 0.9444 - model_4_accuracy: 0.8889 - loss1: 8.4229 - loss2: 9.6993 - val_loss: 11.9893 - val_model_loss: 2.9980 - val_model_1_loss: 2.4597 - val_model_2_loss: 2.4759 - val_model_3_loss: 2.1776 - val_model_4_loss: 1.8780 - val_model_accuracy: 0.3167 - val_model_1_accuracy: 0.3750 - val_model_2_accuracy: 0.3861 - val_model_3_accuracy: 0.4556 - val_model_4_accuracy: 0.4611 - val_loss1: 7.9386 - val_loss2: 9.7493
# Epoch 292/300
# 2/2 [==============================] - 1s 1s/step - loss: 1.9708 - model_loss: 0.3443 - model_1_loss: 0.5719 - model_2_loss: 0.3576 - model_3_loss: 0.3807 - model_4_loss: 0.3162 - model_accuracy: 0.9444 - model_1_accuracy: 0.8333 - model_2_accuracy: 0.8889 - model_3_accuracy: 0.8889 - model_4_accuracy: 0.8889 - loss1: 8.6747 - loss2: 9.6643 - val_loss: 12.4500 - val_model_loss: 3.0386 - val_model_1_loss: 2.5067 - val_model_2_loss: 2.5853 - val_model_3_loss: 2.3012 - val_model_4_loss: 2.0182 - val_model_accuracy: 0.3278 - val_model_1_accuracy: 0.3750 - val_model_2_accuracy: 0.3750 - val_model_3_accuracy: 0.4417 - val_model_4_accuracy: 0.4306 - val_loss1: 7.9640 - val_loss2: 9.7382
# Epoch 293/300
# 2/2 [==============================] - 1s 1s/step - loss: 2.4525 - model_loss: 0.5876 - model_1_loss: 0.2544 - model_2_loss: 0.5857 - model_3_loss: 0.3278 - model_4_loss: 0.6971 - model_accuracy: 0.7222 - model_1_accuracy: 1.0000 - model_2_accuracy: 0.8333 - model_3_accuracy: 0.8333 - model_4_accuracy: 0.7222 - loss1: 8.5967 - loss2: 9.7320 - val_loss: 12.5919 - val_model_loss: 3.0481 - val_model_1_loss: 2.5399 - val_model_2_loss: 2.5860 - val_model_3_loss: 2.3557 - val_model_4_loss: 2.0622 - val_model_accuracy: 0.3500 - val_model_1_accuracy: 0.3722 - val_model_2_accuracy: 0.3722 - val_model_3_accuracy: 0.4472 - val_model_4_accuracy: 0.4528 - val_loss1: 8.0048 - val_loss2: 9.7317
# Epoch 294/300
# 2/2 [==============================] - 1s 1s/step - loss: 2.0119 - model_loss: 0.2184 - model_1_loss: 0.6186 - model_2_loss: 0.3439 - model_3_loss: 0.4341 - model_4_loss: 0.3970 - model_accuracy: 0.9444 - model_1_accuracy: 0.8333 - model_2_accuracy: 0.8889 - model_3_accuracy: 0.8889 - model_4_accuracy: 0.8333 - loss1: 8.5860 - loss2: 9.6476 - val_loss: 12.8657 - val_model_loss: 3.1460 - val_model_1_loss: 2.5844 - val_model_2_loss: 2.5616 - val_model_3_loss: 2.4397 - val_model_4_loss: 2.1340 - val_model_accuracy: 0.3444 - val_model_1_accuracy: 0.3778 - val_model_2_accuracy: 0.3806 - val_model_3_accuracy: 0.4333 - val_model_4_accuracy: 0.4500 - val_loss1: 8.0247 - val_loss2: 9.7232
# Epoch 295/300
# 2/2 [==============================] - 1s 1s/step - loss: 2.7373 - model_loss: 0.3559 - model_1_loss: 0.4750 - model_2_loss: 0.6374 - model_3_loss: 0.4555 - model_4_loss: 0.8135 - model_accuracy: 0.8333 - model_1_accuracy: 0.7778 - model_2_accuracy: 0.7778 - model_3_accuracy: 0.8333 - model_4_accuracy: 0.7222 - loss1: 8.7321 - loss2: 9.6730 - val_loss: 13.1549 - val_model_loss: 3.2614 - val_model_1_loss: 2.6522 - val_model_2_loss: 2.5470 - val_model_3_loss: 2.5127 - val_model_4_loss: 2.1816 - val_model_accuracy: 0.3639 - val_model_1_accuracy: 0.3722 - val_model_2_accuracy: 0.3861 - val_model_3_accuracy: 0.4444 - val_model_4_accuracy: 0.4278 - val_loss1: 8.0128 - val_loss2: 9.7130
# Epoch 296/300
# 2/2 [==============================] - 1s 1s/step - loss: 2.6131 - model_loss: 0.2822 - model_1_loss: 0.9265 - model_2_loss: 0.5127 - model_3_loss: 0.4912 - model_4_loss: 0.4004 - model_accuracy: 0.8889 - model_1_accuracy: 0.7222 - model_2_accuracy: 0.6667 - model_3_accuracy: 0.7778 - model_4_accuracy: 0.8889 - loss1: 8.3761 - loss2: 9.6290 - val_loss: 13.4490 - val_model_loss: 3.3200 - val_model_1_loss: 2.6982 - val_model_2_loss: 2.5156 - val_model_3_loss: 2.6330 - val_model_4_loss: 2.2822 - val_model_accuracy: 0.3611 - val_model_1_accuracy: 0.3861 - val_model_2_accuracy: 0.3667 - val_model_3_accuracy: 0.4583 - val_model_4_accuracy: 0.4083 - val_loss1: 8.0291 - val_loss2: 9.7026
# Epoch 297/300
# 2/2 [==============================] - 1s 1s/step - loss: 2.8463 - model_loss: 0.7813 - model_1_loss: 0.3886 - model_2_loss: 0.5450 - model_3_loss: 0.6427 - model_4_loss: 0.4887 - model_accuracy: 0.8333 - model_1_accuracy: 0.8889 - model_2_accuracy: 0.8333 - model_3_accuracy: 0.8333 - model_4_accuracy: 0.8333 - loss1: 8.6007 - loss2: 9.6526 - val_loss: 13.0778 - val_model_loss: 3.2082 - val_model_1_loss: 2.6806 - val_model_2_loss: 2.3461 - val_model_3_loss: 2.5146 - val_model_4_loss: 2.3283 - val_model_accuracy: 0.3861 - val_model_1_accuracy: 0.3806 - val_model_2_accuracy: 0.3611 - val_model_3_accuracy: 0.4667 - val_model_4_accuracy: 0.4250 - val_loss1: 7.9978 - val_loss2: 9.6878
# Epoch 298/300
# 2/2 [==============================] - 1s 1s/step - loss: 2.5778 - model_loss: 0.8365 - model_1_loss: 0.4408 - model_2_loss: 0.3292 - model_3_loss: 0.5658 - model_4_loss: 0.4054 - model_accuracy: 0.7778 - model_1_accuracy: 0.8889 - model_2_accuracy: 0.8889 - model_3_accuracy: 0.8889 - model_4_accuracy: 0.8889 - loss1: 8.3238 - loss2: 9.6530 - val_loss: 12.3248 - val_model_loss: 2.9146 - val_model_1_loss: 2.5830 - val_model_2_loss: 2.2191 - val_model_3_loss: 2.2851 - val_model_4_loss: 2.3230 - val_model_accuracy: 0.4028 - val_model_1_accuracy: 0.3861 - val_model_2_accuracy: 0.3444 - val_model_3_accuracy: 0.4694 - val_model_4_accuracy: 0.4417 - val_loss1: 7.9570 - val_loss2: 9.6810
# Epoch 299/300
# 2/2 [==============================] - 1s 1s/step - loss: 1.4994 - model_loss: 0.2753 - model_1_loss: 0.2346 - model_2_loss: 0.3199 - model_3_loss: 0.2668 - model_4_loss: 0.4028 - model_accuracy: 0.9444 - model_1_accuracy: 0.8889 - model_2_accuracy: 0.8333 - model_3_accuracy: 0.8889 - model_4_accuracy: 0.8889 - loss1: 8.4408 - loss2: 9.6246 - val_loss: 11.7681 - val_model_loss: 2.6426 - val_model_1_loss: 2.4745 - val_model_2_loss: 2.1609 - val_model_3_loss: 2.1686 - val_model_4_loss: 2.3216 - val_model_accuracy: 0.3972 - val_model_1_accuracy: 0.3861 - val_model_2_accuracy: 0.3444 - val_model_3_accuracy: 0.4667 - val_model_4_accuracy: 0.4556 - val_loss1: 7.9338 - val_loss2: 9.6741
# Epoch 300/300
# 2/2 [==============================] - 1s 1s/step - loss: 3.5156 - model_loss: 0.5431 - model_1_loss: 0.6062 - model_2_loss: 0.5771 - model_3_loss: 1.0370 - model_4_loss: 0.7521 - model_accuracy: 0.7222 - model_1_accuracy: 0.7222 - model_2_accuracy: 0.7778 - model_3_accuracy: 0.7222 - model_4_accuracy: 0.6111 - loss1: 8.0803 - loss2: 9.6454 - val_loss: 11.2599 - val_model_loss: 2.4723 - val_model_1_loss: 2.3283 - val_model_2_loss: 2.1447 - val_model_3_loss: 2.0486 - val_model_4_loss: 2.2660 - val_model_accuracy: 0.3889 - val_model_1_accuracy: 0.3917 - val_model_2_accuracy: 0.3417 - val_model_3_accuracy: 0.4833 - val_model_4_accuracy: 0.4556 - val_loss1: 7.9327 - val_loss2: 9.6892
# Epoch 00178: early stopping and save the model

# %%
#evaluation of the five base models
evaluate = model_train.evaluate(x_test,[keras.utils.to_categorical(y_test),keras.utils.to_categorical(y_test),keras.utils.to_categorical(y_test),keras.utils.to_categorical(y_test),keras.utils.to_categorical(y_test)],batch_size=10)
evaluate
# Out:
# 36/36 [==============================] - 2s 28ms/step - loss: 12.2758 - model_loss: 2.9699 - model_1_loss: 2.3723 - model_2_loss: 2.4696 - model_3_loss: 1.8116 - model_4_loss: 2.6524 - model_accuracy: 0.3667 - model_1_accuracy: 0.4306 - model_2_accuracy: 0.3889 - model_3_accuracy: 0.4056 - model_4_accuracy: 0.3833 - loss1: 7.5797 - loss2: 9.7577

# %%
#hard voting ensemble
class HardVotingEnsemble:
    def __init__(self, model, testdata ,batch_size):
        self.ensemble_model = model
        self.testdata = testdata
        self.batch_size = batch_size
        self.data_size = testdata[1].shape[0]
    def prediction(self):
        predictions =[]
        for i in range(int(self.data_size/self.batch_size)):
            batch_predictions = np.argmax(self.ensemble_model.predict(self.testdata[0][i*self.batch_size:(i+1)*self.batch_size]),axis=2) 
            batch_predictions = np.stack(batch_predictions, axis=1)
            batch_predictions = [np.argmax(np.bincount(pre)) for pre in batch_predictions]
            predictions = predictions+batch_predictions
        return np.array(predictions)

    def evaluate(self):
        predictions = self.prediction()
        accuracy = np.sum(
            predictions == self.testdata[1]) / self.data_size
        return accuracy
HEnsemble = HardVotingEnsemble(model = model_train,testdata = (x_test, y_test),batch_size=10)
HEnsemble.evaluate()
# Out:
# 0.41944444444444445

# %%
#soft voting ensemble
def SoftVotingEnsemble(model, x, y):
  data_size = x.shape[0]
  predictions = tf.argmax(tf.reduce_mean(model.predict(x), axis = 0),axis=1)
  accuracy = np.sum(
     predictions == y) / data_size
  return accuracy
SoftVotingEnsemble(model_train, x_test, y_test)
# Out:
# 0.425

# %%
class eCustomEarlyStoppingAndSave(keras.callbacks.Callback):
    def __init__(self, save_path, patience=0):
        super(eCustomEarlyStoppingAndSave, self).__init__()
        #self.patience = patience
        self.save_path = save_path
        self.best_weights = None

    def on_train_begin(self, logs=None):
        #self.wait = 0
        self.stopped_epoch = 0
        #self.best_val_distance_loss = np.Inf
        self.best_val_acc = 0

    def on_epoch_end(self, epoch, logs=None):
        #val_distance_loss = logs.get('val_MMD_loss')
        val_acc = logs.get('val_accuracy') 

        if  np.greater(val_acc, self.best_val_acc):
            #self.best_val_distance_loss = val_distance_loss
            self.best_val_acc = val_acc
            #self.wait = 0
            # Record the best weights if current results is better (less).
            self.best_weights = self.model.get_weights()
            self.stopped_epoch = epoch
        #else:
            #self.wait += 1
            #if self.wait >= self.patience:
                #self.stopped_epoch = epoch
                #self.model.stop_training = True
                #print("Restoring model weights from the end of the best epoch.")
                #self.model.set_weights(self.best_weights)

    def on_train_end(self, logs=None):
        self.model.set_weights(self.best_weights)
        if self.stopped_epoch >= 0:
            print("Epoch %05d: early stopping and save the model" %
                  (self.stopped_epoch + 1))
        #self.model.save(self.save_path)

# %%
class eNEUdata(keras.utils.Sequence):
    def __init__(self, data_x, data_y, batch_size, train):
      self.data_x = data_x
      self.data_y = data_y
      self.train = train
      self.batch_size = batch_size

    def __len__(self):
      return int(np.ceil(len(self.data_y) / self.batch_size))

    def __getitem__(self, idx):
      batch_x = self.data_x[idx * self.batch_size:(idx + 1) * self.batch_size]
                            
      batch_y = self.data_y[idx * self.batch_size:(idx + 1) * self.batch_size]
      if self.train == True:
          batch_x = Data_Aug(batch_x)

      batch_x = np.clip(batch_x / 255.0, 0, 1).astype("float32")
      batch_y = keras.utils.to_categorical(batch_y, 6)
      return batch_x, batch_y

# %%
#feature fusion model
input_size = (200, 200, 3)
model_path = '100_samples_seed_fix.h5'
model = keras.models.load_model(model_path)
extractor_1 = keras.models.Model(inputs=model.layers[1].inputs,outputs=model.layers[1].layers[12].output)
extractor_2 = keras.models.Model(inputs=model.layers[2].inputs,outputs=model.layers[2].layers[12].output)
extractor_3 = keras.models.Model(inputs=model.layers[3].inputs,outputs=model.layers[3].layers[12].output)
extractor_4 = keras.models.Model(inputs=model.layers[4].inputs,outputs=model.layers[4].layers[12].output)
extractor_5 = keras.models.Model(inputs=model.layers[5].inputs,outputs=model.layers[5].layers[12].output)
extractor_1.trainable = False
extractor_2.trainable = False
extractor_3.trainable = False
extractor_4.trainable = False
extractor_5.trainable = False
inputs = keras.Input(shape = input_size)
features_1 = extractor_1(inputs, training = False)
features_2 = extractor_2(inputs, training = False)
features_3 = extractor_3(inputs, training = False)
features_4 = extractor_4(inputs, training = False)
features_5 = extractor_5(inputs, training = False)

x = keras.layers.Concatenate(axis=-1)([features_1,features_2,features_3,features_4,features_5])

x = keras.layers.Flatten()(x)
x = keras.layers.Dense(128,  name='dense_100')(x)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.Activation('relu')(x)
x = keras.layers.Dropout(0.5)(x)
outputs = keras.layers.Dense(6, activation='softmax', name='dense_101')(x)
ensemble = keras.Model(inputs = inputs, outputs = outputs)
ensemble.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-3),
                    loss='categorical_crossentropy',
                    metrics=['accuracy'])
train_sequence = eNEUdata(x_train, y_train, batch_size=10, train=True)
validation_sequence = eNEUdata(x_val, y_val, batch_size=10, train=False)
history = ensemble.fit(
    train_sequence,
    epochs=50,
    validation_data=validation_sequence,
    #validation_steps=200,
    callbacks=eCustomEarlyStoppingAndSave(
        save_path='ensemble.h5',
        patience=10))
evaluate = ensemble.evaluate(x_test,keras.utils.to_categorical(y_test))
# Out:
# Epoch 1/50
# 2/2 [==============================] - 4s 1s/step - loss: 2.0433 - accuracy: 0.3889 - val_loss: 18.3346 - val_accuracy: 0.3833
# Epoch 2/50
# 2/2 [==============================] - 1s 920ms/step - loss: 1.2985 - accuracy: 0.5556 - val_loss: 10.5596 - val_accuracy: 0.3806
# Epoch 3/50
# 2/2 [==============================] - 1s 1s/step - loss: 1.0808 - accuracy: 0.7222 - val_loss: 7.3208 - val_accuracy: 0.3972
# Epoch 4/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.9328 - accuracy: 0.6667 - val_loss: 6.0198 - val_accuracy: 0.4167
# Epoch 5/50
# 2/2 [==============================] - 1s 914ms/step - loss: 0.7018 - accuracy: 0.8889 - val_loss: 5.1627 - val_accuracy: 0.4139
# Epoch 6/50
# 2/2 [==============================] - 1s 912ms/step - loss: 1.2560 - accuracy: 0.5556 - val_loss: 4.5152 - val_accuracy: 0.4167
# Epoch 7/50
# 2/2 [==============================] - 1s 916ms/step - loss: 0.6410 - accuracy: 0.8889 - val_loss: 4.1926 - val_accuracy: 0.4139
# Epoch 8/50
# 2/2 [==============================] - 1s 1s/step - loss: 1.0895 - accuracy: 0.7222 - val_loss: 3.9419 - val_accuracy: 0.4333
# Epoch 9/50
# 2/2 [==============================] - 1s 914ms/step - loss: 1.1469 - accuracy: 0.6667 - val_loss: 3.7369 - val_accuracy: 0.4194
# Epoch 10/50
# 2/2 [==============================] - 1s 919ms/step - loss: 1.0755 - accuracy: 0.6111 - val_loss: 3.5369 - val_accuracy: 0.3889
# Epoch 11/50
# 2/2 [==============================] - 1s 918ms/step - loss: 0.7614 - accuracy: 0.7222 - val_loss: 3.4256 - val_accuracy: 0.3917
# Epoch 12/50
# 2/2 [==============================] - 1s 927ms/step - loss: 0.9567 - accuracy: 0.7222 - val_loss: 3.2456 - val_accuracy: 0.3889
# Epoch 13/50
# 2/2 [==============================] - 1s 933ms/step - loss: 0.8400 - accuracy: 0.7778 - val_loss: 3.1385 - val_accuracy: 0.4000
# Epoch 14/50
# 2/2 [==============================] - 1s 913ms/step - loss: 0.7621 - accuracy: 0.7778 - val_loss: 3.0089 - val_accuracy: 0.3917
# Epoch 15/50
# 2/2 [==============================] - 1s 919ms/step - loss: 1.0989 - accuracy: 0.6667 - val_loss: 2.9183 - val_accuracy: 0.4028
# Epoch 16/50
# 2/2 [==============================] - 1s 941ms/step - loss: 0.6406 - accuracy: 0.7222 - val_loss: 2.8070 - val_accuracy: 0.4083
# Epoch 17/50
# 2/2 [==============================] - 1s 948ms/step - loss: 1.1184 - accuracy: 0.6111 - val_loss: 2.7296 - val_accuracy: 0.4222
# Epoch 18/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.5826 - accuracy: 0.7778 - val_loss: 2.6931 - val_accuracy: 0.4472
# Epoch 19/50
# 2/2 [==============================] - 1s 906ms/step - loss: 0.7128 - accuracy: 0.8333 - val_loss: 2.6563 - val_accuracy: 0.4444
# Epoch 20/50
# 2/2 [==============================] - 1s 921ms/step - loss: 0.9706 - accuracy: 0.6667 - val_loss: 2.5989 - val_accuracy: 0.4083
# Epoch 21/50
# 2/2 [==============================] - 1s 914ms/step - loss: 0.9375 - accuracy: 0.6667 - val_loss: 2.5500 - val_accuracy: 0.3889
# Epoch 22/50
# 2/2 [==============================] - 1s 935ms/step - loss: 0.4579 - accuracy: 0.8333 - val_loss: 2.4915 - val_accuracy: 0.3917
# Epoch 23/50
# 2/2 [==============================] - 1s 917ms/step - loss: 0.6189 - accuracy: 0.7222 - val_loss: 2.4462 - val_accuracy: 0.3861
# Epoch 24/50
# 2/2 [==============================] - 1s 936ms/step - loss: 0.8484 - accuracy: 0.7222 - val_loss: 2.3934 - val_accuracy: 0.3722
# Epoch 25/50
# 2/2 [==============================] - 1s 927ms/step - loss: 0.6883 - accuracy: 0.7222 - val_loss: 2.3536 - val_accuracy: 0.3667
# Epoch 26/50
# 2/2 [==============================] - 1s 928ms/step - loss: 0.5132 - accuracy: 0.8333 - val_loss: 2.3211 - val_accuracy: 0.3722
# Epoch 27/50
# 2/2 [==============================] - 1s 938ms/step - loss: 0.4326 - accuracy: 0.8889 - val_loss: 2.3039 - val_accuracy: 0.3694
# Epoch 28/50
# 2/2 [==============================] - 1s 943ms/step - loss: 0.9181 - accuracy: 0.5556 - val_loss: 2.2820 - val_accuracy: 0.3667
# Epoch 29/50
# 2/2 [==============================] - 1s 916ms/step - loss: 0.5908 - accuracy: 0.7778 - val_loss: 2.2658 - val_accuracy: 0.3667
# Epoch 30/50
# 2/2 [==============================] - 1s 904ms/step - loss: 0.3520 - accuracy: 0.8889 - val_loss: 2.2549 - val_accuracy: 0.3694
# Epoch 31/50
# 2/2 [==============================] - 1s 940ms/step - loss: 0.5296 - accuracy: 0.8333 - val_loss: 2.2495 - val_accuracy: 0.3722
# Epoch 32/50
# 2/2 [==============================] - 1s 903ms/step - loss: 0.8926 - accuracy: 0.6111 - val_loss: 2.2258 - val_accuracy: 0.3778
# Epoch 33/50
# 2/2 [==============================] - 1s 928ms/step - loss: 0.4902 - accuracy: 0.8333 - val_loss: 2.2069 - val_accuracy: 0.3639
# Epoch 34/50
# 2/2 [==============================] - 1s 898ms/step - loss: 0.6455 - accuracy: 0.8889 - val_loss: 2.1952 - val_accuracy: 0.3583
# Epoch 35/50
# 2/2 [==============================] - 1s 937ms/step - loss: 0.3544 - accuracy: 0.8889 - val_loss: 2.1797 - val_accuracy: 0.3583
# Epoch 36/50
# 2/2 [==============================] - 1s 900ms/step - loss: 0.4839 - accuracy: 0.8889 - val_loss: 2.1709 - val_accuracy: 0.3611
# Epoch 37/50
# 2/2 [==============================] - 1s 956ms/step - loss: 0.6067 - accuracy: 0.8889 - val_loss: 2.1663 - val_accuracy: 0.3611
# Epoch 38/50
# 2/2 [==============================] - 1s 910ms/step - loss: 0.4282 - accuracy: 0.9444 - val_loss: 2.1626 - val_accuracy: 0.3583
# Epoch 39/50
# 2/2 [==============================] - 1s 915ms/step - loss: 0.5347 - accuracy: 0.8333 - val_loss: 2.1648 - val_accuracy: 0.3556
# Epoch 40/50
# 2/2 [==============================] - 1s 907ms/step - loss: 0.2353 - accuracy: 1.0000 - val_loss: 2.1657 - val_accuracy: 0.3639
# Epoch 41/50
# 2/2 [==============================] - 1s 913ms/step - loss: 0.5826 - accuracy: 0.8889 - val_loss: 2.1672 - val_accuracy: 0.3583
# Epoch 42/50
# 2/2 [==============================] - 1s 982ms/step - loss: 0.3430 - accuracy: 0.8889 - val_loss: 2.1735 - val_accuracy: 0.3583
# Epoch 43/50
# 2/2 [==============================] - 1s 929ms/step - loss: 0.4782 - accuracy: 0.8333 - val_loss: 2.1713 - val_accuracy: 0.3583
# Epoch 44/50
# 2/2 [==============================] - 1s 918ms/step - loss: 0.5963 - accuracy: 0.8333 - val_loss: 2.1624 - val_accuracy: 0.3583
# Epoch 45/50
# 2/2 [==============================] - 1s 911ms/step - loss: 0.3205 - accuracy: 0.8889 - val_loss: 2.1444 - val_accuracy: 0.3611
# Epoch 46/50
# 2/2 [==============================] - 1s 928ms/step - loss: 0.4186 - accuracy: 0.8333 - val_loss: 2.1204 - val_accuracy: 0.3667
# Epoch 47/50
# 2/2 [==============================] - 1s 953ms/step - loss: 0.6451 - accuracy: 0.7222 - val_loss: 2.1087 - val_accuracy: 0.3639
# Epoch 48/50
# 2/2 [==============================] - 1s 932ms/step - loss: 0.4688 - accuracy: 0.7778 - val_loss: 2.0943 - val_accuracy: 0.3694
# Epoch 49/50
# 2/2 [==============================] - 1s 944ms/step - loss: 0.4942 - accuracy: 0.8333 - val_loss: 2.0845 - val_accuracy: 0.3889
# Epoch 50/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.5259 - accuracy: 0.8333 - val_loss: 2.0827 - val_accuracy: 0.4500
# Epoch 00050: early stopping and save the model
# 12/12 [==============================] - 1s 48ms/step - loss: 2.5615 - accuracy: 0.4333

# %%
#finetuning
extractor_1.trainable = True
extractor_2.trainable = True
extractor_3.trainable = True
extractor_4.trainable = True
extractor_5.trainable = True
ensemble.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-5),
                    loss='categorical_crossentropy',
                    metrics=['accuracy'])
#train_sequence = ecifar10data(sampled_x_train, sampled_y_train, batch_size=10, train=False)
#validation_sequence = ecifar10data(x_val, y_val, batch_size=10, train=False)
history = ensemble.fit(
    train_sequence,
    epochs=20,
    validation_data=validation_sequence,
    #validation_steps=200,
    callbacks=eCustomEarlyStoppingAndSave(
        save_path='ensemble.h5',
        patience=10))
evaluate = ensemble.evaluate(x_test,keras.utils.to_categorical(y_test))
# Out:
# Epoch 1/20
# 2/2 [==============================] - 4s 1s/step - loss: 0.4555 - accuracy: 0.8333 - val_loss: 2.0918 - val_accuracy: 0.4556
# Epoch 2/20
# 2/2 [==============================] - 1s 1s/step - loss: 0.4308 - accuracy: 0.8889 - val_loss: 2.0955 - val_accuracy: 0.4583
# Epoch 3/20
# 2/2 [==============================] - 1s 1s/step - loss: 0.4100 - accuracy: 0.8889 - val_loss: 2.0861 - val_accuracy: 0.4639
# Epoch 4/20
# 2/2 [==============================] - 1s 946ms/step - loss: 0.3127 - accuracy: 0.9444 - val_loss: 2.0849 - val_accuracy: 0.4611
# Epoch 5/20
# 2/2 [==============================] - 1s 1s/step - loss: 0.6028 - accuracy: 0.8333 - val_loss: 2.0715 - val_accuracy: 0.4667
# Epoch 6/20
# 2/2 [==============================] - 1s 964ms/step - loss: 0.4003 - accuracy: 0.8889 - val_loss: 2.0572 - val_accuracy: 0.4667
# Epoch 7/20
# 2/2 [==============================] - 1s 1s/step - loss: 0.3947 - accuracy: 0.8889 - val_loss: 2.0486 - val_accuracy: 0.4694
# Epoch 8/20
# 2/2 [==============================] - 1s 954ms/step - loss: 0.6809 - accuracy: 0.7222 - val_loss: 2.0343 - val_accuracy: 0.4667
# Epoch 9/20
# 2/2 [==============================] - 1s 938ms/step - loss: 0.2807 - accuracy: 1.0000 - val_loss: 2.0229 - val_accuracy: 0.4583
# Epoch 10/20
# 2/2 [==============================] - 1s 935ms/step - loss: 0.5049 - accuracy: 0.8889 - val_loss: 2.0101 - val_accuracy: 0.4583
# Epoch 11/20
# 2/2 [==============================] - 1s 958ms/step - loss: 0.4833 - accuracy: 0.8889 - val_loss: 1.9946 - val_accuracy: 0.4528
# Epoch 12/20
# 2/2 [==============================] - 1s 914ms/step - loss: 0.3542 - accuracy: 0.9444 - val_loss: 1.9766 - val_accuracy: 0.4500
# Epoch 13/20
# 2/2 [==============================] - 1s 925ms/step - loss: 0.1858 - accuracy: 1.0000 - val_loss: 1.9599 - val_accuracy: 0.4472
# Epoch 14/20
# 2/2 [==============================] - 1s 968ms/step - loss: 0.2812 - accuracy: 0.8889 - val_loss: 1.9472 - val_accuracy: 0.4500
# Epoch 15/20
# 2/2 [==============================] - 1s 985ms/step - loss: 0.4952 - accuracy: 0.8889 - val_loss: 1.9379 - val_accuracy: 0.4472
# Epoch 16/20
# 2/2 [==============================] - 1s 937ms/step - loss: 0.2217 - accuracy: 1.0000 - val_loss: 1.9292 - val_accuracy: 0.4472
# Epoch 17/20
# 2/2 [==============================] - 1s 959ms/step - loss: 0.3371 - accuracy: 0.8889 - val_loss: 1.9228 - val_accuracy: 0.4500
# Epoch 18/20
# 2/2 [==============================] - 1s 992ms/step - loss: 0.8192 - accuracy: 0.7222 - val_loss: 1.9143 - val_accuracy: 0.4500
# Epoch 19/20
# 2/2 [==============================] - 1s 936ms/step - loss: 0.2108 - accuracy: 1.0000 - val_loss: 1.9120 - val_accuracy: 0.4500
# Epoch 20/20
# 2/2 [==============================] - 1s 928ms/step - loss: 0.8402 - accuracy: 0.7222 - val_loss: 1.9041 - val_accuracy: 0.4528
# Epoch 00007: early stopping and save the model
# 12/12 [==============================] - 1s 49ms/step - loss: 2.4032 - accuracy: 0.4472

# %%
#f1 score
predict = tf.argmax(ensemble.predict(x_test),axis=-1)
classification_report(y_test, predict,digits=4)
# Out:
# '              precision    recall  f1-score   support\n\n           0     0.5978    0.9167    0.7237        60\n           1     0.4038    0.3500    0.3750        60\n           2     0.9231    0.8000    0.8571        60\n           3     0.2500    0.0333    0.0588        60\n           4     0.0000    0.0000    0.0000        60\n           5     0.2869    0.5833    0.3846        60\n\n    accuracy                         0.4472       360\n   macro avg     0.4103    0.4472    0.3999       360\nweighted avg     0.4103    0.4472    0.3999       360\n'
